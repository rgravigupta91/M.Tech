# %% [markdown]
# # Mini Project
# ### - Bharat Devdas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Import Dataset

# %%
bank_df = pd.read_csv('bank1.csv')

# %% [markdown]
# ## 2. a. Identify the Features data types before entering into the analysis

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# ## 2. b. Convert the datatypes which are wrongly identified according to the business(domain). Kindly use the User Defined function and loop to convert the data types once.

# %%
def change(df, cols, dt):
    for col in cols:
        df[col] = df[col].astype(dt)

# %% [markdown]
# In my opinion the balance field can be a float and not an integer as it holds the average balance value.

# %%
change(bank_df, ['balance'], 'float')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %%
bank_df.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %% [markdown]
# ## 2. c. Find and Remove missing if any. Use visualization to find the missing values or Use general method to find the missing values.

# %%
bank_df.isna()
# Out:
#         age    job  marital  education  default  balance  housing   loan  \
# 0     False  False    False      False    False    False    False  False
# 1     False  False    False      False    False    False    False  False
# 2     False  False    False      False    False    False    False  False
# 3     False  False    False      False    False    False    False  False
# 4     False  False    False      False    False    False    False  False
# ...     ...    ...      ...        ...      ...      ...      ...    ...
# 4516  False  False    False      False    False    False    False  False
# 4517  False  False    False      False    False    False    False  False
# 4518  False  False    False      False    False    False    False  False
# 4519  False  False    False      False    False    False    False  False
# 4520  False  False    False      False    False    False    False  False
#
#       contact    day  month  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
bank_df.isna().nunique()
# Out:
# age          1
# job          1
# marital      1
# education    1
# default      1
# balance      1
# housing      1
# loan         1
# contact      1
# day          1
# month        1
# duration     1
# campaign     1
# pdays        1
# previous     1
# poutcome     1
# y            1
# dtype: int64

# %%
bank_df.isna().any()
# Out:
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# y            False
# dtype: bool

# %%
bank_df.isna().any().sum()
# Out:
# 0

# %%
sns.heatmap(bank_df.isna(), cbar=False, cmap='rainbow')
# Out:
# <Axes: >

# %% [markdown]
# The above result shows that there are no missing values. We can assume all values are filled.

# %% [markdown]
# ## Find duplicates (if necessary)

# %%
bank_df[bank_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, y]
# Index: []

# %% [markdown]
# The above result shows that there are no duplicate records.

# %% [markdown]
# ## 3. Find the average balance of the customer who belongs to the subscribed customer and non-subscribed customer and also use a related plot to show them in visualization.

# %%
bank_df.groupby(by='y')['balance'].mean()
# Out:
# y
# no     1403.211750
# yes    1571.955854
# Name: balance, dtype: float64

# %%
# By value
plt.bar(x=['non-subscribed','subscribed'], height=bank_df.groupby(by='y')['balance'].mean())
plt.show()

# %%
# By percentage
plt.pie(labels=['non-subscribed','subscribed'] ,x=bank_df.groupby(by='y').balance.mean(),autopct='%.2f')
plt.show()

# %% [markdown]
# The average balance of customers who belong to subscribed group is ***1571.955854***
#
# The average balance of customers who belong to non subscribed group is ***1403.211750***

# %% [markdown]
# ## 4. Use a pie plot to find the distribution(frequency) of the education. Make sure to add labels and show the percentage of each education distribution.

# %%
val_cnt = bank_df.education.value_counts()
val_cnt
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
plt.pie(labels=val_cnt.index, x=val_cnt.values, autopct='%.2f')
plt.show()

# %% [markdown]
# ## 5. Create a function that should be able to create a new feature(Variable) called season using the month column.

# %%
def addSeason(df, mon_col):
    season_dic = {'jan':'winter', 'feb':'winter', 'mar':'spring', 'apr':'spring', 'may':'spring', 'jun':'summer',
                  'jul':'summer', 'aug':'summer', 'sep':'autumn', 'oct':'autumn', 'nov':'autumn', 'dec':'winter'}
    df['season'] = df[mon_col].map(season_dic)

addSeason(bank_df, 'month')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %% [markdown]
# ## 6. Use the count plot with a variable that you created in the above question and also the Y variable to find the class distribution.

# %%
sns.countplot(x=bank_df.season, hue=bank_df.y)
# Out:
# <Axes: xlabel='season', ylabel='count'>

# %% [markdown]
# ## 7. Use the Pdays feature and find does it cause any effect on the subscription of the term using the bar plot.

# %%
plt.figure(figsize=(10,8), dpi=100)
sns.barplot(data=bank_df, x='y', y='pdays')
plt.show()

# %% [markdown]
# ## 8. Replace the -1 as nan values for the P-days store.

# %%
bank_df.pdays.replace(-1, np.nan, inplace=True)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
# 4520   44   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %% [markdown]
# ## 9. Once you are done with question number 8, do the same analysis as question number 7. And observe the difference between question number 7 and question number 9.

# %%
plt.figure(figsize=(8,6), dpi=100)
sns.barplot(data=bank_df, x='y', y='pdays')
# Out:
# <Axes: xlabel='y', ylabel='pdays'>

# %% [markdown]
# ## 10. Does the customer take the term subscription who has less than 0 balance?
# Hint: Use any kind of plot which would you the related information to this question.

# %%
less_than_zero_bal_subs = bank_df[bank_df.balance<0].y
plt.pie(labels=less_than_zero_bal_subs.value_counts().index, x=less_than_zero_bal_subs.value_counts(),
        autopct='%.2f')
plt.show()

# %% [markdown]
# The plot show that **8.47%** of customers whose balance is less than 0 have subscribed to the term.

# %% [markdown]
# ## 11. Use Pivot table to find the maximum balance for each type of job.

# %%
max_bax_per_education = pd.pivot_table(bank_df, index='job', values='balance', aggfunc='max')
max_bax_per_education
# Out:
#                balance
# job
# admin.         22171.0
# blue-collar    16353.0
# entrepreneur   42045.0
# housemaid      26965.0
# management     27359.0
# retired        71188.0
# self-employed  16430.0
# services       26394.0
# student        11555.0
# technician     27733.0
# unemployed      9019.0
# unknown         7337.0

# %% [markdown]
# ## 12. Use the Age, balance, and Y column to plot the scatter plot and find what kind of relationship Age and balance had, and See the points which belong 0 and 1 class and how they are distributed.

# %%
cls_y = bank_df[bank_df.y == 'yes']
cls_n = bank_df[bank_df.y == 'no']

plt.figure(figsize=(10,8), dpi=100)
plt.scatter(cls_y['age'], cls_y['balance'], label='YES')
plt.scatter(cls_n['age'], cls_n['balance'], label='NO')
plt.xlabel('AGE')
plt.ylabel('BALANCE')
plt.legend()
plt.show()

# %% [markdown]
# ## 13. Use the violin plot and also the box plot to find the distribution of the balance for each class of the Y column. And try to tell why we have a Violin plot and Box plot both rather than one.

# %%
plt.figure(figsize=(15,9), dpi=100)
sns.violinplot(x=bank_df.balance, y=bank_df.y)
plt.show()

# %%
plt.figure(figsize=(15,9), dpi=100)
sns.boxplot(x=bank_df.balance, y=bank_df.y)
plt.show()

# %% [markdown]
# ### Boxplot vs Violin Plot
# The box plot shows the distribution of numerical values, which include the median, quartiles and outliers. The box plot also hides the individual data points.
# The violin plot is called as such because the plot looks like a violin. The plot is similar to box plot but it also adds a density plot. The violin helps visualise the dataset's distribution and shows the density at different values.

# %% [markdown]
# ## 14. Use a pie plot to know the Proportion(distribution) of the defaulters and non-defaulters.
# Note: Try to explore more parameters that are there in the pie-plot method.

# %%
plt.pie(labels=bank_df.default.value_counts().index, x=bank_df.default.value_counts(), autopct='%.2f',
        explode=[.3,0], shadow=True)
plt.legend()
plt.title('Proportion of defaulters')
plt.show()
#bank_df.default.nunique()

# %% [markdown]
# ## 15. Use Box plot and strip plot to know the distribution of the Pdays with respect to Y classes and differentiate both plots.

# %%
plt.figure(figsize=(15,9), dpi=100)
sns.boxplot(x=bank_df.pdays, y=bank_df.y)
plt.show()

# %%
plt.figure(figsize=(15,9), dpi=100)
sns.stripplot(x=bank_df.pdays, y=bank_df.y)
plt.show()

# %% [markdown]
# The box plot only shows the distribution of the campaigns to subscribed and non-subscribed customers.
# But it is the strip plot that shows that there the subscribed customers are contacted in intervals close to 100 days, while the non subcribed customers are contacted more often.
