# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = [101,112,203,304,335,406,507,608,709,810]
plt.plot(data)
plt.show()

# %%
data = [101,112,203,304,335,406,507,608,709,810]
plt.plot(data)
plt.title('Line Plot')
plt.show()

# %%
data = [101,112,203,304,335,406,507,608,709,810]
plt.plot(data)
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
data = [101,112,203,304,335,406,507,608,709,810]
plt.plot(data)
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.show()

# %%
data = [101,112,203,304,335,406,507,608,709,810]
plt.plot(data)
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(color='r', linestyle='-.', linewidth=1)
plt.show()

# %%
x = [1,2,3,4]

y1 = [80000,78000,87000,95000]
y2 = [75000,14000,18000,20888]
y3 = [45000,45000,80333,80000]
y4 = [47000,45000,78000,45700]

plt.plot(x,y1,'g',label='Vivo',linewidth=5)
plt.plot(x,y2,'r',label='Oppo',linewidth=5)
plt.plot(x,y3,'c',label='Samsung',linewidth=5)
plt.plot(x,y4,'y',label='Micromax',linewidth=5)

plt.title('Sales details in line plot')
plt.xlabel('Days')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
#df_iris = pd.read_csv('Iris.csv')
from sklearn import datasets
iris = datasets.load_iris(as_frame=True)
iris = iris.data

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris.plot.scatter(x='sepal length (cm)',y='sepal width (cm)')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
plt.scatter(x='sepal length (cm)',y='sepal width (cm)', col)
