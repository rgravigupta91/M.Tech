# %% [markdown]
# ## Question 1 : Function

# %% [markdown]
# A dam releases 2M gallons of water in a month. Then increases the water release exponentially for next 3 months. On every 5th month the government closes the dam for a month and again starts releasing water in the same way.
#
# 1. Construct the funtion for the amount of water release from the dam.
# 2. Draw the function of the monthly amount of water release from the dam for 4 years.

# %% [markdown]
# ### 1.1 : Construct the function for the amount of water release from the dam.

# %% [markdown]
# ### 1.2 : Draw the function of the monthly amount of water release from the dam for 4 years .

# %% [markdown]
# ## Question 2 : Limit

# %% [markdown]
# According to a research  the amount of iceberg melts everyday can be put in an equation.
# The function to express the change in the volume of the iceberg could be written as 1 - (1/x)**(1/x).
#
# 1. What would happen to iceberg in very distant future.

# %% [markdown]
# ### 2.1 : What would happen to iceberg in very distant future.

# %% [markdown]
# ## Question 3 : Derivative

# %% [markdown]
# A particle travels along the function 2 x** 2 - 3 * x + 1 .Where x represents seconds.
#
# 1. Draw Movement function of the particle
# 2. Find the rate of change of movement of the particle
#     1. Use the limit concept.
#     2. use the differential fuction
# 3. Draw the rate of change of movement of the particle
# 4. Find the rate of change of movement of the particle at 90 seconds
#     1. Use the limit concept.
#     2. use the differential fuction
# 5. Draw the rate of change of movement of the particle  at 90 seconds

# %% [markdown]
# ### 3.1 : Draw Movement function of the particle

# %% [markdown]
# ### 3.2 : Find the rate of change of movement of the particle

# %% [markdown]
# ### 3.2.1 : Use the limit concept.

# %% [markdown]
# ### 3.2.2 : use the differential fuction

# %% [markdown]
# ### 3.3 : Draw the rate of change of movement of the particle

# %% [markdown]
# ### 3.4 : Find the rate of change of movement of the particle at 90 seconds

# %% [markdown]
# ### 3.4.1 : Use the limit concept.

# %% [markdown]
# ### 3.4.2 : use the differential fuction

# %% [markdown]
# ### 3.5 : Draw the rate of change of movement of the particle  at 90 seconds

# %% [markdown]
# ## Question 4 : Chain Rule

# %% [markdown]
# ### Find the derivative with the help of chain rule.

# %%
Image(S4_TH.png)

# %% [markdown]
# ### 4.1 : Calculate f1

# %% [markdown]
# ### 4.2 : Calculate f2

# %% [markdown]
# ### 4.3 : Calculate f3

# %% [markdown]
# ### 4.4 : Calculate f4

# %% [markdown]
# ### 4.5 : Calculate f5

# %% [markdown]
# ### 4.6 : Multiply f1 ,f2 ,f3 ,f4 ,f5

# %% [markdown]
# ### 4.7 : Calculate differentiation of f(x) with respect to x

# %% [markdown]
# ## ----------------------------------------------HAPPY LEARNING---------------------------------------------------------
