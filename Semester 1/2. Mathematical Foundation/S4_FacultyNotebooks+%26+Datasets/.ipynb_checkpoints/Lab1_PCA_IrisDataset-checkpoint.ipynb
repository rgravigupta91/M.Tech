# %% [markdown]
# ### Load Data

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
X.shape
# Out:
# (150, 4)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ### Visualize Data

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Lets create a 3D Graph

# %%
fig = plt.figure()
ax = Axes3D(fig)
for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean()-1.5,
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name)
# Change the order of labels, so that they match
y_clr = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y_clr)

#plt.show()
# Out:
# C:\Users\milan\AppData\Local\Temp/ipykernel_10332/1191685298.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\milan\AppData\Local\Temp/ipykernel_10332/1191685298.py:8: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_clr = np.choose(y, [1, 2, 0]).astype(np.float)

# %% [markdown]
# ### Using PCA

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# PCA with 2 components

# %%
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %% [markdown]
# Get new dimensions

# %%
X_pca = pca.transform(X)

# %%
X_pca.shape
# Out:
# (150, 2)

# %% [markdown]
# Plotting Iris data using 2 PCs

# %%
plt.plot(X_pca[y == 0, 0], X_pca[y == 0, 1], 'bo', label='Setosa')
plt.plot(X_pca[y == 1, 0], X_pca[y == 1, 1], 'go', label='Versicolour')
plt.plot(X_pca[y == 2, 0], X_pca[y == 2, 1], 'ro', label='Virginica')
plt.legend(loc=0)

# %% [markdown]
# ### Exploring PCA

# %% [markdown]
# Check EigenVectors or PC 1/2

# %%
pca.components_
# Out:
# array([[ 0.36138659, -0.08452251,  0.85667061,  0.3582892 ],
#        [ 0.65658877,  0.73016143, -0.17337266, -0.07548102]])

# %%
pca.explained_variance_
# Out:
# array([4.22824171, 0.24267075])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.92461872, 0.05306648])
