# %% [markdown]
# # SLR FINAL EXAM - Practice

# %% [markdown]
# ### Data_set:
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.

# %% [markdown]
# 1. id = listing ID
# 2. name = name of the listing
# 3. host_id = host ID
# 4. host_name = name of the host
# 5. neighbourhood_group = location
# 6. neighbourhood = area
# 7. latitude = latitude coordinates
# 8. longitude = longitude coordinates
# 9. room_type = listing space type
# 10. price = price in dollars (Target variable)
# 11. minimum_nights = amount of nights minimum
# 12. number_of_reviews = number of reviews
# 13. last_review = latest review
# 14. reviews_per_month = number of reviews per month
# 15. calculated_host_listings_count = amount of listing per host
# 16. availability_365 = number of days when listing is available for booking

# %% [markdown]
# ### 1.	 Read the dataset (tab, csv, xls, txt, inbuilt dataset)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_set.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.shape
# Out:
# (48895, 16)

# %%
ny_big = pd.read_csv('listings.csv.gz', compression='gzip')
ny_big.shape
# Out:
# (394, 75)

# %%
ny_big.describe().T
# Out:
#                                               count          mean  \
# id                                            394.0  5.480226e+17
# scrape_id                                     394.0  2.024051e+13
# host_id                                       394.0  2.247919e+08
# host_listings_count                           394.0  1.992132e+01
# host_total_listings_count                     394.0  3.438832e+01
# neighbourhood_group_cleansed                    0.0           NaN
# latitude                                      394.0  4.265788e+01
# longitude                                     394.0 -7.377660e+01
# accommodates                                  394.0  3.532995e+00
# bathrooms                                     344.0  1.236919e+00
# bedrooms                                      389.0  1.624679e+00
# beds                                          343.0  1.606414e+00
# minimum_nights                                394.0  5.269036e+00
# maximum_nights                                394.0  5.385127e+02
# minimum_minimum_nights                        394.0  5.030457e+00
# maximum_minimum_nights                        394.0  5.492386e+00
# minimum_maximum_nights                        394.0  7.501980e+02
# maximum_maximum_nights                        394.0  7.733959e+02
# minimum_nights_avg_ntm                        394.0  5.309645e+00
# maximum_nights_avg_ntm                        394.0  7.687713e+02
# calendar_updated                                0.0           NaN
# availability_30                               394.0  1.382995e+01
# availability_60                               394.0  3.206853e+01
# availability_90                               394.0  5.190102e+01
# availability_365                              394.0  2.203096e+02
# number_of_reviews                             394.0  5.724619e+01
# number_of_reviews_ltm                         394.0  1.722335e+01
# number_of_reviews_l30d                        394.0  1.522843e+00
# review_scores_rating                          349.0  4.780544e+00
# review_scores_accuracy                        349.0  4.826562e+00
# review_scores_cleanliness                     349.0  4.775931e+00
# review_scores_checkin                         349.0  4.866734e+00
# review_scores_communication                   349.0  4.884183e+00
# review_scores_location                        349.0  4.708797e+00
# review_scores_value                           349.0  4.750860e+00
# license                                         0.0           NaN
# calculated_host_listings_count                394.0  5.142132e+00
# calculated_host_listings_count_entire_homes   394.0  3.868020e+00
# calculated_host_listings_count_private_rooms  394.0  1.269036e+00
# calculated_host_listings_count_shared_rooms   394.0  5.076142e-03
# reviews_per_month                             349.0  2.107192e+00
#
#                                                        std           min  \
# id                                            4.411279e+17  1.489424e+06
# scrape_id                                     0.000000e+00  2.024051e+13
# host_id                                       1.820328e+08  6.490680e+05
# host_listings_count                           1.252281e+02  1.000000e+00
# host_total_listings_count                     2.295770e+02  1.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      9.562238e-03  4.263066e+01
# longitude                                     1.923227e-02 -7.387649e+01
# accommodates                                  2.524219e+00  1.000000e+00
# bathrooms                                     6.600670e-01  0.000000e+00
# bedrooms                                      1.059083e+00  0.000000e+00
# beds                                          1.365688e+00  0.000000e+00
# minimum_nights                                2.009149e+01  1.000000e+00
# maximum_nights                                4.211354e+02  1.000000e+00
# minimum_minimum_nights                        1.998127e+01  1.000000e+00
# maximum_minimum_nights                        2.002927e+01  1.000000e+00
# minimum_maximum_nights                        4.380094e+02  1.000000e+00
# maximum_maximum_nights                        4.271782e+02  1.000000e+00
# minimum_nights_avg_ntm                        2.004300e+01  1.000000e+00
# maximum_nights_avg_ntm                        4.262443e+02  1.000000e+00
# calendar_updated                                       NaN           NaN
# availability_30                               1.037756e+01  0.000000e+00
# availability_60                               2.039952e+01  0.000000e+00
# availability_90                               2.956294e+01  0.000000e+00
# availability_365                              1.108273e+02  0.000000e+00
# number_of_reviews                             1.018728e+02  0.000000e+00
# number_of_reviews_ltm                         2.246685e+01  0.000000e+00
# number_of_reviews_l30d                        2.295196e+00  0.000000e+00
# review_scores_rating                          3.537679e-01  1.000000e+00
# review_scores_accuracy                        3.285132e-01  1.000000e+00
# review_scores_cleanliness                     3.868723e-01  1.000000e+00
# review_scores_checkin                         2.420309e-01  3.000000e+00
# review_scores_communication                   2.244514e-01  3.000000e+00
# review_scores_location                        3.765706e-01  1.000000e+00
# review_scores_value                           3.216112e-01  2.000000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                5.549692e+00  1.000000e+00
# calculated_host_listings_count_entire_homes   5.606961e+00  0.000000e+00
# calculated_host_listings_count_private_rooms  2.719958e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   7.115635e-02  0.000000e+00
# reviews_per_month                             2.021007e+00  4.000000e-02
#
#                                                        25%           50%  \
# id                                            4.824728e+07  7.013127e+17
# scrape_id                                     2.024051e+13  2.024051e+13
# host_id                                       4.762598e+07  1.886791e+08
# host_listings_count                           2.000000e+00  3.000000e+00
# host_total_listings_count                     2.000000e+00  5.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      4.265245e+01  4.265728e+01
# longitude                                    -7.379013e+01 -7.377326e+01
# accommodates                                  2.000000e+00  3.000000e+00
# bathrooms                                     1.000000e+00  1.000000e+00
# bedrooms                                      1.000000e+00  1.000000e+00
# beds                                          1.000000e+00  1.000000e+00
# minimum_nights                                1.000000e+00  2.000000e+00
# maximum_nights                                3.650000e+02  3.650000e+02
# minimum_minimum_nights                        1.000000e+00  1.500000e+00
# maximum_minimum_nights                        1.000000e+00  2.000000e+00
# minimum_maximum_nights                        3.650000e+02  1.125000e+03
# maximum_maximum_nights                        3.650000e+02  1.125000e+03
# minimum_nights_avg_ntm                        1.000000e+00  2.000000e+00
# maximum_nights_avg_ntm                        3.650000e+02  1.125000e+03
# calendar_updated                                       NaN           NaN
# availability_30                               3.000000e+00  1.500000e+01
# availability_60                               1.400000e+01  3.650000e+01
# availability_90                               2.725000e+01  5.900000e+01
# availability_365                              1.260000e+02  2.440000e+02
# number_of_reviews                             4.000000e+00  1.700000e+01
# number_of_reviews_ltm                         2.000000e+00  9.000000e+00
# number_of_reviews_l30d                        0.000000e+00  0.000000e+00
# review_scores_rating                          4.730000e+00  4.880000e+00
# review_scores_accuracy                        4.800000e+00  4.910000e+00
# review_scores_cleanliness                     4.740000e+00  4.870000e+00
# review_scores_checkin                         4.840000e+00  4.950000e+00
# review_scores_communication                   4.860000e+00  4.960000e+00
# review_scores_location                        4.600000e+00  4.820000e+00
# review_scores_value                           4.670000e+00  4.830000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                1.000000e+00  3.000000e+00
# calculated_host_listings_count_entire_homes   1.000000e+00  2.000000e+00
# calculated_host_listings_count_private_rooms  0.000000e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   0.000000e+00  0.000000e+00
# reviews_per_month                             5.700000e-01  1.500000e+00
#
#                                                        75%           max
# id                                            9.379253e+17  1.149284e+18
# scrape_id                                     2.024051e+13  2.024051e+13
# host_id                                       3.904722e+08  5.750301e+08
# host_listings_count                           9.000000e+00  1.178000e+03
# host_total_listings_count                     1.300000e+01  2.181000e+03
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      4.266260e+01  4.271490e+01
# longitude                                    -7.376268e+01 -7.373810e+01
# accommodates                                  4.000000e+00  1.600000e+01
# bathrooms                                     1.000000e+00  7.000000e+00
# bedrooms                                      2.000000e+00  7.000000e+00
# beds                                          2.000000e+00  8.000000e+00
# minimum_nights                                3.000000e+00  3.650000e+02
# maximum_nights                                1.125000e+03  1.125000e+03
# minimum_minimum_nights                        3.000000e+00  3.650000e+02
# maximum_minimum_nights                        3.000000e+00  3.650000e+02
# minimum_maximum_nights                        1.125000e+03  1.125000e+03
# maximum_maximum_nights                        1.125000e+03  1.125000e+03
# minimum_nights_avg_ntm                        3.000000e+00  3.650000e+02
# maximum_nights_avg_ntm                        1.125000e+03  1.125000e+03
# calendar_updated                                       NaN           NaN
# availability_30                               2.300000e+01  3.000000e+01
# availability_60                               5.000000e+01  6.000000e+01
# availability_90                               7.800000e+01  9.000000e+01
# availability_365                              3.207500e+02  3.650000e+02
# number_of_reviews                             6.400000e+01  7.950000e+02
# number_of_reviews_ltm                         2.400000e+01  1.310000e+02
# number_of_reviews_l30d                        2.000000e+00  1.200000e+01
# review_scores_rating                          4.990000e+00  5.000000e+00
# review_scores_accuracy                        5.000000e+00  5.000000e+00
# review_scores_cleanliness                     4.980000e+00  5.000000e+00
# review_scores_checkin                         5.000000e+00  5.000000e+00
# review_scores_communication                   5.000000e+00  5.000000e+00
# review_scores_location                        4.950000e+00  5.000000e+00
# review_scores_value                           4.950000e+00  5.000000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                8.000000e+00  2.200000e+01
# calculated_host_listings_count_entire_homes   4.000000e+00  2.200000e+01
# calculated_host_listings_count_private_rooms  1.000000e+00  1.100000e+01
# calculated_host_listings_count_shared_rooms   0.000000e+00  1.000000e+00
# reviews_per_month                             3.000000e+00  1.105000e+01

# %%
ny_big.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')
