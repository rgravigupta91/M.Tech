# %% [markdown]
# ## Table of Contents
#
# ### 1. Data Loading and Preprocessing
# > #### 1.1 Load the Data
# > #### 1.2 Define custom dataset
# > #### 1.3 Data Exploration
# ### 2. Lane Segmentation using FCN
# > #### 2.1 Define model architecture
# > #### 2.2 Train the model
# > #### 2.3 Calculate IoU score
# ### 3. Lane Segmentation using DeepLabv3
# > #### 3.1 Define model architecture
# > #### 3.2 Train the model
# > #### 3.3 Calculate IoU score
#
# ---

# %% [markdown]
# ### 1. Data Loading and Preprocessing

# %% [markdown]
# #### 1.1 Load the Data

# %%
# Upload data from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip drive/My\ Drive/dataset_camVid.zip
# Out:
# Archive:  drive/My Drive/dataset_camVid.zip
#   inflating: data/CamVid/test/0001TP_008550.png
#   inflating: data/CamVid/test/0001TP_008580.png
#   inflating: data/CamVid/test/0001TP_008610.png
#   inflating: data/CamVid/test/0001TP_008640.png
#   inflating: data/CamVid/test/0001TP_008670.png
#   inflating: data/CamVid/test/0001TP_008700.png
#   inflating: data/CamVid/test/0001TP_008730.png
#   inflating: data/CamVid/test/0001TP_008760.png
#   inflating: data/CamVid/test/0001TP_008790.png
#   inflating: data/CamVid/test/0001TP_008820.png
#   inflating: data/CamVid/test/0001TP_008850.png
#   inflating: data/CamVid/test/0001TP_008880.png
#   inflating: data/CamVid/test/0001TP_008910.png
#   inflating: data/CamVid/test/0001TP_008940.png
#   inflating: data/CamVid/test/0001TP_008970.png
#   inflating: data/CamVid/test/0001TP_009000.png
#   inflating: data/CamVid/test/0001TP_009030.png
#   inflating: data/CamVid/test/0001TP_009060.png
#   inflating: data/CamVid/test/0001TP_009090.png
#   inflating: data/CamVid/test/0001TP_009120.png
#   inflating: data/CamVid/test/0001TP_009150.png
#   inflating: data/CamVid/test/0001TP_009180.png
#   inflating: data/CamVid/test/0001TP_009210.png
#   inflating: data/CamVid/test/0001TP_009240.png
#   inflating: data/CamVid/test/0001TP_009270.png
#   inflating: data/CamVid/test/0001TP_009300.png
#   inflating: data/CamVid/test/0001TP_009330.png
#   inflating: data/CamVid/test/0001TP_009360.png
#   inflating: data/CamVid/test/0001TP_009390.png
#   inflating: data/CamVid/test/0001TP_009420.png
#   inflating: data/CamVid/test/0001TP_009450.png
#   inflating: data/CamVid/test/0001TP_009480.png
#   inflating: data/CamVid/test/0001TP_009510.png
#   inflating: data/CamVid/test/0001TP_009540.png
#   inflating: data/CamVid/test/0001TP_009570.png
#   inflating: data/CamVid/test/0001TP_009600.png
#   inflating: data/CamVid/test/0001TP_009630.png
#   inflating: data/CamVid/test/0001TP_009660.png
#   inflating: data/CamVid/test/0001TP_009690.png
#   inflating: data/CamVid/test/0001TP_009720.png
#   inflating: data/CamVid/test/0001TP_009750.png
#   inflating: data/CamVid/test/0001TP_009780.png
#   inflating: data/CamVid/test/0001TP_009810.png
#   inflating: data/CamVid/test/0001TP_009840.png
#   inflating: data/CamVid/test/0001TP_009870.png
#   inflating: data/CamVid/test/0001TP_009900.png
#   inflating: data/CamVid/testannot/Seq05VD_f00960.png
#   inflating: data/CamVid/testannot/Seq05VD_f00990.png
#  extracting: data/CamVid/testannot/Seq05VD_f01020.png
#  extracting: data/CamVid/testannot/Seq05VD_f01050.png
#  extracting: data/CamVid/testannot/Seq05VD_f01080.png
#   inflating: data/CamVid/testannot/Seq05VD_f01110.png
#  extracting: data/CamVid/testannot/Seq05VD_f01140.png
#  extracting: data/CamVid/testannot/Seq05VD_f01170.png
#  extracting: data/CamVid/testannot/Seq05VD_f01200.png
#  extracting: data/CamVid/testannot/Seq05VD_f01230.png
#  extracting: data/CamVid/testannot/Seq05VD_f01260.png
#  extracting: data/CamVid/testannot/Seq05VD_f01290.png
#  extracting: data/CamVid/testannot/Seq05VD_f01320.png
#  extracting: data/CamVid/testannot/Seq05VD_f01350.png
#  extracting: data/CamVid/testannot/Seq05VD_f01380.png
#  extracting: data/CamVid/testannot/Seq05VD_f01410.png
#   inflating: data/CamVid/testannot/Seq05VD_f01440.png
#  extracting: data/CamVid/testannot/Seq05VD_f01470.png
#  extracting: data/CamVid/testannot/Seq05VD_f01500.png
#  extracting: data/CamVid/testannot/Seq05VD_f01530.png
#  extracting: data/CamVid/testannot/Seq05VD_f01560.png
#  extracting: data/CamVid/testannot/Seq05VD_f01590.png
#  extracting: data/CamVid/testannot/Seq05VD_f01620.png
#  extracting: data/CamVid/testannot/Seq05VD_f01650.png
#  extracting: data/CamVid/testannot/Seq05VD_f01680.png
#  extracting: data/CamVid/testannot/Seq05VD_f01710.png
#  extracting: data/CamVid/testannot/Seq05VD_f01740.png
#   inflating: data/CamVid/testannot/Seq05VD_f01770.png
#  extracting: data/CamVid/testannot/Seq05VD_f01800.png
#  extracting: data/CamVid/testannot/Seq05VD_f01830.png
#  extracting: data/CamVid/testannot/Seq05VD_f01860.png
#  extracting: data/CamVid/testannot/Seq05VD_f01890.png
#   inflating: data/CamVid/testannot/Seq05VD_f01920.png
#  extracting: data/CamVid/testannot/Seq05VD_f01950.png
#  extracting: data/CamVid/testannot/Seq05VD_f01980.png
#  extracting: data/CamVid/testannot/Seq05VD_f02010.png
#   inflating: data/CamVid/testannot/Seq05VD_f02040.png
#  extracting: data/CamVid/testannot/Seq05VD_f02070.png
#  extracting: data/CamVid/testannot/Seq05VD_f02100.png
#  extracting: data/CamVid/testannot/Seq05VD_f02130.png
#  extracting: data/CamVid/testannot/Seq05VD_f02160.png
#  extracting: data/CamVid/testannot/Seq05VD_f02190.png
#  extracting: data/CamVid/testannot/Seq05VD_f02220.png
#  extracting: data/CamVid/testannot/Seq05VD_f02250.png
#  extracting: data/CamVid/testannot/Seq05VD_f02280.png
#  extracting: data/CamVid/testannot/Seq05VD_f02310.png
#  extracting: data/CamVid/testannot/Seq05VD_f02340.png
#  extracting: data/CamVid/testannot/Seq05VD_f02370.png
#  extracting: data/CamVid/testannot/Seq05VD_f02400.png
#  extracting: data/CamVid/testannot/Seq05VD_f02430.png
#  extracting: data/CamVid/testannot/Seq05VD_f02460.png
#  extracting: data/CamVid/testannot/Seq05VD_f02490.png
#  extracting: data/CamVid/testannot/Seq05VD_f02520.png
#  extracting: data/CamVid/testannot/Seq05VD_f02550.png
#  extracting: data/CamVid/testannot/Seq05VD_f02580.png
#  extracting: data/CamVid/testannot/Seq05VD_f02610.png
#  extracting: data/CamVid/testannot/Seq05VD_f02640.png
#  extracting: data/CamVid/testannot/Seq05VD_f02670.png
#  extracting: data/CamVid/testannot/Seq05VD_f02700.png
#  extracting: data/CamVid/testannot/Seq05VD_f02730.png
#  extracting: data/CamVid/testannot/Seq05VD_f02760.png
#  extracting: data/CamVid/testannot/Seq05VD_f02790.png
#  extracting: data/CamVid/testannot/Seq05VD_f02820.png
#  extracting: data/CamVid/testannot/Seq05VD_f02850.png
#  extracting: data/CamVid/testannot/Seq05VD_f02880.png
#  extracting: data/CamVid/testannot/Seq05VD_f02910.png
#   inflating: data/CamVid/testannot/Seq05VD_f02940.png
#   inflating: data/CamVid/testannot/Seq05VD_f02970.png
#   inflating: data/CamVid/testannot/Seq05VD_f03000.png
#  extracting: data/CamVid/testannot/Seq05VD_f03030.png
#  extracting: data/CamVid/testannot/Seq05VD_f03060.png
#  extracting: data/CamVid/testannot/Seq05VD_f03090.png
#  extracting: data/CamVid/testannot/Seq05VD_f03120.png
#  extracting: data/CamVid/testannot/Seq05VD_f03150.png
#   inflating: data/CamVid/testannot/Seq05VD_f03180.png
#  extracting: data/CamVid/testannot/Seq05VD_f03210.png
#  extracting: data/CamVid/testannot/Seq05VD_f03240.png
#  extracting: data/CamVid/testannot/Seq05VD_f03270.png
#   inflating: data/CamVid/testannot/Seq05VD_f03300.png
#   inflating: data/CamVid/testannot/Seq05VD_f03330.png
#  extracting: data/CamVid/testannot/Seq05VD_f03360.png
#  extracting: data/CamVid/testannot/Seq05VD_f03390.png
#  extracting: data/CamVid/testannot/Seq05VD_f03420.png
#  extracting: data/CamVid/testannot/Seq05VD_f03450.png
#  extracting: data/CamVid/testannot/Seq05VD_f03480.png
#   inflating: data/CamVid/testannot/Seq05VD_f03510.png
#   inflating: data/CamVid/testannot/Seq05VD_f03540.png
#   inflating: data/CamVid/testannot/Seq05VD_f03570.png
#  extracting: data/CamVid/testannot/Seq05VD_f03600.png
#  extracting: data/CamVid/testannot/Seq05VD_f03630.png
#  extracting: data/CamVid/testannot/Seq05VD_f03660.png
#  extracting: data/CamVid/testannot/Seq05VD_f03690.png
#  extracting: data/CamVid/testannot/Seq05VD_f03720.png
#  extracting: data/CamVid/testannot/Seq05VD_f03750.png
#  extracting: data/CamVid/testannot/Seq05VD_f03780.png
#  extracting: data/CamVid/testannot/Seq05VD_f03810.png
#  extracting: data/CamVid/testannot/Seq05VD_f03840.png
#  extracting: data/CamVid/testannot/Seq05VD_f03870.png
#  extracting: data/CamVid/testannot/Seq05VD_f03900.png
#  extracting: data/CamVid/testannot/Seq05VD_f03930.png
#   inflating: data/CamVid/testannot/Seq05VD_f03960.png
#   inflating: data/CamVid/testannot/Seq05VD_f03990.png
#  extracting: data/CamVid/testannot/Seq05VD_f04020.png
#  extracting: data/CamVid/testannot/Seq05VD_f04050.png
#   inflating: data/CamVid/testannot/Seq05VD_f04080.png
#   inflating: data/CamVid/testannot/Seq05VD_f04110.png
#   inflating: data/CamVid/testannot/Seq05VD_f04140.png
#   inflating: data/CamVid/testannot/Seq05VD_f04170.png
#  extracting: data/CamVid/testannot/Seq05VD_f04200.png
#  extracting: data/CamVid/testannot/Seq05VD_f04230.png
#   inflating: data/CamVid/testannot/Seq05VD_f04260.png
#  extracting: data/CamVid/testannot/Seq05VD_f04290.png
#  extracting: data/CamVid/testannot/Seq05VD_f04320.png
#  extracting: data/CamVid/testannot/Seq05VD_f04350.png
#  extracting: data/CamVid/testannot/Seq05VD_f04380.png
#  extracting: data/CamVid/testannot/Seq05VD_f04410.png
#  extracting: data/CamVid/testannot/Seq05VD_f04440.png
#  extracting: data/CamVid/testannot/Seq05VD_f04470.png
#  extracting: data/CamVid/testannot/Seq05VD_f04500.png
#  extracting: data/CamVid/testannot/Seq05VD_f04530.png
#  extracting: data/CamVid/testannot/Seq05VD_f04560.png
#  extracting: data/CamVid/testannot/Seq05VD_f04590.png
#  extracting: data/CamVid/testannot/Seq05VD_f04620.png
#  extracting: data/CamVid/testannot/Seq05VD_f04650.png
#  extracting: data/CamVid/testannot/Seq05VD_f04680.png
#  extracting: data/CamVid/testannot/Seq05VD_f04710.png
#  extracting: data/CamVid/testannot/Seq05VD_f04740.png
#  extracting: data/CamVid/testannot/Seq05VD_f04770.png
#   inflating: data/CamVid/testannot/Seq05VD_f04800.png
#  extracting: data/CamVid/testannot/Seq05VD_f04830.png
#  extracting: data/CamVid/testannot/Seq05VD_f04860.png
#  extracting: data/CamVid/testannot/Seq05VD_f04890.png
#  extracting: data/CamVid/testannot/Seq05VD_f04920.png
#  extracting: data/CamVid/testannot/Seq05VD_f04950.png
#  extracting: data/CamVid/testannot/Seq05VD_f04980.png
#   inflating: data/CamVid/testannot/Seq05VD_f05010.png
#  extracting: data/CamVid/testannot/Seq05VD_f05040.png
#  extracting: data/CamVid/testannot/Seq05VD_f05070.png
#  extracting: data/CamVid/testannot/Seq05VD_f05100.png
#   inflating: data/CamVid/test/Seq05VD_f00000.png
#   inflating: data/CamVid/test/Seq05VD_f00030.png
#   inflating: data/CamVid/test/Seq05VD_f00060.png
#   inflating: data/CamVid/test/Seq05VD_f00090.png
#   inflating: data/CamVid/test/Seq05VD_f00120.png
#   inflating: data/CamVid/test/Seq05VD_f00150.png
#   inflating: data/CamVid/test/Seq05VD_f00180.png
#   inflating: data/CamVid/test/Seq05VD_f00210.png
#   inflating: data/CamVid/test/Seq05VD_f00240.png
#   inflating: data/CamVid/test/Seq05VD_f00270.png
#   inflating: data/CamVid/test/Seq05VD_f00300.png
#   inflating: data/CamVid/test/Seq05VD_f00330.png
#   inflating: data/CamVid/test/Seq05VD_f00360.png
#   inflating: data/CamVid/test/Seq05VD_f02010.png
#   inflating: data/CamVid/test/Seq05VD_f02040.png
#   inflating: data/CamVid/test/Seq05VD_f02070.png
#   inflating: data/CamVid/test/Seq05VD_f02100.png
#   inflating: data/CamVid/test/Seq05VD_f02130.png
#   inflating: data/CamVid/test/Seq05VD_f02160.png
#   inflating: data/CamVid/test/Seq05VD_f02190.png
#   inflating: data/CamVid/test/Seq05VD_f02220.png
#   inflating: data/CamVid/test/Seq05VD_f02250.png
#   inflating: data/CamVid/test/Seq05VD_f02280.png
#   inflating: data/CamVid/test/Seq05VD_f02310.png
#   inflating: data/CamVid/test/Seq05VD_f02340.png
#   inflating: data/CamVid/test/Seq05VD_f02370.png
#   inflating: data/CamVid/test/Seq05VD_f02400.png
#   inflating: data/CamVid/test/Seq05VD_f02430.png
#   inflating: data/CamVid/test/Seq05VD_f02460.png
#   inflating: data/CamVid/test/Seq05VD_f02490.png
#   inflating: data/CamVid/test/Seq05VD_f02520.png
#   inflating: data/CamVid/test/Seq05VD_f02550.png
#   inflating: data/CamVid/test/Seq05VD_f02580.png
#   inflating: data/CamVid/test/Seq05VD_f02610.png
#   inflating: data/CamVid/test/Seq05VD_f02640.png
#   inflating: data/CamVid/test/Seq05VD_f02670.png
#   inflating: data/CamVid/test/Seq05VD_f02700.png
#   inflating: data/CamVid/test/Seq05VD_f02730.png
#   inflating: data/CamVid/test/Seq05VD_f02760.png
#   inflating: data/CamVid/test/Seq05VD_f02790.png
#   inflating: data/CamVid/test/Seq05VD_f02820.png
#   inflating: data/CamVid/test/Seq05VD_f02850.png
#   inflating: data/CamVid/test/Seq05VD_f02880.png
#   inflating: data/CamVid/test/Seq05VD_f02910.png
#   inflating: data/CamVid/test/Seq05VD_f02940.png
#   inflating: data/CamVid/test/Seq05VD_f02970.png
#   inflating: data/CamVid/test/Seq05VD_f03000.png
#   inflating: data/CamVid/test/Seq05VD_f03030.png
#   inflating: data/CamVid/test/Seq05VD_f03060.png
#   inflating: data/CamVid/test/Seq05VD_f03090.png
#   inflating: data/CamVid/test/Seq05VD_f03120.png
#   inflating: data/CamVid/test/Seq05VD_f03150.png
#   inflating: data/CamVid/test/Seq05VD_f03180.png
#   inflating: data/CamVid/test/Seq05VD_f03210.png
#   inflating: data/CamVid/test/Seq05VD_f03240.png
#   inflating: data/CamVid/test/Seq05VD_f03270.png
#   inflating: data/CamVid/test/Seq05VD_f03300.png
#   inflating: data/CamVid/test/Seq05VD_f03330.png
#   inflating: data/CamVid/test/Seq05VD_f03360.png
#   inflating: data/CamVid/test/Seq05VD_f03390.png
#   inflating: data/CamVid/test/Seq05VD_f03420.png
#   inflating: data/CamVid/test/Seq05VD_f03450.png
#   inflating: data/CamVid/test/Seq05VD_f03480.png
#   inflating: data/CamVid/test/Seq05VD_f03510.png
#   inflating: data/CamVid/test/Seq05VD_f03540.png
#   inflating: data/CamVid/test/Seq05VD_f03570.png
#   inflating: data/CamVid/test/Seq05VD_f03600.png
#   inflating: data/CamVid/test/Seq05VD_f03630.png
#   inflating: data/CamVid/test/Seq05VD_f03660.png
#   inflating: data/CamVid/test/Seq05VD_f03690.png
#   inflating: data/CamVid/test/Seq05VD_f03720.png
#   inflating: data/CamVid/test/Seq05VD_f03750.png
#   inflating: data/CamVid/test/Seq05VD_f03780.png
#   inflating: data/CamVid/test/Seq05VD_f03810.png
#   inflating: data/CamVid/test/Seq05VD_f03840.png
#   inflating: data/CamVid/test/Seq05VD_f03870.png
#   inflating: data/CamVid/test/Seq05VD_f03900.png
#   inflating: data/CamVid/test/Seq05VD_f03930.png
#   inflating: data/CamVid/test/Seq05VD_f03960.png
#   inflating: data/CamVid/test/Seq05VD_f03990.png
#   inflating: data/CamVid/test/Seq05VD_f04020.png
#   inflating: data/CamVid/test/Seq05VD_f04050.png
#   inflating: data/CamVid/test/Seq05VD_f04080.png
#   inflating: data/CamVid/test/Seq05VD_f04110.png
#   inflating: data/CamVid/test/Seq05VD_f04140.png
#   inflating: data/CamVid/test/Seq05VD_f04170.png
#   inflating: data/CamVid/test/Seq05VD_f04200.png
#   inflating: data/CamVid/test/Seq05VD_f04230.png
#   inflating: data/CamVid/test/Seq05VD_f04260.png
#   inflating: data/CamVid/test/Seq05VD_f04290.png
#   inflating: data/CamVid/test/Seq05VD_f04320.png
#   inflating: data/CamVid/test/Seq05VD_f04350.png
#   inflating: data/CamVid/test/Seq05VD_f04380.png
#   inflating: data/CamVid/test/Seq05VD_f04410.png
#   inflating: data/CamVid/test/Seq05VD_f04440.png
#   inflating: data/CamVid/test/Seq05VD_f04470.png
#   inflating: data/CamVid/test/Seq05VD_f04500.png
#   inflating: data/CamVid/test/Seq05VD_f04530.png
#   inflating: data/CamVid/test/Seq05VD_f04560.png
#   inflating: data/CamVid/test/Seq05VD_f04590.png
#   inflating: data/CamVid/test/Seq05VD_f04620.png
#   inflating: data/CamVid/test/Seq05VD_f04650.png
#   inflating: data/CamVid/test/Seq05VD_f04680.png
#   inflating: data/CamVid/test/Seq05VD_f04710.png
#   inflating: data/CamVid/test/Seq05VD_f04740.png
#   inflating: data/CamVid/test/Seq05VD_f04770.png
#   inflating: data/CamVid/test/Seq05VD_f04800.png
#   inflating: data/CamVid/test/Seq05VD_f04830.png
#   inflating: data/CamVid/test/Seq05VD_f04860.png
#   inflating: data/CamVid/test/Seq05VD_f04890.png
#   inflating: data/CamVid/test/Seq05VD_f04920.png
#   inflating: data/CamVid/test/Seq05VD_f04950.png
#   inflating: data/CamVid/test/Seq05VD_f04980.png
#   inflating: data/CamVid/test/Seq05VD_f05010.png
#   inflating: data/CamVid/test/Seq05VD_f05040.png
#   inflating: data/CamVid/test/Seq05VD_f05070.png
#   inflating: data/CamVid/test/Seq05VD_f05100.png
#   inflating: data/CamVid/train/0001TP_006690.png
#   inflating: data/CamVid/train/0001TP_006720.png
#   inflating: data/CamVid/train/0001TP_006750.png
#   inflating: data/CamVid/train/0001TP_006780.png
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
from random import random

# import pytorch related modules
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose, ToTensor, Resize

from torch.nn import Sequential
from torch.nn import Conv2d, ReLU, Sigmoid, BatchNorm2d, Dropout

from torchvision.models.segmentation import fcn_resnet101, deeplabv3_resnet101
from torchvision.models.segmentation.deeplabv3 import DeepLabHead

# %%
# set seed
seed = 42
np.random.seed(seed)
torch.manual_seed(seed);

# %%
x_train_dir = '/content/data/CamVid/train'
y_train_dir = '/content/data/CamVid/trainannot'

x_val_dir = '/content/data/CamVid/val'
y_val_dir = '/content/data/CamVid/valannot'

x_test_dir = '/content/data/CamVid/test'
y_test_dir = '/content/data/CamVid/testannot'

# %% [markdown]
# #### 1.2 Define custom dataset

# %%
# define custom dataset class
class CamVidDataset(Dataset):
    def __init__(self, images_dir, masks_dir=None, transforms=None, training_type=None):
        # get all image names
        self.image_names = os.listdir(images_dir)

        # set training type, transforms
        self.training_type = training_type
        self.transforms = transforms

        # get image and target paths
        self.images_paths = []
        self.masks_paths = []
        for image_name in self.image_names:
            self.images_paths.append(os.path.join(images_dir, image_name))
            if self.training_type=="train" or self.training_type=="val":
                self.masks_paths.append(os.path.join(masks_dir, image_name.split('.')[0] + '.png'))
    
    def __getitem__(self, i):
        
        if self.training_type=="train" or self.training_type=="val":
            # read data
            image = Image.open(self.images_paths[i])
            mask = Image.open(self.masks_paths[i])

            # preprocess mask
            mask = np.array(mask)
            mask = (mask == 3)
            mask = Image.fromarray(mask)

            # apply transforms
            image = self.transforms(image)
            mask = self.transforms(mask)
            
            return image, mask
        
        else:
            # read data
            image = Image.open(self.images_fps[i])
            
            # apply transforms
            image = self.transforms(image)
            
            return image
        
    def __len__(self):
        return len(self.image_names)

# %% [markdown]
# #### 1.3 Data Exploration

# %%
train_transforms = Compose([
    Resize((224, 224)),
    ToTensor()
])

# %%
# Lets look at data we have
dataset = CamVidDataset(x_train_dir, y_train_dir, transforms=train_transforms, training_type='train')

image, gt_mask = dataset[0]

# %%
image.shape, gt_mask.shape
# Out:
# (torch.Size([3, 224, 224]), torch.Size([1, 224, 224]))

# %%
plt.imshow(np.transpose(image, (1, 2, 0)))

# %%
plt.imshow(gt_mask.squeeze(), cmap='gray')

# %%
# create transform
train_transforms = Compose([
    Resize((224, 224)),
    ToTensor()
])
# create instance of custom dataset
train_dataset = CamVidDataset(
    x_train_dir, 
    y_train_dir, 
    transforms=train_transforms,
    training_type='train'
)
# create dataloader
train_loader = DataLoader(
    train_dataset, 
    batch_size=16,
    num_workers=4
)

# %%
for batch_x, batch_y in train_loader:
    break

# %%
batch_x.shape, batch_y.shape
# Out:
# (torch.Size([16, 3, 224, 224]), torch.Size([16, 1, 224, 224]))

# %% [markdown]
# ### 2. Lane Segmentation using FCN

# %% [markdown]
# #### 2.1 Define model architecture

# %%
# define model
model = fcn_resnet101(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/checkpoints/resnet101-5d3b4d8f.pth
# HBox(children=(FloatProgress(value=0.0, max=178728960.0), HTML(value='')))
# Downloading: "https://download.pytorch.org/models/fcn_resnet101_coco-7ecb50ca.pth" to /root/.cache/torch/checkpoints/fcn_resnet101_coco-7ecb50ca.pth
# HBox(children=(FloatProgress(value=0.0, max=217800805.0), HTML(value='')))

# %%
# print model
model
# Out:
# FCN(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): FCNHead(
#     (0): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(512, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
# freeze model parameters
for parameters in model.parameters():
    parameters.requires_grad = False

# %%
model.classifier = Sequential(
    Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False), 
    BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 
    ReLU(), 
    Dropout(p=0.1, inplace=False), 
    Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1)),
    Sigmoid()
)

# %%
# check for one iteration of loop
for batch_x, batch_y in train_loader:
    break

# %%
# check model on one image
model.eval()
output = model(batch_x[1].view(1, 3, 224, 224))['out'].detach().numpy()

# %%
# print output
plt.imshow(output.squeeze(), cmap='gray')

# %% [markdown]
# #### 2.2 Train the model

# %%
# transfer model to GPU
model = model.to("cuda")

# %%
# define optimization and loss function
criterion = torch.nn.BCELoss()
optimizer = torch.optim.Adam([parameters for parameters in model.parameters() if parameters.requires_grad], lr=1e-3)

# %%
# set model to train
model.train()

# train model
for epoch in range(5):

    # initialize variables
    epoch_loss = cnt = 0

    # loop through the data
    for batch_x, batch_y in train_loader:
        # get batch images and targets and transfer them to GPU
        batch_x = batch_x.to("cuda").float()
        batch_y = batch_y.to("cuda").float()

        # clear gradients
        optimizer.zero_grad()

        # pass images to model
        outputs = model(batch_x)

        # get loss
        loss = criterion(outputs['out'], batch_y)

        # do a backward pass
        loss.backward()

        # update gradients
        optimizer.step()

        # sum loss and get count
        epoch_loss += loss.item()
        cnt += 1

    # take average loss for all batches
    epoch_loss /= cnt
    
    # print loss
    print("Training loss for epoch {} is {} ".format(epoch + 1, epoch_loss))
# Out:
# Training loss for epoch 1 is 0.19129586219787598
# Training loss for epoch 2 is 0.12210948020219803
# Training loss for epoch 3 is 0.10102380002322404
# Training loss for epoch 4 is 0.08621591847875844
# Training loss for epoch 5 is 0.07602501142284145

# %% [markdown]
# #### 2.3 Calculate IoU score

# %%
# get sample data
image = Image.open('/content/data/CamVid/train/0006R0_f00930.png')
gt_mask = Image.open('/content/data/CamVid/trainannot/0006R0_f00930.png')

# %%
plt.imshow(image)

# %%
# preprocess mask
gt_mask = np.array(gt_mask)
gt_mask = (gt_mask == 3)
gt_mask = Image.fromarray(gt_mask)

# apply data augmentation
transform = Compose([
            Resize((224, 224)),
            ToTensor()
            ])
        
image = transform(image)

gt_mask = transform(gt_mask)

# %%
model.eval()
output = model(image.view(1, 3, 224, 224).to("cuda"))['out'].cpu().detach().numpy()

# %%
plt.imshow(gt_mask.squeeze(), cmap='gray')

# %%
plt.imshow((output.squeeze() > 0.5).astype(int), cmap='gray')

# %%
# convert predicted mask to flattened numpy array
mask = (output.squeeze() > 0.5).astype(int)
pred = mask.ravel().copy()

# convert ground truth mask to flattened numpy array
gt_mask = gt_mask.cpu().detach().numpy()
target = gt_mask.ravel().copy().astype(int)

# get class indices for Lane
pred_inds = pred == 1
target_inds = target == 1

# calculate intersection
intersection = pred_inds[target_inds].sum()

# calculate union
union = pred_inds.sum() + target_inds.sum() - intersection

# get IoU score
iou = (float(intersection) / float(max(union, 1)))
iou
# Out:
# 0.9350255730251942

# %% [markdown]
# ### 2. Lane Segmentation using DeepLabv3

# %% [markdown]
# #### 3.1 Define model architecture

# %%
model = deeplabv3_resnet101(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /root/.cache/torch/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
# HBox(children=(FloatProgress(value=0.0, max=244545539.0), HTML(value='')))

# %%
for parameters in model.parameters():
    parameters.requires_grad = False

# %%
model.classifier = DeepLabHead(in_channels=2048, num_classes=1)

# %%
# check for one iteration of loop
for batch_x, batch_y in train_loader:
    break

# %%
# check model on one image
model.eval()
output = model(batch_x[1].view(1, 3, 224, 224))['out'].detach().numpy()

# %%
# print output
plt.imshow(output.squeeze(), cmap='gray')

# %% [markdown]
# #### 3.2 Train the model

# %%
# transfer model to GPU
model = model.to("cuda")

# %%
# define optimization and loss function
criterion = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam([parameters for parameters in model.parameters() if parameters.requires_grad], lr=1e-3)

# %%
# set model to train
model.train()

# train model
for epoch in range(5):

    # initialize variables
    epoch_loss = cnt = 0

    # loop through the data
    for batch_x, batch_y in train_loader:
        # get batch images and targets and transfer them to GPU
        batch_x = batch_x.to("cuda").float()
        batch_y = batch_y.to("cuda").float()

        # clear gradients
        optimizer.zero_grad()

        # pass images to model
        outputs = model(batch_x)

        # get loss
        loss = criterion(outputs['out'], batch_y)

        # do a backward pass
        loss.backward()

        # update gradients
        optimizer.step()

        # sum loss and get count
        epoch_loss += loss.item()
        cnt += 1

    # take average loss for all batches
    epoch_loss /= cnt
    
    # print loss
    print("Training loss for epoch {} is {} ".format(epoch + 1, epoch_loss))
# Out:
# Training loss for epoch 1 is 0.16160690298546915
# Training loss for epoch 2 is 0.08582162241572919
# Training loss for epoch 3 is 0.06951171840014665
# Training loss for epoch 4 is 0.05915875619520312
# Training loss for epoch 5 is 0.05214554978453595

# %% [markdown]
# #### 3.3 Calculate IoU score

# %%
# get sample data
image = Image.open('/content/data/CamVid/train/0006R0_f00930.png')
gt_mask = Image.open('/content/data/CamVid/trainannot/0006R0_f00930.png')

# %%
plt.imshow(image)

# %%
# preprocess mask
gt_mask = np.array(gt_mask)
gt_mask = (gt_mask == 3)
gt_mask = Image.fromarray(gt_mask)

# apply data augmentation
transform = Compose([
            Resize((224, 224)),
            ToTensor()
            ])
        
image = transform(image)

gt_mask = transform(gt_mask)

# %%
model.eval()
output = model(image.view(1, 3, 224, 224).to("cuda"))['out'].cpu().detach().numpy()

# %%
plt.imshow(gt_mask.squeeze(), cmap='gray')

# %%
plt.imshow((output.squeeze() > 0.5).astype(int), cmap='gray')

# %%
# convert predicted mask to flattened numpy array
mask = (output.squeeze() > 0.5).astype(int)
pred = mask.ravel().copy()

# convert ground truth mask to flattened numpy array
gt_mask = gt_mask.cpu().detach().numpy()
target = gt_mask.ravel().copy().astype(int)

# get class indices for Lane
pred_inds = pred == 1
target_inds = target == 1

# calculate intersection
intersection = pred_inds[target_inds].sum()

# calculate union
union = pred_inds.sum() + target_inds.sum() - intersection

# get IoU score
iou = (float(intersection) / float(max(union, 1)))
iou
