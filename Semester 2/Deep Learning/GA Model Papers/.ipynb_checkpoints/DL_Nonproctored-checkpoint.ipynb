# %% [markdown]
# Hello all,
#
# The dataset has been attached to the graded assessment with two folders which consists of two objects i.e., dogs and wolves images. Please develop a CNN to identify the shapes as either dog or wolf. The task has been categorized into binary classification.
#
# NOTE: Dataset acquired from the internet and entire credit goes to the original author
#
# INSTRUCTIONS:
#
#
# 1.   Your code should be unique and give some possible explanation of the architecture.
# 2.   Incase of similarities between two peers submissions, The submissions will be considered as copy and plagirazied and marks will be ZERO.
# 3.  No restrictions on CNN architecture. Feel free to explore.
# 4. Duration is 60 minutes. Late submission will not be allowed at any cost.
# 5. All the best.
