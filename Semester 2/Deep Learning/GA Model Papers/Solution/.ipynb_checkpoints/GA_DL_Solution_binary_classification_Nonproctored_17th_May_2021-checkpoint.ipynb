# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from numpy.random import seed
from pandas import read_csv, DataFrame
from sklearn.preprocessing import minmax_scale
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Flatten,Dense,Dropout,Activation
from keras.layers.normalization import BatchNormalization
import numpy as np
import pandas as pd
import sys
import tensorflow as tf
from keras import * 
import keras 
print( keras.__version__)
from keras import backend as K
K.set_image_data_format('channels_last')
##K.set_image_dim_ordering('tf')
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
from keras.metrics import binary_accuracy
from keras.metrics import categorical_accuracy

keras.backend.backend()
##keras.backend.image_dim_ordering()
# Out:
# 2.4.3
# 'tensorflow'

# %%
#demo for planes
img_width, img_height = 200, 200


train_data_dir      = '/content/drive/My Drive/DL-Assessment/re_data/Train/'
validation_data_dir = '/content/drive/My Drive/DL-Assessment/re_data/Valid/'

batch_size = 2

# %%
import time
start = time.time()

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
    
    
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape)) #(3,227, 227)
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# the model so far outputs 3D feature maps (height, width, features)

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
# COMPILE
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

end = time.time()
print(end - start)
# Out:
# 0.11767745018005371

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

#batch_size = 10
# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 900 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
import time
start = time.time()

model.fit_generator(train_generator,
                        steps_per_epoch=100,
                        epochs=100,
                        validation_data=validation_generator)

end = time.time()
print(end - start)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 100/100 [==============================] - 16s 155ms/step - loss: 0.8586 - accuracy: 0.4373 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 2/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.7206 - accuracy: 0.5041 - val_loss: 0.6932 - val_accuracy: 0.5100
# Epoch 3/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.6916 - accuracy: 0.5448 - val_loss: 0.7392 - val_accuracy: 0.5000
# Epoch 4/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.6772 - accuracy: 0.5756 - val_loss: 0.6488 - val_accuracy: 0.5000
# Epoch 5/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.7153 - accuracy: 0.6047 - val_loss: 0.6766 - val_accuracy: 0.5000
# Epoch 6/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6959 - accuracy: 0.5759 - val_loss: 0.7456 - val_accuracy: 0.5800
# Epoch 7/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6625 - accuracy: 0.6452 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 8/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6877 - accuracy: 0.5322 - val_loss: 0.6939 - val_accuracy: 0.5000
# Epoch 9/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.7013 - accuracy: 0.4947 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 10/100
# 100/100 [==============================] - 15s 148ms/step - loss: 0.6944 - accuracy: 0.5099 - val_loss: 0.6910 - val_accuracy: 0.5100
# Epoch 11/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.6931 - accuracy: 0.5701 - val_loss: 0.6857 - val_accuracy: 0.6000
# Epoch 12/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6912 - accuracy: 0.5292 - val_loss: 0.6890 - val_accuracy: 0.5200
# Epoch 13/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6841 - accuracy: 0.6070 - val_loss: 1.4642 - val_accuracy: 0.5000
# Epoch 14/100
# 100/100 [==============================] - 15s 148ms/step - loss: 0.6833 - accuracy: 0.5876 - val_loss: 0.6809 - val_accuracy: 0.5800
# Epoch 15/100
# 100/100 [==============================] - 15s 148ms/step - loss: 0.6838 - accuracy: 0.5371 - val_loss: 0.6525 - val_accuracy: 0.6500
# Epoch 16/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.6849 - accuracy: 0.6182 - val_loss: 0.6365 - val_accuracy: 0.7100
# Epoch 17/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.7140 - accuracy: 0.5596 - val_loss: 0.6446 - val_accuracy: 0.6300
# Epoch 18/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6626 - accuracy: 0.5924 - val_loss: 0.6633 - val_accuracy: 0.6300
# Epoch 19/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6833 - accuracy: 0.5727 - val_loss: 0.6919 - val_accuracy: 0.5300
# Epoch 20/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.7112 - accuracy: 0.4593 - val_loss: 0.6928 - val_accuracy: 0.4900
# Epoch 21/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6941 - accuracy: 0.4965 - val_loss: 0.6858 - val_accuracy: 0.5700
# Epoch 22/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6804 - accuracy: 0.5896 - val_loss: 0.6644 - val_accuracy: 0.6000
# Epoch 23/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6808 - accuracy: 0.6682 - val_loss: 0.6267 - val_accuracy: 0.6700
# Epoch 24/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6470 - accuracy: 0.6921 - val_loss: 0.6425 - val_accuracy: 0.6300
# Epoch 25/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6924 - accuracy: 0.5360 - val_loss: 0.6483 - val_accuracy: 0.6400
# Epoch 26/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6403 - accuracy: 0.6427 - val_loss: 0.6469 - val_accuracy: 0.6300
# Epoch 27/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6255 - accuracy: 0.6937 - val_loss: 0.6637 - val_accuracy: 0.6100
# Epoch 28/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6994 - accuracy: 0.5130 - val_loss: 0.6706 - val_accuracy: 0.6000
# Epoch 29/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6265 - accuracy: 0.6718 - val_loss: 0.6606 - val_accuracy: 0.6300
# Epoch 30/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.6578 - accuracy: 0.6102 - val_loss: 0.6505 - val_accuracy: 0.6600
# Epoch 31/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.6397 - accuracy: 0.6844 - val_loss: 0.6457 - val_accuracy: 0.6300
# Epoch 32/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6544 - accuracy: 0.6674 - val_loss: 0.6635 - val_accuracy: 0.6000
# Epoch 33/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6608 - accuracy: 0.6079 - val_loss: 0.6630 - val_accuracy: 0.5600
# Epoch 34/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.6365 - accuracy: 0.6528 - val_loss: 0.6430 - val_accuracy: 0.6100
# Epoch 35/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6491 - accuracy: 0.6339 - val_loss: 0.6613 - val_accuracy: 0.6000
# Epoch 36/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6358 - accuracy: 0.6165 - val_loss: 0.6294 - val_accuracy: 0.6700
# Epoch 37/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6488 - accuracy: 0.6577 - val_loss: 0.6253 - val_accuracy: 0.6500
# Epoch 38/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.6114 - accuracy: 0.6378 - val_loss: 0.6190 - val_accuracy: 0.6700
# Epoch 39/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6170 - accuracy: 0.6106 - val_loss: 0.6091 - val_accuracy: 0.6800
# Epoch 40/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.6510 - accuracy: 0.5755 - val_loss: 0.6442 - val_accuracy: 0.5400
# Epoch 41/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6319 - accuracy: 0.7018 - val_loss: 0.6177 - val_accuracy: 0.6900
# Epoch 42/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6519 - accuracy: 0.6239 - val_loss: 0.6324 - val_accuracy: 0.6700
# Epoch 43/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6028 - accuracy: 0.6748 - val_loss: 0.7473 - val_accuracy: 0.5300
# Epoch 44/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6359 - accuracy: 0.6628 - val_loss: 0.6163 - val_accuracy: 0.6900
# Epoch 45/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.6705 - accuracy: 0.6188 - val_loss: 0.6495 - val_accuracy: 0.6800
# Epoch 46/100
# 100/100 [==============================] - 16s 156ms/step - loss: 0.6413 - accuracy: 0.6061 - val_loss: 0.6428 - val_accuracy: 0.6900
# Epoch 47/100
# 100/100 [==============================] - 16s 162ms/step - loss: 0.6354 - accuracy: 0.6152 - val_loss: 0.6135 - val_accuracy: 0.6800
# Epoch 48/100
# 100/100 [==============================] - 17s 167ms/step - loss: 0.6563 - accuracy: 0.5839 - val_loss: 0.6324 - val_accuracy: 0.5400
# Epoch 49/100
# 100/100 [==============================] - 16s 159ms/step - loss: 0.5983 - accuracy: 0.7678 - val_loss: 0.5966 - val_accuracy: 0.7100
# Epoch 50/100
# 100/100 [==============================] - 16s 160ms/step - loss: 0.6033 - accuracy: 0.6643 - val_loss: 0.6035 - val_accuracy: 0.6800
# Epoch 51/100
# 100/100 [==============================] - 16s 156ms/step - loss: 0.5719 - accuracy: 0.6695 - val_loss: 0.5926 - val_accuracy: 0.6900
# Epoch 52/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5443 - accuracy: 0.7548 - val_loss: 0.6279 - val_accuracy: 0.6900
# Epoch 53/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5967 - accuracy: 0.6870 - val_loss: 0.6161 - val_accuracy: 0.7000
# Epoch 54/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.5318 - accuracy: 0.7749 - val_loss: 0.6301 - val_accuracy: 0.6800
# Epoch 55/100
# 100/100 [==============================] - 15s 154ms/step - loss: 0.5556 - accuracy: 0.7232 - val_loss: 0.6809 - val_accuracy: 0.6000
# Epoch 56/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.6330 - accuracy: 0.7170 - val_loss: 0.6398 - val_accuracy: 0.6700
# Epoch 57/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5872 - accuracy: 0.6251 - val_loss: 0.6658 - val_accuracy: 0.6900
# Epoch 58/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5967 - accuracy: 0.7049 - val_loss: 0.6134 - val_accuracy: 0.6800
# Epoch 59/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.6286 - accuracy: 0.6630 - val_loss: 0.6224 - val_accuracy: 0.7000
# Epoch 60/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5756 - accuracy: 0.6935 - val_loss: 0.6814 - val_accuracy: 0.6600
# Epoch 61/100
# 100/100 [==============================] - 15s 154ms/step - loss: 0.5583 - accuracy: 0.6889 - val_loss: 0.6036 - val_accuracy: 0.6800
# Epoch 62/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.5661 - accuracy: 0.7378 - val_loss: 0.6052 - val_accuracy: 0.7100
# Epoch 63/100
# 100/100 [==============================] - 15s 154ms/step - loss: 0.5506 - accuracy: 0.7031 - val_loss: 0.6167 - val_accuracy: 0.7200
# Epoch 64/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5733 - accuracy: 0.7213 - val_loss: 0.6205 - val_accuracy: 0.7100
# Epoch 65/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5730 - accuracy: 0.7106 - val_loss: 0.6252 - val_accuracy: 0.6500
# Epoch 66/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.4406 - accuracy: 0.7688 - val_loss: 0.5931 - val_accuracy: 0.7000
# Epoch 67/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5592 - accuracy: 0.7726 - val_loss: 0.6405 - val_accuracy: 0.6800
# Epoch 68/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.4916 - accuracy: 0.7584 - val_loss: 0.6154 - val_accuracy: 0.6900
# Epoch 69/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.5510 - accuracy: 0.7427 - val_loss: 0.6303 - val_accuracy: 0.6800
# Epoch 70/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.5384 - accuracy: 0.7236 - val_loss: 0.6477 - val_accuracy: 0.7100
# Epoch 71/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5119 - accuracy: 0.6919 - val_loss: 0.6264 - val_accuracy: 0.7100
# Epoch 72/100
# 100/100 [==============================] - 15s 154ms/step - loss: 0.7382 - accuracy: 0.6259 - val_loss: 0.6126 - val_accuracy: 0.6900
# Epoch 73/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.4952 - accuracy: 0.7550 - val_loss: 0.6295 - val_accuracy: 0.6800
# Epoch 74/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5004 - accuracy: 0.7811 - val_loss: 0.5955 - val_accuracy: 0.7100
# Epoch 75/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.6522 - accuracy: 0.7152 - val_loss: 0.6024 - val_accuracy: 0.7000
# Epoch 76/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.6217 - accuracy: 0.7064 - val_loss: 0.5946 - val_accuracy: 0.7300
# Epoch 77/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5675 - accuracy: 0.7516 - val_loss: 0.5796 - val_accuracy: 0.7200
# Epoch 78/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.4740 - accuracy: 0.8334 - val_loss: 0.6023 - val_accuracy: 0.7200
# Epoch 79/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5419 - accuracy: 0.7921 - val_loss: 0.6082 - val_accuracy: 0.7300
# Epoch 80/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5135 - accuracy: 0.7203 - val_loss: 0.6119 - val_accuracy: 0.7300
# Epoch 81/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5506 - accuracy: 0.7407 - val_loss: 0.6080 - val_accuracy: 0.7500
# Epoch 82/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5095 - accuracy: 0.7761 - val_loss: 0.6356 - val_accuracy: 0.6800
# Epoch 83/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5311 - accuracy: 0.7770 - val_loss: 0.5970 - val_accuracy: 0.7000
# Epoch 84/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6038 - accuracy: 0.7251 - val_loss: 0.6223 - val_accuracy: 0.7000
# Epoch 85/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.5458 - accuracy: 0.7291 - val_loss: 0.6041 - val_accuracy: 0.7000
# Epoch 86/100
# 100/100 [==============================] - 15s 154ms/step - loss: 0.5892 - accuracy: 0.6353 - val_loss: 0.5730 - val_accuracy: 0.7300
# Epoch 87/100
# 100/100 [==============================] - 15s 154ms/step - loss: 0.5183 - accuracy: 0.7875 - val_loss: 0.5808 - val_accuracy: 0.7000
# Epoch 88/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.4939 - accuracy: 0.7679 - val_loss: 0.6000 - val_accuracy: 0.7400
# Epoch 89/100
# 100/100 [==============================] - 15s 154ms/step - loss: 0.5392 - accuracy: 0.7046 - val_loss: 0.6468 - val_accuracy: 0.6800
# Epoch 90/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.4824 - accuracy: 0.7751 - val_loss: 0.5813 - val_accuracy: 0.7100
# Epoch 91/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.5551 - accuracy: 0.7010 - val_loss: 0.6207 - val_accuracy: 0.6700
# Epoch 92/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.5687 - accuracy: 0.7113 - val_loss: 0.5736 - val_accuracy: 0.7300
# Epoch 93/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.5158 - accuracy: 0.7116 - val_loss: 0.6085 - val_accuracy: 0.7400
# Epoch 94/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.4958 - accuracy: 0.7808 - val_loss: 0.6125 - val_accuracy: 0.7300
# Epoch 95/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.4915 - accuracy: 0.7640 - val_loss: 0.7513 - val_accuracy: 0.6400
# Epoch 96/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.5217 - accuracy: 0.7463 - val_loss: 0.6003 - val_accuracy: 0.7000
# Epoch 97/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.5193 - accuracy: 0.7578 - val_loss: 0.6108 - val_accuracy: 0.7400
# Epoch 98/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.6056 - accuracy: 0.6520 - val_loss: 0.5923 - val_accuracy: 0.7400
# Epoch 99/100
# 100/100 [==============================] - 15s 153ms/step - loss: 0.4736 - accuracy: 0.7857 - val_loss: 0.5892 - val_accuracy: 0.7200
# Epoch 100/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.4364 - accuracy: 0.8456 - val_loss: 0.6199 - val_accuracy: 0.7300
# 1522.9141414165497

# %%
from skimage.io import imread
from skimage.transform import resize
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt

import cv2
import numpy as np

import time
start = time.time()

#img = imread('/content/drive/My Drive/28th_April_2021_GA_DL_GL/GL-Dataset/AD_GL_Test/0-Sq.png')

 #make sure that path_to_file contains the path to the image you want to predict on. 
img = imread('/content/drive/My Drive/DL-Assessment/20210505-175328-151032.jpg')
img = resize(img,(200,200))
#img = load_img(img, target_size=(227, 227))
#print('PIL image size',img.size)
plt.imshow(img)
plt.show()

test_img = cv2.imread('/content/drive/My Drive/DL-Assessment/20210505-175328-151032.jpg')
test_img = test_img.reshape(1,200,200,3)

Y = model.predict(test_img)[0]
print(Y)

#val = np.argmax(Y)
if(Y >= 0.5):
    print("Wolf")
else:
    print("Dog")

end = time.time()
print(end - start)
# Out:
# [0.]
# Dog
# 0.41082143783569336

# %%
from skimage.io import imread
from skimage.transform import resize
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt

import cv2
import numpy as np

import time
start = time.time()

#img = imread('/content/drive/My Drive/28th_April_2021_GA_DL_GL/GL-Dataset/AD_GL_Test/0-Sq.png')

 #make sure that path_to_file contains the path to the image you want to predict on. 
img = imread('/content/drive/My Drive/DL-Assessment/20210505-175427-427576.jpg')
img = resize(img,(200,200))
#img = load_img(img, target_size=(227, 227))
#print('PIL image size',img.size)
plt.imshow(img)
plt.show()

test_img = cv2.imread('/content/drive/My Drive/DL-Assessment/20210505-175427-427576.jpg')
test_img = test_img.reshape(1,200,200,3)

Y = model.predict(test_img)[0]
print(Y)

#val = np.argmax(Y)
if(Y >= 0.5):
    print("Wolf")
else:
    print("Dog")

end = time.time()
print(end - start)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-bf96a69286f4> in <module>()
#      15
#      16  #make sure that path_to_file contains the path to the image you want to predict on.
# ---> 17 img = imread('/content/drive/My Drive/DL-Assessment/20210505-175427-427576.jpg')
#      18 img = resize(img,(200,200))
#      19 #img = load_img(img, target_size=(227, 227))
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/_plugins/imageio_plugin.py in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     263
#     264     # Get reader and read first
# --> 265     reader = read(uri, format, "i", **kwargs)
#     266     with reader:
#     267         return reader.get_data(0)
#
# /usr/local/lib/python3.7/dist-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     170
#     171     # Create request object
# --> 172     request = Request(uri, "r" + mode, **kwargs)
#     173
#     174     # Get format
#
# /usr/local/lib/python3.7/dist-packages/imageio/core/request.py in __init__(self, uri, mode, **kwargs)
#     122
#     123         # Parse what was given
# --> 124         self._parse_uri(uri)
#     125
#     126         # Set extension
#
# /usr/local/lib/python3.7/dist-packages/imageio/core/request.py in _parse_uri(self, uri)
#     258                 # Reading: check that the file exists (but is allowed a dir)
#     259                 if not os.path.exists(fn):
# --> 260                     raise FileNotFoundError("No such file: '%s'" % fn)
#     261             else:
#     262                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/content/drive/My Drive/DL-Assessment/20210505-175427-427576.jpg'
