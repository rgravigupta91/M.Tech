# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = []
for i in range(10):
    image = plt.imread('images/train/'+str(i)+'.jpg')
    X.append(image)

# %%
X
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[139,  91,  68],
#          [139,  91,  68],
#          [138,  90,  67],
#          ...,
#          [200, 242, 255],
#          [200, 242, 255],
#          [200, 242, 255]],
#
#         [[138,  92,  68],
#          [138,  92,  68],
#          [138,  92,  68],
#          ...,
#          [200, 242, 255],
#          [200, 242, 255],
#          [200, 242, 255]],
#
#         [[137,  93,  68],
# ...

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
X = np.array(X)

# %%
X.shape
# Out:
# (10, 600, 600, 3)

# %%
plt.imsave('all.jpg',X)

# %%
A = plt.imread('all.jpg')

# %%
if A == X:
    print('Yes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 if A == X:
#       2     print('Yes')
#
# ValueError: operands could not be broadcast together with shapes (10,600,3) (10,600,600,3)

# %%
A.shape
# Out:
# (10, 600, 3)
