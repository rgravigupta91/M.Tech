# %% [markdown]
# ### Introduction to Tensorflow 2.0

# %%
import tensorflow as tf

# %% [markdown]
# #### 1. Create a random tensor with 10 rows and 10 columns. Output random values should between range 1 and 10

# %% [markdown]
# #### 2. Assign the first value (first row, first column) and last value(last row, last column) to ZERO

# %% [markdown]
# #### 3. Create two tensor constants and perfrom subtraction and division

# %% [markdown]
# #### 4. Create 2 random matrices of size [4,4] and [4,4] with minimum value -10 and maximum value 10 and perform multiplication

# %% [markdown]
# #### 5. Create a float tensor and cast it into integer

# %% [markdown]
# #### 6. Create two tensors y1 and y2 randomly with normal distribution.
# ###### compute  sum of (y1-y2)^2
# ###### Compute avg of (y1-y2)^2
# ###### Sqrt (avg(y1-y2)^2)

# %% [markdown]
# #### 7. Create a matrix M1 randomly and compute its eigen value, determinant and transpose

# %% [markdown]
# #### 8. Create two matrix of size 3x4 and 3x4. Perform matrix multiplication by transposing any one matrix

# %% [markdown]
# #### 9. Perform the follwing equation using tensors y = 3*(x^3) + 4(x^2), where x = [3,7,8,4]

# %% [markdown]
# #### 10. #### 14. Consider the regression data below:
# inp=tf.constant([[18,1.5,1.5],[21,3,1.2],[29,7,2.5],[29,11,1.5],[17,1,1.5],
#                  [22,2,2.5],[31,12,1.5],[30,8,2.5]])
#
# out=tf.constant([[5],[6],[9],[13],[4.8],[5.5],[13.2],[10.5]])
#
# Compute the model coefficents using adam optimizer ? Use loss function as Mean squared error.
