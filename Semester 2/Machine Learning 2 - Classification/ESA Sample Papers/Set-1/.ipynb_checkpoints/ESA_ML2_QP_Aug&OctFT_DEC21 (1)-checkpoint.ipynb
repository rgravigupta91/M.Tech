# %% [markdown]
# # ML2 EXAM

# %% [markdown]
# ### DATA DESCRIPTION:
#
# This data set contains details of a bank's customers who have taken loans and the target variable is a binary variable reflecting the fact whether the customer will payback the loan or not.
#
# **CustomerId:** Unique Ids for bank customer identification
#
# **CreditScore:** Credit score of the customer
#
# **Geography:** The country from which the customer belongs
#
# **Gender:** Male or Female
#
# **Age:** Age of the customer
#
# **Tenure:** Number of years for which the customer has taken the loan
#
# **Balance:** Bank balance of the customer
#
# **NumOfProducts:** Number of bank products the customer is utilising
#
# **HasCrCard:** Binary Flag for whether the customer holds a credit card with the bank or not
#
# **IsActiveMember:** Binary Flag for whether the customer is an active member with the bank or not
#
# **EstimatedSalary:** Estimated salary of the customer in Dollars
#
# **Exited:** Binary flag 1 if the customer closed account with bank and 0 if the customer is retained
#
# **Target Column Description:** Payback the loan; class label is divided into groups (customer paybacks and not).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Section -B (Marks - 30)

# %% [markdown]
# ### 1.	Read the dataset (tab, csv, xls, txt, inbuilt dataset)

# %%
# Kindly change the below cells from markdown to code and execute it
df = pd.read_csv('Loan.csv')

# %% [markdown]
# import csv
#
# with open("data_set.csv","r")as file:
#
#     reader=csv.reader(file)
#
# df=pd.read_csv("data_set.csv")
#
# df.head()

# %% [markdown]
# ### 2.a.	Summarize important observations from the data set (5 Marks)
#
# Some pointers which would help you, but don’t be limited by these
#
# i.	Find out number of rows; no. & types of variables (continuous, categorical etc.)
#
# ii.	Calculate five-point summary for numerical variables
#
# iii.	Summarize observations for categorical variables – no. of categories, % observations in each category

# %%
df.head()
# Out:
#    CustomerId  CreditScore Geography  Gender   Age  Tenure    Balance  \
# 0     1152345          350     Spain    Male  54.0       1  152677.48
# 1     1152346          350   Germany    Male  39.0       0  109733.20
# 2     1152347          350    France    Male  51.0      10       0.00
# 3     1152348          350    France  Female  35.0       3       0.00
# 4     1152349          350    France  Female  59.0       0  111098.85
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Loan
# 0              1          1               1        191973.49     1
# 1              2          0               0        123602.11     1
# 2              1          1               1        125823.79     1
# 3              1          0               0        113796.15     1
# 4              1          1               1        172321.21     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       1630 non-null   int64
#  1   CreditScore      1630 non-null   int64
#  2   Geography        1630 non-null   object
#  3   Gender           1571 non-null   object
#  4   Age              1479 non-null   float64
#  5   Tenure           1630 non-null   int64
#  6   Balance          1630 non-null   float64
#  7   NumOfProducts    1630 non-null   int64
#  8   HasCrCard        1630 non-null   int64
#  9   IsActiveMember   1630 non-null   int64
#  10  EstimatedSalary  1630 non-null   float64
#  11  Loan             1630 non-null   int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 152.9+ KB

# %%
df.describe()
# Out:
#          CustomerId  CreditScore          Age       Tenure        Balance  \
# count  1.630000e+03  1630.000000  1479.000000  1630.000000    1630.000000
# mean   1.153352e+06   508.435583    38.016227     5.049693   76512.060387
# std    1.057108e+03    50.711238     8.152538     2.858111   62438.946664
# min    1.152345e+06   350.000000    18.000000     0.000000       0.000000
# 25%    1.152752e+06   480.000000    32.000000     3.000000       0.000000
# 50%    1.153160e+06   512.000000    38.000000     5.000000   96566.615000
# 75%    1.153567e+06   533.000000    44.000000     8.000000  127544.947500
# max    1.158803e+06   688.000000    60.000000    10.000000  221532.800000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count    1630.000000  1630.000000     1630.000000      1630.000000
# mean        1.508589     0.701227        0.489571    101016.860571
# std         0.564653     0.457861        0.500045     57100.527663
# min         1.000000     0.000000        0.000000       287.990000
# 25%         1.000000     0.000000        0.000000     53813.492500
# 50%         1.000000     1.000000        0.000000    101697.220000
# 75%         2.000000     1.000000        1.000000    149644.060000
# max         4.000000     1.000000        1.000000    199862.750000
#
#               Loan
# count  1630.000000
# mean      0.211043
# std       0.408174
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
for column in df.columns:
    print(f"{column}: Number of unique values {df[column].nunique()}")
# Out:
# CustomerId: Number of unique values 1630
# CreditScore: Number of unique values 237
# Geography: Number of unique values 3
# Gender: Number of unique values 2
# Age: Number of unique values 43
# Tenure: Number of unique values 11
# Balance: Number of unique values 1040
# NumOfProducts: Number of unique values 4
# HasCrCard: Number of unique values 2
# IsActiveMember: Number of unique values 2
# EstimatedSalary: Number of unique values 1630
# Loan: Number of unique values 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       1630 non-null   int64
#  1   CreditScore      1630 non-null   int64
#  2   Geography        1630 non-null   object
#  3   Gender           1571 non-null   object
#  4   Age              1479 non-null   float64
#  5   Tenure           1630 non-null   int64
#  6   Balance          1630 non-null   float64
#  7   NumOfProducts    1630 non-null   int64
#  8   HasCrCard        1630 non-null   int64
#  9   IsActiveMember   1630 non-null   int64
#  10  EstimatedSalary  1630 non-null   float64
#  11  Loan             1630 non-null   int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 152.9+ KB

# %%
numeric = df.select_dtypes(include=['float64','int64'])
numeric.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Loan'],
#       dtype='object')

# %%
df.describe()
# Out:
#          CustomerId  CreditScore          Age       Tenure        Balance  \
# count  1.630000e+03  1630.000000  1479.000000  1630.000000    1630.000000
# mean   1.153352e+06   508.435583    38.016227     5.049693   76512.060387
# std    1.057108e+03    50.711238     8.152538     2.858111   62438.946664
# min    1.152345e+06   350.000000    18.000000     0.000000       0.000000
# 25%    1.152752e+06   480.000000    32.000000     3.000000       0.000000
# 50%    1.153160e+06   512.000000    38.000000     5.000000   96566.615000
# 75%    1.153567e+06   533.000000    44.000000     8.000000  127544.947500
# max    1.158803e+06   688.000000    60.000000    10.000000  221532.800000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count    1630.000000  1630.000000     1630.000000      1630.000000
# mean        1.508589     0.701227        0.489571    101016.860571
# std         0.564653     0.457861        0.500045     57100.527663
# min         1.000000     0.000000        0.000000       287.990000
# 25%         1.000000     0.000000        0.000000     53813.492500
# 50%         1.000000     1.000000        0.000000    101697.220000
# 75%         2.000000     1.000000        1.000000    149644.060000
# max         4.000000     1.000000        1.000000    199862.750000
#
#               Loan
# count  1630.000000
# mean      0.211043
# std       0.408174
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# ### 2.b.	Check for defects in the data. Perform necessary actions to ‘fix’ these defects (10 Marks)
#
# Some pointers which would help you, but don’t be limited by these
#
# i.	Do variables have missing/null values?Is it a defect? If Yes, what steps are being taken to rectify the problem.
#
# ii.	Do variables have outliers?Is it a defect? If Yes, what steps are being taken to rectify the problem.
#
# iii.	Is the Target distributed evenly? Is it a defect? If Yes, what steps are being taken to rectify the problem.
#
# iv. Is there any textual data? Is it a defect? If Yes, what steps are being taken to rectify the problem.

# %%
df.isnull().sum()
# Out:
# CustomerId           0
# CreditScore          0
# Geography            0
# Gender              59
# Age                151
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Loan                 0
# dtype: int64

# %%
ind = df[df['Gender'].isnull()].index

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      837
# Female    734
# Name: count, dtype: int64

# %%
for i in ind:
    df['Gender'][i] = 'Male'
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1743945884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'][i] = 'Male'

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      896
# Female    734
# Name: count, dtype: int64

# %%
box = plt.boxplot(df[df['Age'].isnull()==False]['Age']);

# %%
df['Age'].fillna(int(df['Age'].mean()), inplace=True)

# %%
numeric.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Loan'],
#       dtype='object')

# %%
box = plt.boxplot(df['CreditScore']);

# %%
box = plt.boxplot(df['Age']);

# %%
box = plt.boxplot(df['NumOfProducts']);

# %%
from scipy import stats

# %%
Z = np.abs(stats.zscore(df[['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']]))
print(Z)
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        3.125228  2.059130  1.417347  1.220213       0.900986   0.652742
# 1        3.125228  0.126918  1.767336  0.532221       0.870555   1.532000
# 2        3.125228  1.672688  1.732552  1.225766       0.900986   0.652742
# 3        3.125228  0.388339  0.717370  1.225766       0.900986   1.532000
# 4        3.125228  2.703201  1.767336  0.554100       0.900986   0.652742
# ...           ...       ...       ...       ...            ...        ...
# 1625     0.425370  0.001897  0.367381  1.225766       0.870555   0.652742
# 1626     0.425370  0.001897  1.032574  1.225766       0.870555   0.652742
# 1627     0.445095  0.001897  1.417347  1.071699       0.870555   1.532000
# 1628     0.445095  0.001897  1.417347  1.225766       0.900986   0.652742
# 1629     0.445095  0.001897  0.682585  0.726410       0.900986   0.652742
#
#       IsActiveMember  EstimatedSalary
# 0           1.021081         1.593410
# 1           0.979354         0.395656
# 2           1.021081         0.434576
# 3           0.979354         0.223872
# 4           1.021081         1.249134
# ...              ...              ...
# 1625        1.021081         1.118152
# 1626        1.021081         1.764603
# 1627        1.021081         0.291057
# 1628        0.979354         1.688942
# 1629        0.979354         0.814682
#
# [1630 rows x 8 columns]

# %%
df = df[(Z <3).all(axis=1)]

# %%
df.shape
# Out:
# (1588, 12)

# %%
df['Loan'].value_counts()
# Out:
# Loan
# 0    1258
# 1     330
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Geography'] = le.fit_transform(df['Geography'])
df.head()
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\4143213740.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Geography'] = le.fit_transform(df['Geography'])
#     CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 6      1152351          358          2  Female  37.0       8  143542.36
# 7      1152352          359          0  Female  35.0       6  128747.69
# 8      1152353          363          2  Female  41.0       6  146098.43
# 9      1152354          365          1    Male  35.0       0  127760.07
# 10     1152355          367          2    Male  38.0       6   93608.28
#
#     NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Loan
# 6               3          1               0        141959.11     1
# 7               1          1               0        146955.71     1
# 8               3          1               0        100615.14     1
# 9               1          1               0         81537.85     1
# 10              1          1               0        168816.73     1

# %%
df['Gender'] = le.fit_transform(df['Gender'])
df.head()
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_15104\1049255870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = le.fit_transform(df['Gender'])
#     CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 6      1152351          358          2       0  37.0       8  143542.36
# 7      1152352          359          0       0  35.0       6  128747.69
# 8      1152353          363          2       0  41.0       6  146098.43
# 9      1152354          365          1       1  35.0       0  127760.07
# 10     1152355          367          2       1  38.0       6   93608.28
#
#     NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Loan
# 6               3          1               0        141959.11     1
# 7               1          1               0        146955.71     1
# 8               3          1               0        100615.14     1
# 9               1          1               0         81537.85     1
# 10              1          1               0        168816.73     1

# %%
df = df.drop(['CustomerId'], axis=1)

# %%
df.shape
# Out:
# (1588, 11)

# %% [markdown]
# ### 2.c.	Summarize relationships among variables (5 marks)
# i.	Plot relevant categorical plots. Find out which are the variables most correlated or appear to be in causation with Target? Do you want to exclude some variables from the model based on this analysis? What other actions will you take?
#
#
# ii.	Plot all independent variables with the target & find out the relationship? Perform the Relevant Tests to find out if the Independent variables are associated with the Target Variable.
#
#  Hint: based on your observations you may want to transform features or create additional features.

# %%
plt.figure(figsize=(20,10))
sns.pairplot(df)
plt.show()
# Out:
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
cor = df.corr()
cor
# Out:
#                  CreditScore  Geography    Gender       Age    Tenure  \
# CreditScore         1.000000   0.018152  0.014231 -0.030433 -0.002697
# Geography           0.018152   1.000000 -0.003818  0.037846  0.019544
# Gender              0.014231  -0.003818  1.000000 -0.017296  0.008636
# Age                -0.030433   0.037846 -0.017296  1.000000 -0.022415
# Tenure             -0.002697   0.019544  0.008636 -0.022415  1.000000
# Balance            -0.000603   0.062941  0.005280  0.062108 -0.032482
# NumOfProducts       0.006113   0.019459  0.004523 -0.015200  0.044641
# HasCrCard          -0.057235   0.027256  0.023981 -0.018497 -0.011906
# IsActiveMember      0.039458   0.013609  0.008345  0.022168 -0.051406
# EstimatedSalary    -0.019415  -0.016578 -0.029687 -0.018752  0.001286
# Loan               -0.097109   0.025081 -0.101126  0.345714 -0.022287
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CreditScore     -0.000603       0.006113  -0.057235        0.039458
# Geography        0.062941       0.019459   0.027256        0.013609
# Gender           0.005280       0.004523   0.023981        0.008345
# Age              0.062108      -0.015200  -0.018497        0.022168
# Tenure          -0.032482       0.044641  -0.011906       -0.051406
# Balance          1.000000      -0.320845  -0.021262       -0.031151
# NumOfProducts   -0.320845       1.000000   0.036014        0.001177
# HasCrCard       -0.021262       0.036014   1.000000       -0.024185
# IsActiveMember  -0.031151       0.001177  -0.024185        1.000000
# EstimatedSalary  0.004785       0.026258  -0.018614       -0.027980
# Loan             0.098170      -0.102967  -0.027383       -0.148017
#
#                  EstimatedSalary      Loan
# CreditScore            -0.019415 -0.097109
# Geography              -0.016578  0.025081
# Gender                 -0.029687 -0.101126
# Age                    -0.018752  0.345714
# Tenure                  0.001286 -0.022287
# Balance                 0.004785  0.098170
# NumOfProducts           0.026258 -0.102967
# HasCrCard              -0.018614 -0.027383
# IsActiveMember         -0.027980 -0.148017
# EstimatedSalary         1.000000  0.052774
# Loan                    0.052774  1.000000

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(df.corr(), annot = True )
top, bottom = ax.get_ylim()
ax.set_ylim(top + 1.5, bottom - 1.5 )
plt.show()

# %% [markdown]
# ### 2.d.	Split dataset into train and test (70:30) (5 marks)
# i.	Are both train and test representative of the overall data? How would you ascertain this statistically?

# %%
X = df.drop(['Loan'], axis=1)
y=df['Loan']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7, stratify=y,test_size=0.3, random_state=42)

# %% [markdown]
# ### 2.e.	Fit a base model and explain the reason of selecting that model. Please write your key observations (5 marks)
#
# i.	What is the overall Accuracy? Please comment on whether it is good or not.
#
# ii.	What is Precision, Recall and F1 Score and what will be the optimization objective keeping in mind the problem statement.
#
# iii. Which variables are significant?
#
# iv.	What is Cohen’s Kappa Value and what inference do you make from the model
#
# v.	Which other key model output parameters do you want to look at?

# %%
from sklearn.tree import DecisionTreeClassifier

df_default = DecisionTreeClassifier()
df_default.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

y_pred_default = df_default.predict(X_test)

print(classification_report(y_test, y_pred_default))
print(accuracy_score(y_test, y_pred_default))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       378
#            1       0.50      0.54      0.51        99
#
#     accuracy                           0.79       477
#    macro avg       0.69      0.70      0.69       477
# weighted avg       0.80      0.79      0.79       477
#
# 0.790356394129979

# %%
feature_importances = pd.DataFrame(df_default.feature_importances_,
                                   index = X_train.columns,
                                   columns=['importance']).sort_values('importance')

# %%
feature_importances
# Out:
#                  importance
# Gender             0.013678
# HasCrCard          0.017011
# Geography          0.030965
# IsActiveMember     0.047289
# NumOfProducts      0.100260
# Tenure             0.108539
# Balance            0.158620
# EstimatedSalary    0.166052
# CreditScore        0.175236
# Age                0.182352

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(y_test, y_pred_default)
# Out:
# 0.38113031293787947

# %% [markdown]
# # Section -C (Marks - 40)

# %% [markdown]
# ### 3.a.	How do you improve overall efficiency of the model? Write clearly the changes that you will make before re-fitting the model. Fit the final model. (20 marks)
# Please feel free to have any number of iterations to get to the final answer. Marks are awarded based on the quality of final model you are able to achieve.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_dtc = {'min_samples_split': np.arange(2,10), 'min_samples_leaf': np.arange(0.05, .2 ), 'max_leaf_nodes': np.arange(2,30) } 
cv_dtc = GridSearchCV(estimator = df_default, param_grid = param_dtc, cv = 3, refit = 'precision', n_jobs=-1)

# %%
cv_dtc.fit(X,y)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'min_samples_leaf': array([0.05]),
#                          'min_samples_split': array([2, 3, 4, 5, 6, 7, 8, 9])},
#              refit='predict')

# %%
print("Best Score : " + str(cv_dtc.best_score_))
print("Best Parameters : " + str(cv_dtc.best_params_))
# Out:
# Best Score : 0.8148779588876603
# Best Parameters : {'min_samples_leaf': 0.05, 'min_samples_split': 2}

# %%
y_pred = cv_dtc.predict(X_test)

print("Accuracy ", cv_dtc_score(X_test, y_test))

# %% [markdown]
# ### 3.b.	Summarize as follows (20 marks)
#
# i.	Summarize the overall fit of the model and list down the measures to prove that it is a good model
#
# ii.	Write down a business interpretation/explanation of the model – which variables are affecting the target the most and explain the relationship. Feel free to use charts or graphs to explain.
#
# iii.	What changes from the base model had the most effect on model performance?
#
# iv.	What are the key risks to your results and interpretation?
