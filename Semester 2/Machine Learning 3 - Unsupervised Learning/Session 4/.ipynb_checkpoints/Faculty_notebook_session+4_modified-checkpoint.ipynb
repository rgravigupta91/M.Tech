# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="faculty.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=6px>
#                   <b> Faculty Notebook <br> (Session 4) </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
#
# 1. **[Recommendation System](#System)**
# 2. **[Types of recommendation System](#System1)**
#
# 3. **[Popularity based recommendation system](#System3)**
#
# 4. **[Content-based recommendation system](#System4)**
#
# 5. **[Collaborative recommendation system](#System5)**

# %% [markdown]
# <a id="System"> </a>
# ## Recommendation System

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Recommender systems aim to predict users’ interests and recommend product items that quite likely are interesting for them.<br>
#                         <br>Recommendation system will help businesses improve their shopper's,user experience or on website,youtub,amazon and result in better customer acquisition and retention.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="System1"> </a>
# ## Types of recommendation system

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>There are majorly six types of recommender systems which work primarily in the Media and Entertainment industry::<br><br>
#                         1. Popularity based recommendation system<br>
#                         2. Content-based recommendation system<br>
#                         3. Collaborative recommendation system<br>
#                         4. Matrix factorization recommendation system<br>
#                         5. Association Rule<br>
#                         6. Hybrid-recommendation system <br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="System3"> </a>
#
# ###  Popularity based recommendation system

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>This model is not actually personalized - it simply recommends to a user the most popular items that the user has not previously consumed i.e. even though you know the behaviour of the user you cannot recommend items accordingly.<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:200%">
#                 <font color="#21618C">
#                     <b>Read the movie_dataset.csv.<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### Import the basic libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Reading the movie_dataset.csv

# %%
data=pd.read_csv('D:/millan_sir/Dataset_SVD/book.csv')

# %%
data.head(2)
# Out:
#    Unnamed: 0  userID        ISBN  bookRating             bookTitle  \
# 0           0  276725  034545104X           0  Flesh Tones: A Novel
# 1           1    2313  034545104X           5  Flesh Tones: A Novel
#
#    totalRatingCount               Location
# 0                60      tyler, texas, usa
# 1                60  cincinnati, ohio, usa

# %% [markdown]
# ### Popularity Based Recommendation System

# %%
# Top 10 books interms of average rating 

pd.DataFrame(data.groupby('bookTitle')['bookRating'].mean().sort_values(ascending=False))
# Out:
#                                                   bookRating
# bookTitle
# Das Parfum: Die Geschichte Eines Morders           10.000000
# Matilda                                             8.000000
# Harry Potter and the Chamber of Secrets (Book 2)    6.720588
# MÃ?Â¶rder ohne Gesicht.                             6.500000
# Ender's Game (Ender Wiggins Saga (Paperback))       5.857143
# ...                                                      ...
# The Law of Love                                     1.000000
# Legend                                              0.777778
# Hannibal                                            0.000000
# Childhood's End                                     0.000000
# The Return                                          0.000000
#
# [198 rows x 1 columns]

# %%
# some books may get high average rating , but it is not reviewed by many users
# Hence we need to consider the review count also for better recommendation
popularity_table=data.groupby('bookTitle').agg({'bookRating':'mean','totalRatingCount':'count'})

# %%
popularity_table.head()
# Out:
#                                                     bookRating  \
# bookTitle
# 1st to Die: A Novel                                   3.415301
# A Child Called \It\": One Child's Courage to Su...    4.139738
# A Cold Heart: An Alex Delaware Novel                  3.112903
# A Kiss of Shadows (Meredith Gentry Novels (Pape...    4.013333
# A Man in Full                                         2.111111
#
#                                                     totalRatingCount
# bookTitle
# 1st to Die: A Novel                                              366
# A Child Called \It\": One Child's Courage to Su...               229
# A Cold Heart: An Alex Delaware Novel                              62
# A Kiss of Shadows (Meredith Gentry Novels (Pape...                75
# A Man in Full                                                     90

# %%
#popularity_table['rating_per_count']=popularity_table['bookRating']/popularity_table['totalRatingCount']
#popularity_table.sort_values('rating_per_count',ascending=False)

# %%
#consider the books for recommendation only if it has 100 rating counts
top_popularity_table=popularity_table[popularity_table['totalRatingCount']>100]

# %%
#Top 10 books to recommed based on popularity
top_popularity_table.sort_values('bookRating',ascending=False).head(10)
# Out:
#                                                     bookRating  \
# bookTitle
# Harry Potter and the Chamber of Secrets (Book 2)      6.720588
# Harry Potter and the Order of the Phoenix (Book 5)    5.565693
# Harry Potter and the Sorcerer's Stone (Harry Po...    4.850598
# To Kill a Mockingbird                                 4.761329
# The Da Vinci Code                                     4.699329
# The Lovely Bones: A Novel                             4.622624
# Fahrenheit 451                                        4.615120
# A Wrinkle In Time                                     4.569444
# Girl with a Pearl Earring                             4.319648
# The Notebook                                          4.307692
#
#                                                     totalRatingCount
# bookTitle
# Harry Potter and the Chamber of Secrets (Book 2)                 136
# Harry Potter and the Order of the Phoenix (Book 5)               274
# Harry Potter and the Sorcerer's Stone (Harry Po...               502
# To Kill a Mockingbird                                            331
# The Da Vinci Code                                                745
# The Lovely Bones: A Novel                                       1052
# Fahrenheit 451                                                   291
# A Wrinkle In Time                                                144
# Girl with a Pearl Earring                                        341
# The Notebook                                                     104

# %%
#Top 10 books to recommed based on popularity
top_popularity_table.sort_values('totalRatingCount',ascending=False).head(10)
# Out:
#                                                     bookRating  \
# bookTitle
# Wild Animus                                           1.055014
# The Lovely Bones: A Novel                             4.622624
# The Da Vinci Code                                     4.699329
# A Painted House                                       3.260870
# The Summons                                           3.375421
# The Pilot's Wife : A Novel                            3.598814
# Harry Potter and the Sorcerer's Stone (Harry Po...    4.850598
# The Joy Luck Club                                     3.105033
# She's Come Undone (Oprah's Book Club)                 3.580569
# She's Come Undone (Oprah's Book Club (Paperback))     3.481572
#
#                                                     totalRatingCount
# bookTitle
# Wild Animus                                                     1436
# The Lovely Bones: A Novel                                       1052
# The Da Vinci Code                                                745
# A Painted House                                                  736
# The Summons                                                      594
# The Pilot's Wife : A Novel                                       506
# Harry Potter and the Sorcerer's Stone (Harry Po...               502
# The Joy Luck Club                                                457
# She's Come Undone (Oprah's Book Club)                            422
# She's Come Undone (Oprah's Book Club (Paperback))                407

# %% [markdown]
# ##### So, I hope you now have enough idea about the popularity based recommendation system lets get into Content-based recommendation system

# %% [markdown]
# <a id="System4"> </a>
#
# ###  Content-based recommendation system

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>This method uses only information about the description and attributes of the items users has previously consumed to model user's preferences. In other words, these algorithms try to recommend items that are similar to those that a user liked in the past (or is examining in the present). In particular, various candidate items are compared with items previously rated by the user and the best-matching items are recommended..<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:200%">
#                 <font color="#21618C">
#                     <b>Read the movie_metadata.csv dataset.<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#### A simple Content Based Recommendation System

# %%
data1=pd.read_csv('D:/millan_sir/Dataset_SVD/movie_metadata.csv')

# %%
data1.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
#
# [2 rows x 28 columns]

# %%
data1.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
genres=data1['genres'].str.split('|',expand=True)
genres=genres.iloc[:,0:3]

# %%
genres
# Out:
#                 0          1         2
# 0          Action  Adventure   Fantasy
# 1          Action  Adventure   Fantasy
# 2          Action  Adventure  Thriller
# 3          Action   Thriller      None
# 4     Documentary       None      None
# ...           ...        ...       ...
# 5038       Comedy      Drama      None
# 5039        Crime      Drama   Mystery
# 5040        Drama     Horror  Thriller
# 5041       Comedy      Drama   Romance
# 5042  Documentary       None      None
#
# [5043 rows x 3 columns]

# %%
genres=genres.fillna('Others')

# %%
genres.columns=['genre1','genre2','genre3']
genres.head(10)
# Out:
#         genre1     genre2    genre3
# 0       Action  Adventure   Fantasy
# 1       Action  Adventure   Fantasy
# 2       Action  Adventure  Thriller
# 3       Action   Thriller    Others
# 4  Documentary     Others    Others
# 5       Action  Adventure    Sci-Fi
# 6       Action  Adventure   Romance
# 7    Adventure  Animation    Comedy
# 8       Action  Adventure    Sci-Fi
# 9    Adventure     Family   Fantasy

# %%
data1=pd.concat([data1,genres],axis=1)

# %%
data1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   content_rating       budget  title_year  actor_2_facebook_likes imdb_score  \
# 0          PG-13  237000000.0      2009.0                   936.0        7.9
# 1          PG-13  300000000.0      2007.0                  5000.0        7.1
# 2          PG-13  245000000.0      2015.0                   393.0        6.8
# 3          PG-13  250000000.0      2012.0                 23000.0        8.5
# 4            NaN          NaN         NaN                    12.0        7.1
#
#    aspect_ratio movie_facebook_likes       genre1     genre2    genre3
# 0          1.78                33000       Action  Adventure   Fantasy
# 1          2.35                    0       Action  Adventure   Fantasy
# 2          2.35                85000       Action  Adventure  Thriller
# 3          2.35               164000       Action   Thriller    Others
# 4           NaN                    0  Documentary     Others    Others
#
# [5 rows x 31 columns]

# %%
#movie_feat=['movie_title','genre1','genre2','genre3','language','content_rating',
           #'imdb_score','num_user_for_reviews','movie_facebook_likes']

# %%
movie_feat=['movie_title','genre1','genre2','genre3','content_rating','imdb_score']

# %%
data2=data1[movie_feat]

# %%
data2.head(2)
# Out:
#                                  movie_title  genre1     genre2   genre3  \
# 0                                    Avatar   Action  Adventure  Fantasy
# 1  Pirates of the Caribbean: At World's End   Action  Adventure  Fantasy
#
#   content_rating  imdb_score
# 0          PG-13         7.9
# 1          PG-13         7.1

# %%
data2=data2.drop_duplicates()

# %%
data2.index=data2['movie_title']

# %%
data2=data2.drop('movie_title',axis=1)

# %%
data2.head(2)
# Out:
#                                            genre1     genre2   genre3  \
# movie_title
# Avatar                                     Action  Adventure  Fantasy
# Pirates of the Caribbean: At World's End   Action  Adventure  Fantasy
#
#                                           content_rating  imdb_score
# movie_title
# Avatar                                             PG-13         7.9
# Pirates of the Caribbean: At World's End           PG-13         7.1

# %%
data3=pd.get_dummies(data2)

# %%
data3.head()
# Out:
#                                                     imdb_score  genre1_Action  \
# movie_title
# Avatar                                                     7.9              1
# Pirates of the Caribbean: At World's End                   7.1              1
# Spectre                                                    6.8              1
# The Dark Knight Rises                                      8.5              1
# Star Wars: Episode VII - The Force Awakens     ...         7.1              0
#
#                                                     genre1_Adventure  \
# movie_title
# Avatar                                                             0
# Pirates of the Caribbean: At World's End                           0
# Spectre                                                            0
# The Dark Knight Rises                                              0
# Star Wars: Episode VII - The Force Awakens     ...                 0
#
#                                                     genre1_Animation  \
# movie_title
# Avatar                                                             0
# Pirates of the Caribbean: At World's End                           0
# Spectre                                                            0
# The Dark Knight Rises                                              0
# Star Wars: Episode VII - The Force Awakens     ...                 0
#
#                                                     genre1_Biography  \
# movie_title
# Avatar                                                             0
# Pirates of the Caribbean: At World's End                           0
# Spectre                                                            0
# The Dark Knight Rises                                              0
# Star Wars: Episode VII - The Force Awakens     ...                 0
#
#                                                     genre1_Comedy  \
# movie_title
# Avatar                                                          0
# Pirates of the Caribbean: At World's End                        0
# Spectre                                                         0
# The Dark Knight Rises                                           0
# Star Wars: Episode VII - The Force Awakens     ...              0
#
#                                                     genre1_Crime  \
# movie_title
# Avatar                                                         0
# Pirates of the Caribbean: At World's End                       0
# Spectre                                                        0
# The Dark Knight Rises                                          0
# Star Wars: Episode VII - The Force Awakens     ...             0
#
#                                                     genre1_Documentary  \
# movie_title
# Avatar                                                               0
# Pirates of the Caribbean: At World's End                             0
# Spectre                                                              0
# The Dark Knight Rises                                                0
# Star Wars: Episode VII - The Force Awakens     ...                   1
#
#                                                     genre1_Drama  \
# movie_title
# Avatar                                                         0
# Pirates of the Caribbean: At World's End                       0
# Spectre                                                        0
# The Dark Knight Rises                                          0
# Star Wars: Episode VII - The Force Awakens     ...             0
#
#                                                     genre1_Family  ...  \
# movie_title                                                        ...
# Avatar                                                          0  ...
# Pirates of the Caribbean: At World's End                        0  ...
# Spectre                                                         0  ...
# The Dark Knight Rises                                           0  ...
# Star Wars: Episode VII - The Force Awakens     ...              0  ...
#
#                                                     content_rating_Passed  \
# movie_title
# Avatar                                                                  0
# Pirates of the Caribbean: At World's End                                0
# Spectre                                                                 0
# The Dark Knight Rises                                                   0
# Star Wars: Episode VII - The Force Awakens     ...                      0
#
#                                                     content_rating_R  \
# movie_title
# Avatar                                                             0
# Pirates of the Caribbean: At World's End                           0
# Spectre                                                            0
# The Dark Knight Rises                                              0
# Star Wars: Episode VII - The Force Awakens     ...                 0
#
#                                                     content_rating_TV-14  \
# movie_title
# Avatar                                                                 0
# Pirates of the Caribbean: At World's End                               0
# Spectre                                                                0
# The Dark Knight Rises                                                  0
# Star Wars: Episode VII - The Force Awakens     ...                     0
#
#                                                     content_rating_TV-G  \
# movie_title
# Avatar                                                                0
# Pirates of the Caribbean: At World's End                              0
# Spectre                                                               0
# The Dark Knight Rises                                                 0
# Star Wars: Episode VII - The Force Awakens     ...                    0
#
#                                                     content_rating_TV-MA  \
# movie_title
# Avatar                                                                 0
# Pirates of the Caribbean: At World's End                               0
# Spectre                                                                0
# The Dark Knight Rises                                                  0
# Star Wars: Episode VII - The Force Awakens     ...                     0
#
#                                                     content_rating_TV-PG  \
# movie_title
# Avatar                                                                 0
# Pirates of the Caribbean: At World's End                               0
# Spectre                                                                0
# The Dark Knight Rises                                                  0
# Star Wars: Episode VII - The Force Awakens     ...                     0
#
#                                                     content_rating_TV-Y  \
# movie_title
# Avatar                                                                0
# Pirates of the Caribbean: At World's End                              0
# Spectre                                                               0
# The Dark Knight Rises                                                 0
# Star Wars: Episode VII - The Force Awakens     ...                    0
#
#                                                     content_rating_TV-Y7  \
# movie_title
# Avatar                                                                 0
# Pirates of the Caribbean: At World's End                               0
# Spectre                                                                0
# The Dark Knight Rises                                                  0
# Star Wars: Episode VII - The Force Awakens     ...                     0
#
#                                                     content_rating_Unrated  \
# movie_title
# Avatar                                                                   0
# Pirates of the Caribbean: At World's End                                 0
# Spectre                                                                  0
# The Dark Knight Rises                                                    0
# Star Wars: Episode VII - The Force Awakens     ...                       0
#
#                                                     content_rating_X
# movie_title
# Avatar                                                             0
# Pirates of the Caribbean: At World's End                           0
# Spectre                                                            0
# The Dark Knight Rises                                              0
# Star Wars: Episode VII - The Force Awakens     ...                 0
#
# [5 rows x 89 columns]

# %%
data3=data3.dropna()

# %%
from sklearn.neighbors import NearestNeighbors

# %%
rec_model = NearestNeighbors(metric = 'cosine')
rec_model.fit(data3)
# Out:
# NearestNeighbors(metric='cosine')

# %%
query_movie_index=200
dist, ind = rec_model.kneighbors(data3.iloc[query_movie_index, :].values.reshape(1, -1), n_neighbors = 6)
# Out:
# C:\Users\Saranya A\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
list(data3.index[ind[0]])[1:]
# Out:
# ['Harry Potter and the Half-Blood Prince\xa0',
#  'Harry Potter and the Chamber of Secrets\xa0',
#  "Pete's Dragon\xa0",
#  'Harry Potter and the Prisoner of Azkaban\xa0',
#  'The Princess Bride\xa0']

# %%
for i in range(0, len(dist[0])):
    if i == 0:
        print('Top 5 Recommendations for the user who watched the movie :',data3.index[query_movie_index])
    else:
        print(i, data3.index[ind[0][i]])
# Out:
# Top 5 Recommendations for the user who watched the movie : Harry Potter and the Sorcerer's Stone
# 1 Harry Potter and the Half-Blood Prince
# 2 Harry Potter and the Chamber of Secrets
# 3 Pete's Dragon
# 4 Harry Potter and the Prisoner of Azkaban
# 5 The Princess Bride

# %%
data3.loc[data3.index[ind][0]]
# Out:
# C:\Users\Saranya A\AppData\Local\Temp\ipykernel_10352\4135941718.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   data3.loc[data3.index[ind][0]]
#                                            imdb_score  genre1_Action  \
# movie_title
# Harry Potter and the Sorcerer's Stone             7.5              0
# Harry Potter and the Half-Blood Prince            7.5              0
# Harry Potter and the Chamber of Secrets           7.4              0
# Pete's Dragon                                     7.3              0
# Harry Potter and the Prisoner of Azkaban          7.8              0
# The Princess Bride                                8.1              0
#
#                                            genre1_Adventure  genre1_Animation  \
# movie_title
# Harry Potter and the Sorcerer's Stone                     1                 0
# Harry Potter and the Half-Blood Prince                    1                 0
# Harry Potter and the Chamber of Secrets                   1                 0
# Pete's Dragon                                             1                 0
# Harry Potter and the Prisoner of Azkaban                  1                 0
# The Princess Bride                                        1                 0
#
#                                            genre1_Biography  genre1_Comedy  \
# movie_title
# Harry Potter and the Sorcerer's Stone                     0              0
# Harry Potter and the Half-Blood Prince                    0              0
# Harry Potter and the Chamber of Secrets                   0              0
# Pete's Dragon                                             0              0
# Harry Potter and the Prisoner of Azkaban                  0              0
# The Princess Bride                                        0              0
#
#                                            genre1_Crime  genre1_Documentary  \
# movie_title
# Harry Potter and the Sorcerer's Stone                 0                   0
# Harry Potter and the Half-Blood Prince                0                   0
# Harry Potter and the Chamber of Secrets               0                   0
# Pete's Dragon                                         0                   0
# Harry Potter and the Prisoner of Azkaban              0                   0
# The Princess Bride                                    0                   0
#
#                                            genre1_Drama  genre1_Family  ...  \
# movie_title                                                             ...
# Harry Potter and the Sorcerer's Stone                 0              0  ...
# Harry Potter and the Half-Blood Prince                0              0  ...
# Harry Potter and the Chamber of Secrets               0              0  ...
# Pete's Dragon                                         0              0  ...
# Harry Potter and the Prisoner of Azkaban              0              0  ...
# The Princess Bride                                    0              0  ...
#
#                                            content_rating_Passed  \
# movie_title
# Harry Potter and the Sorcerer's Stone                          0
# Harry Potter and the Half-Blood Prince                         0
# Harry Potter and the Chamber of Secrets                        0
# Pete's Dragon                                                  0
# Harry Potter and the Prisoner of Azkaban                       0
# The Princess Bride                                             0
#
#                                            content_rating_R  \
# movie_title
# Harry Potter and the Sorcerer's Stone                     0
# Harry Potter and the Half-Blood Prince                    0
# Harry Potter and the Chamber of Secrets                   0
# Pete's Dragon                                             0
# Harry Potter and the Prisoner of Azkaban                  0
# The Princess Bride                                        0
#
#                                            content_rating_TV-14  \
# movie_title
# Harry Potter and the Sorcerer's Stone                         0
# Harry Potter and the Half-Blood Prince                        0
# Harry Potter and the Chamber of Secrets                       0
# Pete's Dragon                                                 0
# Harry Potter and the Prisoner of Azkaban                      0
# The Princess Bride                                            0
#
#                                            content_rating_TV-G  \
# movie_title
# Harry Potter and the Sorcerer's Stone                        0
# Harry Potter and the Half-Blood Prince                       0
# Harry Potter and the Chamber of Secrets                      0
# Pete's Dragon                                                0
# Harry Potter and the Prisoner of Azkaban                     0
# The Princess Bride                                           0
#
#                                            content_rating_TV-MA  \
# movie_title
# Harry Potter and the Sorcerer's Stone                         0
# Harry Potter and the Half-Blood Prince                        0
# Harry Potter and the Chamber of Secrets                       0
# Pete's Dragon                                                 0
# Harry Potter and the Prisoner of Azkaban                      0
# The Princess Bride                                            0
#
#                                            content_rating_TV-PG  \
# movie_title
# Harry Potter and the Sorcerer's Stone                         0
# Harry Potter and the Half-Blood Prince                        0
# Harry Potter and the Chamber of Secrets                       0
# Pete's Dragon                                                 0
# Harry Potter and the Prisoner of Azkaban                      0
# The Princess Bride                                            0
#
#                                            content_rating_TV-Y  \
# movie_title
# Harry Potter and the Sorcerer's Stone                        0
# Harry Potter and the Half-Blood Prince                       0
# Harry Potter and the Chamber of Secrets                      0
# Pete's Dragon                                                0
# Harry Potter and the Prisoner of Azkaban                     0
# The Princess Bride                                           0
#
#                                            content_rating_TV-Y7  \
# movie_title
# Harry Potter and the Sorcerer's Stone                         0
# Harry Potter and the Half-Blood Prince                        0
# Harry Potter and the Chamber of Secrets                       0
# Pete's Dragon                                                 0
# Harry Potter and the Prisoner of Azkaban                      0
# The Princess Bride                                            0
#
#                                            content_rating_Unrated  \
# movie_title
# Harry Potter and the Sorcerer's Stone                           0
# Harry Potter and the Half-Blood Prince                          0
# Harry Potter and the Chamber of Secrets                         0
# Pete's Dragon                                                   0
# Harry Potter and the Prisoner of Azkaban                        0
# The Princess Bride                                              0
#
#                                            content_rating_X
# movie_title
# Harry Potter and the Sorcerer's Stone                     0
# Harry Potter and the Half-Blood Prince                    0
# Harry Potter and the Chamber of Secrets                   0
# Pete's Dragon                                             0
# Harry Potter and the Prisoner of Azkaban                  0
# The Princess Bride                                        0
#
# [6 rows x 89 columns]

# %% [markdown]
# <a id="System5"> </a>
#
# ###  Collaborative recommendation system

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="note.png">
#             </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Collaborative filtering is currently one of the most frequently used approaches and usually provides better results than content-based recommendations. Some examples of this are found in the recommendation systems of Youtube, Netflix, and Spotify.
#
#
# Collaborative Filtering, which is also known as User-User Filtering. As hinted by its alternate name, this technique uses other users to recommend items to the input user. It attempts to find users that have similar preferences and opinions as the input and then recommends items that they have liked to the input. There are several methods of finding similar users (Even some making use of Machine Learning), and the one we will be using here is going to be based on the Pearson Correlation Function.
#
# <br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:200%">
#                 <font color="#21618C">
#                     <b>Read the ratings.csv dataset.<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split, cross_validate
from surprise import KNNWithMeans,SVDpp
from surprise import accuracy

# %%
ratings = pd.read_csv('D:/millan_sir/Dataset_SVD/ratings.csv')
reader = Reader(rating_scale=(1, 5))

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182

# %%
rating_data = Dataset.load_from_df(ratings[['userId','movieId','rating']],reader)
[trainset, testset] = train_test_split(rating_data, test_size=.15,shuffle=True)

# %%
trainsetfull = rating_data.build_full_trainset()
print('Number of users: ', trainsetfull.n_users, '\n')
print('Number of items: ', trainsetfull.n_items, '\n')
# Out:
# Number of users:  671
#
# Number of items:  9066

# %%
# my_k = 15
# my_min_k = 5
# my_sim_option = {'name':'pearson', 'user_based':False}

# %%
# algo = KNNWithMeans(k = my_k, min_k = my_min_k, sim_options = my_sim_option, verbose = True)

# %%
# results = cross_validate(
#     algo = algo, data = rating_data, measures=['RMSE'], 
#     cv=5, return_train_measures=True
#     )
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
# print(results['test_rmse'].mean())

# %%
alg=SVDpp()
alg.fit(trainsetfull)

# %%
#algo.fit(trainsetfull)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
alg.predict( 40, 10, 4)
# Out:
# Prediction(uid=40, iid=10, r_ui=4, est=4.096402187918934, details={'was_impossible': False})

# %%
item_id=ratings['movieId'].unique()
item_id9=ratings.loc[ratings['userId']==9,'movieId']
item_id_pred=np.setdiff1d(item_id,item_id9)

# %%
item_id9.head()
# Out:
# 699     1
# 700    17
# 701    26
# 702    36
# 703    47
# Name: movieId, dtype: int64

# %%
item_id
# Out:
# array([  31, 1029, 1061, ...,  129, 4736, 6425], dtype=int64)

# %%
item_id_pred
# Out:
# array([     1,      2,      3, ..., 162542, 162672, 163949], dtype=int64)

# %%
testset=[[40,iid,4] for iid in item_id_pred]
pred=alg.test(testset)
pred
# Out:
# [Prediction(uid=40, iid=2, r_ui=4, est=3.923161767098452, details={'was_impossible': False}),
#  Prediction(uid=40, iid=3, r_ui=4, est=3.7607123746867854, details={'was_impossible': False}),
#  Prediction(uid=40, iid=4, r_ui=4, est=3.1133925747896187, details={'was_impossible': False}),
#  Prediction(uid=40, iid=5, r_ui=4, est=3.757272146662598, details={'was_impossible': False}),
#  Prediction(uid=40, iid=6, r_ui=4, est=4.337424407365627, details={'was_impossible': False}),
#  Prediction(uid=40, iid=7, r_ui=4, est=3.732798556835744, details={'was_impossible': False}),
#  Prediction(uid=40, iid=8, r_ui=4, est=4.0206982620863645, details={'was_impossible': False}),
#  Prediction(uid=40, iid=9, r_ui=4, est=3.396403559493625, details={'was_impossible': False}),
#  Prediction(uid=40, iid=10, r_ui=4, est=4.096402187918934, details={'was_impossible': False}),
#  Prediction(uid=40, iid=11, r_ui=4, est=4.23498407252782, details={'was_impossible': False}),
#  Prediction(uid=40, iid=12, r_ui=4, est=3.5527760986830863, details={'was_impossible': False}),
#  Prediction(uid=40, iid=13, r_ui=4, est=4.272600410612027, details={'was_impossible': False}),
#  Prediction(uid=40, iid=14, r_ui=4, est=4.105705147105642, details={'was_impossible': False}),
#  Prediction(uid=40, iid=15, r_ui=4, est=3.2865446477458127, details={'was_impossible': False}),
#  Prediction(uid=40, iid=16, r_ui=4, est=4.32919925230258, details={'was_impossible': False}),
#  Prediction(uid=40, iid=18, r_ui=4, est=4.025350687338292, details={'was_impossible': False}),
#  Prediction(uid=40, iid=19, r_ui=4, est=3.3582122032462514, details={'was_impossible': False}),
#  Prediction(uid=40, iid=20, r_ui=4, est=3.416709599430007, details={'was_impossible': False}),
#  Prediction(uid=40, iid=21, r_ui=4, est=4.238535418729889, details={'was_impossible': False}),
#  Prediction(uid=40, iid=22, r_ui=4, est=3.7153531004655167, details={'was_impossible': False}),
#  Prediction(uid=40, iid=23, r_ui=4, est=3.502159212713503, details={'was_impossible': False}),
#  Prediction(uid=40, iid=24, r_ui=4, est=3.8505860984503997, details={'was_impossible': False}),
#  Prediction(uid=40, iid=25, r_ui=4, est=4.29566155135606, details={'was_impossible': False}),
#  Prediction(uid=40, iid=27, r_ui=4, est=3.9703030751128026, details={'was_impossible': False}),
#  Prediction(uid=40, iid=28, r_ui=4, est=4.660250101518428, details={'was_impossible': False}),
#  Prediction(uid=40, iid=29, r_ui=4, est=4.620988849759478, details={'was_impossible': False}),
#  Prediction(uid=40, iid=30, r_ui=4, est=4.322231353623573, details={'was_impossible': False}),
#  Prediction(uid=40, iid=31, r_ui=4, est=3.8422070439715186, details={'was_impossible': False}),
#  Prediction(uid=40, iid=32, r_ui=4, est=4.232159653495306, details={'was_impossible': False}),
#  Prediction(uid=40, iid=34, r_ui=4, est=4.123393316313817, details={'was_impossible': False}),
#  Prediction(uid=40, iid=35, r_ui=4, est=4.073266339421669, details={'was_impossible': False}),
#  Prediction(uid=40, iid=37, r_ui=4, est=3.7416444669562363, details={'was_impossible': False}),
#  Prediction(uid=40, iid=38, r_ui=4, est=3.837875452414397, details={'was_impossible': False}),
#  Prediction(uid=40, iid=39, r_ui=4, est=4.103889507418794, details={'was_impossible': False}),
#  Prediction(uid=40, iid=40, r_ui=4, est=4.2578047120007, details={'was_impossible': False}),
#  Prediction(uid=40, iid=41, r_ui=4, est=4.609584794044169, details={'was_impossible': False}),
#  Prediction(uid=40, iid=42, r_ui=4, est=3.505693673659989, details={'was_impossible': False}),
#  Prediction(uid=40, iid=43, r_ui=4, est=4.167198787040776, details={'was_impossible': False}),
#  Prediction(uid=40, iid=44, r_ui=4, est=3.345036383937328, details={'was_impossible': False}),
#  Prediction(uid=40, iid=45, r_ui=4, est=3.968505936591535, details={'was_impossible': False}),
#  Prediction(uid=40, iid=46, r_ui=4, est=3.723364295198081, details={'was_impossible': False}),
#  Prediction(uid=40, iid=48, r_ui=4, est=3.4222631963437364, details={'was_impossible': False}),
#  Prediction(uid=40, iid=49, r_ui=4, est=4.128277328036418, details={'was_impossible': False}),
#  Prediction(uid=40, iid=50, r_ui=4, est=4.844383990455433, details={'was_impossible': False}),
#  Prediction(uid=40, iid=52, r_ui=4, est=4.103399644115666, details={'was_impossible': False}),
#  Prediction(uid=40, iid=53, r_ui=4, est=4.291856924779731, details={'was_impossible': False}),
#  Prediction(uid=40, iid=54, r_ui=4, est=4.103767231195327, details={'was_impossible': False}),
#  Prediction(uid=40, iid=55, r_ui=4, est=4.1217903229049835, details={'was_impossible': False}),
#  Prediction(uid=40, iid=57, r_ui=4, est=3.86807732077544, details={'was_impossible': False}),
#  Prediction(uid=40, iid=58, r_ui=4, est=4.458614090927805, details={'was_impossible': False}),
#  Prediction(uid=40, iid=59, r_ui=4, est=4.1055633795696655, details={'was_impossible': False}),
#  Prediction(uid=40, iid=60, r_ui=4, est=3.5291475575034323, details={'was_impossible': False}),
#  Prediction(uid=40, iid=61, r_ui=4, est=3.995348470809654, details={'was_impossible': False}),
#  Prediction(uid=40, iid=62, r_ui=4, est=4.432753815494751, details={'was_impossible': False}),
#  Prediction(uid=40, iid=63, r_ui=4, est=3.628584939909067, details={'was_impossible': False}),
#  Prediction(uid=40, iid=64, r_ui=4, est=3.4154709076804566, details={'was_impossible': False}),
#  Prediction(uid=40, iid=65, r_ui=4, est=2.839056753257525, details={'was_impossible': False}),
#  Prediction(uid=40, iid=66, r_ui=4, est=3.5119468429439893, details={'was_impossible': False}),
#  Prediction(uid=40, iid=68, r_ui=4, est=4.111901391763232, details={'was_impossible': False}),
#  Prediction(uid=40, iid=69, r_ui=4, est=4.4304339587310855, details={'was_impossible': False}),
#  Prediction(uid=40, iid=70, r_ui=4, est=3.8681217359071547, details={'was_impossible': False}),
#  Prediction(uid=40, iid=71, r_ui=4, est=3.4794020052958046, details={'was_impossible': False}),
#  Prediction(uid=40, iid=72, r_ui=4, est=4.173920014376844, details={'was_impossible': False}),
#  Prediction(uid=40, iid=73, r_ui=4, est=4.525808619393039, details={'was_impossible': False}),
#  Prediction(uid=40, iid=74, r_ui=4, est=3.596505072098243, details={'was_impossible': False}),
#  Prediction(uid=40, iid=76, r_ui=4, est=3.8152634913607226, details={'was_impossible': False}),
#  Prediction(uid=40, iid=77, r_ui=4, est=4.118264946339437, details={'was_impossible': False}),
#  Prediction(uid=40, iid=78, r_ui=4, est=3.8836697838463285, details={'was_impossible': False}),
#  Prediction(uid=40, iid=79, r_ui=4, est=3.2198526797244456, details={'was_impossible': False}),
#  Prediction(uid=40, iid=80, r_ui=4, est=4.604439818429925, details={'was_impossible': False}),
#  Prediction(uid=40, iid=81, r_ui=4, est=3.9964491059714526, details={'was_impossible': False}),
#  Prediction(uid=40, iid=82, r_ui=4, est=4.1300817091382775, details={'was_impossible': False}),
#  Prediction(uid=40, iid=83, r_ui=4, est=3.8938873526273, details={'was_impossible': False}),
#  Prediction(uid=40, iid=84, r_ui=4, est=4.275627529369773, details={'was_impossible': False}),
#  Prediction(uid=40, iid=85, r_ui=4, est=4.542387098898422, details={'was_impossible': False}),
#  Prediction(uid=40, iid=86, r_ui=4, est=4.183963812596973, details={'was_impossible': False}),
#  Prediction(uid=40, iid=87, r_ui=4, est=3.5688588616811328, details={'was_impossible': False}),
#  Prediction(uid=40, iid=88, r_ui=4, est=3.5026709528908198, details={'was_impossible': False}),
#  Prediction(uid=40, iid=89, r_ui=4, est=3.8935950207716035, details={'was_impossible': False}),
#  Prediction(uid=40, iid=92, r_ui=4, est=4.0737305641313, details={'was_impossible': False}),
#  Prediction(uid=40, iid=93, r_ui=4, est=3.2464467238030843, details={'was_impossible': False}),
#  Prediction(uid=40, iid=94, r_ui=4, est=4.036974608510301, details={'was_impossible': False}),
#  Prediction(uid=40, iid=95, r_ui=4, est=3.759136843897138, details={'was_impossible': False}),
#  Prediction(uid=40, iid=96, r_ui=4, est=3.7381383135927866, details={'was_impossible': False}),
#  Prediction(uid=40, iid=97, r_ui=4, est=4.628033882849002, details={'was_impossible': False}),
#  Prediction(uid=40, iid=98, r_ui=4, est=4.022263055586804, details={'was_impossible': False}),
#  Prediction(uid=40, iid=99, r_ui=4, est=3.872859965359989, details={'was_impossible': False}),
#  Prediction(uid=40, iid=100, r_ui=4, est=3.7851270421405596, details={'was_impossible': False}),
#  Prediction(uid=40, iid=101, r_ui=4, est=4.424205106374631, details={'was_impossible': False}),
#  Prediction(uid=40, iid=102, r_ui=4, est=3.3936469658778705, details={'was_impossible': False}),
#  Prediction(uid=40, iid=103, r_ui=4, est=4.170683915482875, details={'was_impossible': False}),
#  Prediction(uid=40, iid=104, r_ui=4, est=3.846538138741797, details={'was_impossible': False}),
#  Prediction(uid=40, iid=105, r_ui=4, est=3.6783168705230302, details={'was_impossible': False}),
#  Prediction(uid=40, iid=107, r_ui=4, est=3.9766115397922825, details={'was_impossible': False}),
#  Prediction(uid=40, iid=108, r_ui=4, est=4.079398263334119, details={'was_impossible': False}),
#  Prediction(uid=40, iid=110, r_ui=4, est=4.542122116655352, details={'was_impossible': False}),
#  Prediction(uid=40, iid=111, r_ui=4, est=4.596650942402453, details={'was_impossible': False}),
#  Prediction(uid=40, iid=112, r_ui=4, est=3.983595954789235, details={'was_impossible': False}),
#  Prediction(uid=40, iid=113, r_ui=4, est=3.8816392661303474, details={'was_impossible': False}),
#  Prediction(uid=40, iid=114, r_ui=4, est=4.022516288081878, details={'was_impossible': False}),
#  Prediction(uid=40, iid=116, r_ui=4, est=4.610320333823472, details={'was_impossible': False}),
#  Prediction(uid=40, iid=117, r_ui=4, est=3.8523984992855893, details={'was_impossible': False}),
#  Prediction(uid=40, iid=118, r_ui=4, est=3.844042125665488, details={'was_impossible': False}),
#  Prediction(uid=40, iid=119, r_ui=4, est=4.0686978106159986, details={'was_impossible': False}),
#  Prediction(uid=40, iid=121, r_ui=4, est=4.1754568136035335, details={'was_impossible': False}),
#  Prediction(uid=40, iid=122, r_ui=4, est=3.7074764237623103, details={'was_impossible': False}),
#  Prediction(uid=40, iid=123, r_ui=4, est=4.393921605126628, details={'was_impossible': False}),
#  Prediction(uid=40, iid=124, r_ui=4, est=3.9014813348680795, details={'was_impossible': False}),
#  Prediction(uid=40, iid=125, r_ui=4, est=4.105874957978217, details={'was_impossible': False}),
#  Prediction(uid=40, iid=126, r_ui=4, est=3.3913112329248754, details={'was_impossible': False}),
#  Prediction(uid=40, iid=129, r_ui=4, est=4.038674920625113, details={'was_impossible': False}),
#  Prediction(uid=40, iid=130, r_ui=4, est=4.078742530048918, details={'was_impossible': False}),
#  Prediction(uid=40, iid=131, r_ui=4, est=3.985034195976985, details={'was_impossible': False}),
#  Prediction(uid=40, iid=132, r_ui=4, est=3.5040425862544, details={'was_impossible': False}),
#  Prediction(uid=40, iid=135, r_ui=4, est=3.4619473284863624, details={'was_impossible': False}),
#  Prediction(uid=40, iid=137, r_ui=4, est=3.8003184694004823, details={'was_impossible': False}),
#  Prediction(uid=40, iid=140, r_ui=4, est=3.9625847359605806, details={'was_impossible': False}),
#  Prediction(uid=40, iid=141, r_ui=4, est=3.9697338984357926, details={'was_impossible': False}),
#  Prediction(uid=40, iid=144, r_ui=4, est=3.9065694052569953, details={'was_impossible': False}),
#  Prediction(uid=40, iid=145, r_ui=4, est=3.990774059192773, details={'was_impossible': False}),
#  Prediction(uid=40, iid=146, r_ui=4, est=4.350491063049869, details={'was_impossible': False}),
#  Prediction(uid=40, iid=147, r_ui=4, est=4.206959056160957, details={'was_impossible': False}),
#  Prediction(uid=40, iid=148, r_ui=4, est=4.168238266865264, details={'was_impossible': False}),
#  Prediction(uid=40, iid=149, r_ui=4, est=4.329986504455885, details={'was_impossible': False}),
#  Prediction(uid=40, iid=150, r_ui=4, est=4.297123049399131, details={'was_impossible': False}),
#  Prediction(uid=40, iid=151, r_ui=4, est=4.220312826770807, details={'was_impossible': False}),
#  Prediction(uid=40, iid=152, r_ui=4, est=4.166792529577539, details={'was_impossible': False}),
#  Prediction(uid=40, iid=153, r_ui=4, est=3.53645839512546, details={'was_impossible': False}),
#  Prediction(uid=40, iid=154, r_ui=4, est=4.244344890171262, details={'was_impossible': False}),
#  Prediction(uid=40, iid=155, r_ui=4, est=3.91217399861564, details={'was_impossible': False}),
#  Prediction(uid=40, iid=156, r_ui=4, est=4.42373838103937, details={'was_impossible': False}),
#  Prediction(uid=40, iid=157, r_ui=4, est=3.5437823708994958, details={'was_impossible': False}),
#  Prediction(uid=40, iid=158, r_ui=4, est=3.233262286037067, details={'was_impossible': False}),
#  Prediction(uid=40, iid=159, r_ui=4, est=4.453662154121597, details={'was_impossible': False}),
#  Prediction(uid=40, iid=160, r_ui=4, est=3.07215343941417, details={'was_impossible': False}),
#  Prediction(uid=40, iid=161, r_ui=4, est=4.241935807595458, details={'was_impossible': False}),
#  Prediction(uid=40, iid=162, r_ui=4, est=4.688805651853597, details={'was_impossible': False}),
#  Prediction(uid=40, iid=163, r_ui=4, est=4.111564551475227, details={'was_impossible': False}),
#  Prediction(uid=40, iid=164, r_ui=4, est=4.072243309719999, details={'was_impossible': False}),
#  Prediction(uid=40, iid=165, r_ui=4, est=4.008763082828399, details={'was_impossible': False}),
#  Prediction(uid=40, iid=166, r_ui=4, est=3.877789810046315, details={'was_impossible': False}),
#  Prediction(uid=40, iid=167, r_ui=4, est=4.217092852170255, details={'was_impossible': False}),
#  Prediction(uid=40, iid=168, r_ui=4, est=3.77272023322627, details={'was_impossible': False}),
#  Prediction(uid=40, iid=169, r_ui=4, est=3.5109016157156785, details={'was_impossible': False}),
#  Prediction(uid=40, iid=170, r_ui=4, est=3.876519974297598, details={'was_impossible': False}),
#  Prediction(uid=40, iid=171, r_ui=4, est=4.423555230802697, details={'was_impossible': False}),
#  Prediction(uid=40, iid=172, r_ui=4, est=3.341656740085728, details={'was_impossible': False}),
#  Prediction(uid=40, iid=173, r_ui=4, est=3.22166540512603, details={'was_impossible': False}),
#  Prediction(uid=40, iid=174, r_ui=4, est=3.5602065113594596, details={'was_impossible': False}),
#  Prediction(uid=40, iid=175, r_ui=4, est=4.554109736000793, details={'was_impossible': False}),
#  Prediction(uid=40, iid=176, r_ui=4, est=4.328585148763869, details={'was_impossible': False}),
#  Prediction(uid=40, iid=177, r_ui=4, est=3.650897421060497, details={'was_impossible': False}),
#  Prediction(uid=40, iid=178, r_ui=4, est=4.5077689118504125, details={'was_impossible': False}),
#  Prediction(uid=40, iid=179, r_ui=4, est=3.789944408484558, details={'was_impossible': False}),
#  Prediction(uid=40, iid=180, r_ui=4, est=3.92997113254954, details={'was_impossible': False}),
#  Prediction(uid=40, iid=181, r_ui=4, est=2.5519259579743125, details={'was_impossible': False}),
#  Prediction(uid=40, iid=183, r_ui=4, est=4.1946596564590175, details={'was_impossible': False}),
#  Prediction(uid=40, iid=184, r_ui=4, est=4.247710166466467, details={'was_impossible': False}),
#  Prediction(uid=40, iid=185, r_ui=4, est=3.582961468490897, details={'was_impossible': False}),
#  Prediction(uid=40, iid=186, r_ui=4, est=3.4267663426475163, details={'was_impossible': False}),
#  Prediction(uid=40, iid=187, r_ui=4, est=3.9871606466293428, details={'was_impossible': False}),
#  Prediction(uid=40, iid=188, r_ui=4, est=3.534255982860148, details={'was_impossible': False}),
#  Prediction(uid=40, iid=189, r_ui=4, est=4.108609627760502, details={'was_impossible': False}),
#  Prediction(uid=40, iid=190, r_ui=4, est=4.1732548371420926, details={'was_impossible': False}),
#  Prediction(uid=40, iid=191, r_ui=4, est=3.874594092918276, details={'was_impossible': False}),
#  Prediction(uid=40, iid=193, r_ui=4, est=2.9052618978104943, details={'was_impossible': False}),
#  Prediction(uid=40, iid=194, r_ui=4, est=4.653846885586556, details={'was_impossible': False}),
#  Prediction(uid=40, iid=195, r_ui=4, est=3.824230612549149, details={'was_impossible': False}),
#  Prediction(uid=40, iid=196, r_ui=4, est=3.466456317501037, details={'was_impossible': False}),
#  Prediction(uid=40, iid=198, r_ui=4, est=3.9882382133064174, details={'was_impossible': False}),
#  Prediction(uid=40, iid=199, r_ui=4, est=3.925085955586945, details={'was_impossible': False}),
#  Prediction(uid=40, iid=200, r_ui=4, est=4.11929183061874, details={'was_impossible': False}),
#  Prediction(uid=40, iid=201, r_ui=4, est=4.094491071841187, details={'was_impossible': False}),
#  Prediction(uid=40, iid=202, r_ui=4, est=3.9137063547225512, details={'was_impossible': False}),
#  Prediction(uid=40, iid=203, r_ui=4, est=3.9333619109825575, details={'was_impossible': False}),
#  Prediction(uid=40, iid=204, r_ui=4, est=3.6997679939661876, details={'was_impossible': False}),
#  Prediction(uid=40, iid=205, r_ui=4, est=4.141695209674595, details={'was_impossible': False}),
#  Prediction(uid=40, iid=206, r_ui=4, est=4.169433259980347, details={'was_impossible': False}),
#  Prediction(uid=40, iid=207, r_ui=4, est=4.0214428184535, details={'was_impossible': False}),
#  Prediction(uid=40, iid=208, r_ui=4, est=3.3796197459472053, details={'was_impossible': False}),
#  Prediction(uid=40, iid=209, r_ui=4, est=3.703146728941504, details={'was_impossible': False}),
#  Prediction(uid=40, iid=211, r_ui=4, est=4.050279640567822, details={'was_impossible': False}),
#  Prediction(uid=40, iid=213, r_ui=4, est=4.554727036605059, details={'was_impossible': False}),
#  Prediction(uid=40, iid=214, r_ui=4, est=4.161581366723557, details={'was_impossible': False}),
#  Prediction(uid=40, iid=215, r_ui=4, est=4.300161337376548, details={'was_impossible': False}),
#  Prediction(uid=40, iid=216, r_ui=4, est=3.6920799872599535, details={'was_impossible': False}),
#  Prediction(uid=40, iid=217, r_ui=4, est=3.643533084625557, details={'was_impossible': False}),
#  Prediction(uid=40, iid=218, r_ui=4, est=4.066480476297971, details={'was_impossible': False}),
#  Prediction(uid=40, iid=219, r_ui=4, est=4.298959433949651, details={'was_impossible': False}),
#  Prediction(uid=40, iid=220, r_ui=4, est=3.904059666927574, details={'was_impossible': False}),
#  Prediction(uid=40, iid=222, r_ui=4, est=4.526537534483514, details={'was_impossible': False}),
#  Prediction(uid=40, iid=223, r_ui=4, est=4.319109067901918, details={'was_impossible': False}),
#  Prediction(uid=40, iid=224, r_ui=4, est=4.307701442656497, details={'was_impossible': False}),
#  Prediction(uid=40, iid=225, r_ui=4, est=3.6955545219814567, details={'was_impossible': False}),
#  Prediction(uid=40, iid=227, r_ui=4, est=3.710935726849554, details={'was_impossible': False}),
#  Prediction(uid=40, iid=228, r_ui=4, est=3.792738358223634, details={'was_impossible': False}),
#  Prediction(uid=40, iid=229, r_ui=4, est=4.506343701497973, details={'was_impossible': False}),
#  Prediction(uid=40, iid=230, r_ui=4, est=4.261358660029146, details={'was_impossible': False}),
#  Prediction(uid=40, iid=231, r_ui=4, est=3.6614131014984905, details={'was_impossible': False}),
#  Prediction(uid=40, iid=232, r_ui=4, est=4.725408976864737, details={'was_impossible': False}),
#  Prediction(uid=40, iid=233, r_ui=4, est=4.51719662063821, details={'was_impossible': False}),
#  Prediction(uid=40, iid=234, r_ui=4, est=3.612168641253279, details={'was_impossible': False}),
#  Prediction(uid=40, iid=235, r_ui=4, est=4.245983509253996, details={'was_impossible': False}),
#  Prediction(uid=40, iid=236, r_ui=4, est=3.7754114327315436, details={'was_impossible': False}),
#  Prediction(uid=40, iid=237, r_ui=4, est=3.9767859838431106, details={'was_impossible': False}),
#  Prediction(uid=40, iid=238, r_ui=4, est=3.7993322319320195, details={'was_impossible': False}),
#  Prediction(uid=40, iid=239, r_ui=4, est=3.5708791006125717, details={'was_impossible': False}),
#  Prediction(uid=40, iid=240, r_ui=4, est=3.795875506612069, details={'was_impossible': False}),
#  Prediction(uid=40, iid=241, r_ui=4, est=3.8928505610978963, details={'was_impossible': False}),
#  Prediction(uid=40, iid=242, r_ui=4, est=4.196488826846031, details={'was_impossible': False}),
#  Prediction(uid=40, iid=243, r_ui=4, est=3.9932816452112956, details={'was_impossible': False}),
#  Prediction(uid=40, iid=244, r_ui=4, est=4.027943139991929, details={'was_impossible': False}),
#  Prediction(uid=40, iid=245, r_ui=4, est=4.019285435063251, details={'was_impossible': False}),
#  Prediction(uid=40, iid=246, r_ui=4, est=4.638887098112533, details={'was_impossible': False}),
#  Prediction(uid=40, iid=247, r_ui=4, est=4.17050128776296, details={'was_impossible': False}),
#  Prediction(uid=40, iid=248, r_ui=4, est=3.6861218678269267, details={'was_impossible': False}),
#  Prediction(uid=40, iid=249, r_ui=4, est=3.908657868570094, details={'was_impossible': False}),
#  Prediction(uid=40, iid=250, r_ui=4, est=3.917551023319074, details={'was_impossible': False}),
#  Prediction(uid=40, iid=251, r_ui=4, est=3.986686253828437, details={'was_impossible': False}),
#  Prediction(uid=40, iid=252, r_ui=4, est=3.585412484619248, details={'was_impossible': False}),
#  Prediction(uid=40, iid=253, r_ui=4, est=3.9168806589902045, details={'was_impossible': False}),
#  Prediction(uid=40, iid=254, r_ui=4, est=3.907367068781653, details={'was_impossible': False}),
#  Prediction(uid=40, iid=255, r_ui=4, est=3.629875334919802, details={'was_impossible': False}),
#  Prediction(uid=40, iid=256, r_ui=4, est=3.3608491205851814, details={'was_impossible': False}),
#  Prediction(uid=40, iid=257, r_ui=4, est=4.131844521983182, details={'was_impossible': False}),
#  Prediction(uid=40, iid=258, r_ui=4, est=3.3380357943629466, details={'was_impossible': False}),
#  Prediction(uid=40, iid=259, r_ui=4, est=4.086206021542897, details={'was_impossible': False}),
#  Prediction(uid=40, iid=260, r_ui=4, est=4.617129600459431, details={'was_impossible': False}),
#  Prediction(uid=40, iid=261, r_ui=4, est=4.153794935904885, details={'was_impossible': False}),
#  Prediction(uid=40, iid=262, r_ui=4, est=4.220777705050312, details={'was_impossible': False}),
#  Prediction(uid=40, iid=263, r_ui=4, est=3.9365097940269953, details={'was_impossible': False}),
#  Prediction(uid=40, iid=264, r_ui=4, est=4.226608682756175, details={'was_impossible': False}),
#  Prediction(uid=40, iid=265, r_ui=4, est=4.48258573566062, details={'was_impossible': False}),
#  Prediction(uid=40, iid=266, r_ui=4, est=4.073657363085443, details={'was_impossible': False}),
#  Prediction(uid=40, iid=267, r_ui=4, est=3.468498326651227, details={'was_impossible': False}),
#  Prediction(uid=40, iid=268, r_ui=4, est=4.389471496019793, details={'was_impossible': False}),
#  Prediction(uid=40, iid=269, r_ui=4, est=4.064331751543307, details={'was_impossible': False}),
#  Prediction(uid=40, iid=270, r_ui=4, est=3.737808881574109, details={'was_impossible': False}),
#  Prediction(uid=40, iid=271, r_ui=4, est=3.944142891857607, details={'was_impossible': False}),
#  Prediction(uid=40, iid=272, r_ui=4, est=4.505177589474215, details={'was_impossible': False}),
#  Prediction(uid=40, iid=273, r_ui=4, est=3.598955506606704, details={'was_impossible': False}),
#  Prediction(uid=40, iid=274, r_ui=4, est=3.769046764971769, details={'was_impossible': False}),
#  Prediction(uid=40, iid=275, r_ui=4, est=3.6894738098789097, details={'was_impossible': False}),
#  Prediction(uid=40, iid=276, r_ui=4, est=3.3989784147912165, details={'was_impossible': False}),
#  Prediction(uid=40, iid=277, r_ui=4, est=3.8152129380297444, details={'was_impossible': False}),
#  Prediction(uid=40, iid=278, r_ui=4, est=3.7093758656728553, details={'was_impossible': False}),
#  Prediction(uid=40, iid=279, r_ui=4, est=3.917980210857233, details={'was_impossible': False}),
#  Prediction(uid=40, iid=280, r_ui=4, est=4.449156924819646, details={'was_impossible': False}),
#  Prediction(uid=40, iid=281, r_ui=4, est=4.440618179306024, details={'was_impossible': False}),
#  Prediction(uid=40, iid=282, r_ui=4, est=3.880313985512201, details={'was_impossible': False}),
#  Prediction(uid=40, iid=283, r_ui=4, est=4.022257906569169, details={'was_impossible': False}),
#  Prediction(uid=40, iid=285, r_ui=4, est=4.126158422185919, details={'was_impossible': False}),
#  Prediction(uid=40, iid=287, r_ui=4, est=3.9266743612157917, details={'was_impossible': False}),
#  Prediction(uid=40, iid=288, r_ui=4, est=4.076152839972532, details={'was_impossible': False}),
#  Prediction(uid=40, iid=289, r_ui=4, est=3.9902229940377745, details={'was_impossible': False}),
#  Prediction(uid=40, iid=290, r_ui=4, est=4.3823723870966536, details={'was_impossible': False}),
#  Prediction(uid=40, iid=291, r_ui=4, est=3.1638900574727242, details={'was_impossible': False}),
#  Prediction(uid=40, iid=292, r_ui=4, est=3.9748906761799514, details={'was_impossible': False}),
#  Prediction(uid=40, iid=293, r_ui=4, est=4.546828441247055, details={'was_impossible': False}),
#  Prediction(uid=40, iid=294, r_ui=4, est=3.9159097908277967, details={'was_impossible': False}),
#  Prediction(uid=40, iid=295, r_ui=4, est=3.762462797307784, details={'was_impossible': False}),
#  Prediction(uid=40, iid=296, r_ui=4, est=4.736539553327892, details={'was_impossible': False}),
#  Prediction(uid=40, iid=299, r_ui=4, est=4.183797708244548, details={'was_impossible': False}),
#  Prediction(uid=40, iid=300, r_ui=4, est=4.302611434968985, details={'was_impossible': False}),
#  Prediction(uid=40, iid=301, r_ui=4, est=4.279236459406237, details={'was_impossible': False}),
#  Prediction(uid=40, iid=302, r_ui=4, est=4.074342328632803, details={'was_impossible': False}),
#  Prediction(uid=40, iid=303, r_ui=4, est=3.8568520350638296, details={'was_impossible': False}),
#  Prediction(uid=40, iid=304, r_ui=4, est=4.026961975169932, details={'was_impossible': False}),
#  Prediction(uid=40, iid=305, r_ui=4, est=3.4529167752993972, details={'was_impossible': False}),
#  Prediction(uid=40, iid=306, r_ui=4, est=4.619329313424034, details={'was_impossible': False}),
#  Prediction(uid=40, iid=307, r_ui=4, est=4.643796690030505, details={'was_impossible': False}),
#  Prediction(uid=40, iid=308, r_ui=4, est=4.569437505143586, details={'was_impossible': False}),
#  Prediction(uid=40, iid=309, r_ui=4, est=4.47506081076505, details={'was_impossible': False}),
#  Prediction(uid=40, iid=312, r_ui=4, est=4.090851309151974, details={'was_impossible': False}),
#  Prediction(uid=40, iid=313, r_ui=4, est=3.5314063519266776, details={'was_impossible': False}),
#  Prediction(uid=40, iid=314, r_ui=4, est=4.361493579239123, details={'was_impossible': False}),
#  Prediction(uid=40, iid=315, r_ui=4, est=3.6192374789910984, details={'was_impossible': False}),
#  Prediction(uid=40, iid=316, r_ui=4, est=3.8699703014269757, details={'was_impossible': False}),
#  Prediction(uid=40, iid=317, r_ui=4, est=3.4394037024514312, details={'was_impossible': False}),
#  Prediction(uid=40, iid=319, r_ui=4, est=4.32171004478016, details={'was_impossible': False}),
#  Prediction(uid=40, iid=320, r_ui=4, est=3.797803919737625, details={'was_impossible': False}),
#  Prediction(uid=40, iid=321, r_ui=4, est=4.2100864277454795, details={'was_impossible': False}),
#  Prediction(uid=40, iid=322, r_ui=4, est=4.247157310175323, details={'was_impossible': False}),
#  Prediction(uid=40, iid=324, r_ui=4, est=3.966762324927572, details={'was_impossible': False}),
#  Prediction(uid=40, iid=325, r_ui=4, est=3.9296677437322938, details={'was_impossible': False}),
#  Prediction(uid=40, iid=326, r_ui=4, est=4.462275134342179, details={'was_impossible': False}),
#  Prediction(uid=40, iid=327, r_ui=4, est=3.1556949518354194, details={'was_impossible': False}),
#  Prediction(uid=40, iid=328, r_ui=4, est=4.12037549335886, details={'was_impossible': False}),
#  Prediction(uid=40, iid=329, r_ui=4, est=3.856275815577264, details={'was_impossible': False}),
#  Prediction(uid=40, iid=330, r_ui=4, est=3.6264433317466573, details={'was_impossible': False}),
#  Prediction(uid=40, iid=331, r_ui=4, est=3.759972579745032, details={'was_impossible': False}),
#  Prediction(uid=40, iid=332, r_ui=4, est=3.773258166030682, details={'was_impossible': False}),
#  Prediction(uid=40, iid=333, r_ui=4, est=4.06546911968104, details={'was_impossible': False}),
#  Prediction(uid=40, iid=334, r_ui=4, est=3.670618803746573, details={'was_impossible': False}),
#  Prediction(uid=40, iid=335, r_ui=4, est=3.991522029888943, details={'was_impossible': False}),
#  Prediction(uid=40, iid=336, r_ui=4, est=3.9519424935964422, details={'was_impossible': False}),
#  Prediction(uid=40, iid=337, r_ui=4, est=4.313277688312575, details={'was_impossible': False}),
#  Prediction(uid=40, iid=338, r_ui=4, est=3.561883078415055, details={'was_impossible': False}),
#  Prediction(uid=40, iid=339, r_ui=4, est=3.9772444402074827, details={'was_impossible': False}),
#  Prediction(uid=40, iid=340, r_ui=4, est=3.738228028455616, details={'was_impossible': False}),
#  Prediction(uid=40, iid=341, r_ui=4, est=4.180173237955445, details={'was_impossible': False}),
#  Prediction(uid=40, iid=342, r_ui=4, est=4.054487970288634, details={'was_impossible': False}),
#  Prediction(uid=40, iid=343, r_ui=4, est=3.87133721719143, details={'was_impossible': False}),
#  Prediction(uid=40, iid=344, r_ui=4, est=3.5406471914534237, details={'was_impossible': False}),
#  Prediction(uid=40, iid=345, r_ui=4, est=4.24699941087979, details={'was_impossible': False}),
#  Prediction(uid=40, iid=346, r_ui=4, est=3.88864046309476, details={'was_impossible': False}),
#  Prediction(uid=40, iid=347, r_ui=4, est=4.292668600165285, details={'was_impossible': False}),
#  Prediction(uid=40, iid=348, r_ui=4, est=4.384805118317303, details={'was_impossible': False}),
#  Prediction(uid=40, iid=349, r_ui=4, est=4.337138089437195, details={'was_impossible': False}),
#  Prediction(uid=40, iid=350, r_ui=4, est=3.7852912117823805, details={'was_impossible': False}),
#  Prediction(uid=40, iid=351, r_ui=4, est=3.850350357977015, details={'was_impossible': False}),
#  Prediction(uid=40, iid=352, r_ui=4, est=3.8888879319346, details={'was_impossible': False}),
#  Prediction(uid=40, iid=353, r_ui=4, est=4.154291858322493, details={'was_impossible': False}),
#  Prediction(uid=40, iid=354, r_ui=4, est=4.030284242914772, details={'was_impossible': False}),
#  Prediction(uid=40, iid=355, r_ui=4, est=2.9668082562046556, details={'was_impossible': False}),
#  Prediction(uid=40, iid=356, r_ui=4, est=4.483206630273502, details={'was_impossible': False}),
#  Prediction(uid=40, iid=357, r_ui=4, est=4.140359897481219, details={'was_impossible': False}),
#  Prediction(uid=40, iid=358, r_ui=4, est=3.513567963969865, details={'was_impossible': False}),
#  Prediction(uid=40, iid=360, r_ui=4, est=3.5377602222979934, details={'was_impossible': False}),
#  Prediction(uid=40, iid=361, r_ui=4, est=4.079589207418092, details={'was_impossible': False}),
#  Prediction(uid=40, iid=362, r_ui=4, est=3.8961070634824293, details={'was_impossible': False}),
#  Prediction(uid=40, iid=363, r_ui=4, est=4.457219195131736, details={'was_impossible': False}),
#  Prediction(uid=40, iid=364, r_ui=4, est=4.289727341745489, details={'was_impossible': False}),
#  Prediction(uid=40, iid=365, r_ui=4, est=3.7386343629611334, details={'was_impossible': False}),
#  Prediction(uid=40, iid=366, r_ui=4, est=3.729378421110998, details={'was_impossible': False}),
#  Prediction(uid=40, iid=367, r_ui=4, est=3.6418240121480077, details={'was_impossible': False}),
#  Prediction(uid=40, iid=368, r_ui=4, est=4.224660576142363, details={'was_impossible': False}),
#  Prediction(uid=40, iid=369, r_ui=4, est=3.8295877753605914, details={'was_impossible': False}),
#  Prediction(uid=40, iid=370, r_ui=4, est=3.73341372526574, details={'was_impossible': False}),
#  Prediction(uid=40, iid=371, r_ui=4, est=3.91262679302632, details={'was_impossible': False}),
#  Prediction(uid=40, iid=372, r_ui=4, est=3.5683310851207413, details={'was_impossible': False}),
#  Prediction(uid=40, iid=373, r_ui=4, est=4.645705682981148, details={'was_impossible': False}),
#  Prediction(uid=40, iid=374, r_ui=4, est=2.934173564762726, details={'was_impossible': False}),
#  Prediction(uid=40, iid=375, r_ui=4, est=4.18327319326141, details={'was_impossible': False}),
#  Prediction(uid=40, iid=376, r_ui=4, est=3.8242768819902895, details={'was_impossible': False}),
#  Prediction(uid=40, iid=377, r_ui=4, est=4.154855113158454, details={'was_impossible': False}),
#  Prediction(uid=40, iid=378, r_ui=4, est=3.842980768507991, details={'was_impossible': False}),
#  Prediction(uid=40, iid=379, r_ui=4, est=3.869817030967952, details={'was_impossible': False}),
#  Prediction(uid=40, iid=380, r_ui=4, est=4.069372469712562, details={'was_impossible': False}),
#  Prediction(uid=40, iid=381, r_ui=4, est=3.724974846628457, details={'was_impossible': False}),
#  Prediction(uid=40, iid=382, r_ui=4, est=3.702035052081808, details={'was_impossible': False}),
#  Prediction(uid=40, iid=383, r_ui=4, est=3.722192812144499, details={'was_impossible': False}),
#  Prediction(uid=40, iid=384, r_ui=4, est=3.965134966587691, details={'was_impossible': False}),
#  Prediction(uid=40, iid=387, r_ui=4, est=4.052688223415665, details={'was_impossible': False}),
#  Prediction(uid=40, iid=388, r_ui=4, est=4.183148991806002, details={'was_impossible': False}),
#  Prediction(uid=40, iid=389, r_ui=4, est=4.197823565699284, details={'was_impossible': False}),
#  Prediction(uid=40, iid=390, r_ui=4, est=4.453261781055064, details={'was_impossible': False}),
#  Prediction(uid=40, iid=391, r_ui=4, est=3.9844015979986187, details={'was_impossible': False}),
#  Prediction(uid=40, iid=392, r_ui=4, est=3.9409427937235537, details={'was_impossible': False}),
#  Prediction(uid=40, iid=393, r_ui=4, est=3.452047925168845, details={'was_impossible': False}),
#  Prediction(uid=40, iid=401, r_ui=4, est=4.162888370885723, details={'was_impossible': False}),
#  Prediction(uid=40, iid=405, r_ui=4, est=3.213170557864342, details={'was_impossible': False}),
#  Prediction(uid=40, iid=407, r_ui=4, est=3.6233865281071274, details={'was_impossible': False}),
#  Prediction(uid=40, iid=408, r_ui=4, est=3.995323982149127, details={'was_impossible': False}),
#  Prediction(uid=40, iid=409, r_ui=4, est=4.035326964356919, details={'was_impossible': False}),
#  Prediction(uid=40, iid=410, r_ui=4, est=3.5370805698272316, details={'was_impossible': False}),
#  Prediction(uid=40, iid=412, r_ui=4, est=4.135522602558855, details={'was_impossible': False}),
#  Prediction(uid=40, iid=413, r_ui=4, est=3.190903490967187, details={'was_impossible': False}),
#  Prediction(uid=40, iid=414, r_ui=4, est=3.700620489010431, details={'was_impossible': False}),
#  Prediction(uid=40, iid=415, r_ui=4, est=3.515501913648908, details={'was_impossible': False}),
#  Prediction(uid=40, iid=416, r_ui=4, est=3.8510694941618167, details={'was_impossible': False}),
#  Prediction(uid=40, iid=417, r_ui=4, est=4.1036142601001755, details={'was_impossible': False}),
#  Prediction(uid=40, iid=418, r_ui=4, est=3.9407164760552433, details={'was_impossible': False}),
#  Prediction(uid=40, iid=419, r_ui=4, est=3.4131300560746456, details={'was_impossible': False}),
#  Prediction(uid=40, iid=420, r_ui=4, est=3.318658078619669, details={'was_impossible': False}),
#  Prediction(uid=40, iid=421, r_ui=4, est=3.725806494223255, details={'was_impossible': False}),
#  Prediction(uid=40, iid=422, r_ui=4, est=3.929912047463486, details={'was_impossible': False}),
#  Prediction(uid=40, iid=423, r_ui=4, est=3.9789430505206007, details={'was_impossible': False}),
#  Prediction(uid=40, iid=424, r_ui=4, est=4.078135167031461, details={'was_impossible': False}),
#  Prediction(uid=40, iid=425, r_ui=4, est=4.046752227489869, details={'was_impossible': False}),
#  Prediction(uid=40, iid=426, r_ui=4, est=3.6993968948677547, details={'was_impossible': False}),
#  Prediction(uid=40, iid=427, r_ui=4, est=3.241131087293982, details={'was_impossible': False}),
#  Prediction(uid=40, iid=428, r_ui=4, est=4.3315640255704695, details={'was_impossible': False}),
#  Prediction(uid=40, iid=429, r_ui=4, est=3.7565768427572186, details={'was_impossible': False}),
#  Prediction(uid=40, iid=431, r_ui=4, est=4.238029204680168, details={'was_impossible': False}),
#  Prediction(uid=40, iid=432, r_ui=4, est=3.245732327697938, details={'was_impossible': False}),
#  Prediction(uid=40, iid=433, r_ui=4, est=3.694121358390329, details={'was_impossible': False}),
#  Prediction(uid=40, iid=434, r_ui=4, est=3.683602664192021, details={'was_impossible': False}),
#  Prediction(uid=40, iid=435, r_ui=4, est=3.2117831753504067, details={'was_impossible': False}),
#  Prediction(uid=40, iid=436, r_ui=4, est=3.6251818764167596, details={'was_impossible': False}),
#  Prediction(uid=40, iid=437, r_ui=4, est=3.9660063173374036, details={'was_impossible': False}),
#  Prediction(uid=40, iid=438, r_ui=4, est=4.012601125777597, details={'was_impossible': False}),
#  Prediction(uid=40, iid=439, r_ui=4, est=3.7657414353884757, details={'was_impossible': False}),
#  Prediction(uid=40, iid=440, r_ui=4, est=4.176048035769846, details={'was_impossible': False}),
#  Prediction(uid=40, iid=441, r_ui=4, est=4.120176111388396, details={'was_impossible': False}),
#  Prediction(uid=40, iid=442, r_ui=4, est=3.852100780295326, details={'was_impossible': False}),
#  Prediction(uid=40, iid=443, r_ui=4, est=3.980543007194384, details={'was_impossible': False}),
#  Prediction(uid=40, iid=444, r_ui=4, est=3.7198284331018705, details={'was_impossible': False}),
#  Prediction(uid=40, iid=445, r_ui=4, est=3.79350065682856, details={'was_impossible': False}),
#  Prediction(uid=40, iid=446, r_ui=4, est=4.4123347742150685, details={'was_impossible': False}),
#  Prediction(uid=40, iid=447, r_ui=4, est=4.198922119227981, details={'was_impossible': False}),
#  Prediction(uid=40, iid=448, r_ui=4, est=4.111949181682756, details={'was_impossible': False}),
#  Prediction(uid=40, iid=449, r_ui=4, est=4.000228327395252, details={'was_impossible': False}),
#  Prediction(uid=40, iid=450, r_ui=4, est=4.06162007542487, details={'was_impossible': False}),
#  Prediction(uid=40, iid=451, r_ui=4, est=4.054765878050684, details={'was_impossible': False}),
#  Prediction(uid=40, iid=452, r_ui=4, est=4.341684238596617, details={'was_impossible': False}),
#  Prediction(uid=40, iid=453, r_ui=4, est=3.5261178818829886, details={'was_impossible': False}),
#  Prediction(uid=40, iid=454, r_ui=4, est=4.063556104451131, details={'was_impossible': False}),
#  Prediction(uid=40, iid=455, r_ui=4, est=3.4281194204324605, details={'was_impossible': False}),
#  Prediction(uid=40, iid=456, r_ui=4, est=4.19164685285129, details={'was_impossible': False}),
#  Prediction(uid=40, iid=457, r_ui=4, est=4.495023611628752, details={'was_impossible': False}),
#  Prediction(uid=40, iid=458, r_ui=4, est=4.173710878692911, details={'was_impossible': False}),
#  Prediction(uid=40, iid=459, r_ui=4, est=4.049694811660881, details={'was_impossible': False}),
#  Prediction(uid=40, iid=460, r_ui=4, est=3.843170080677523, details={'was_impossible': False}),
#  Prediction(uid=40, iid=461, r_ui=4, est=4.089399848736865, details={'was_impossible': False}),
#  Prediction(uid=40, iid=463, r_ui=4, est=4.010229698099876, details={'was_impossible': False}),
#  Prediction(uid=40, iid=464, r_ui=4, est=3.7928995927094387, details={'was_impossible': False}),
#  Prediction(uid=40, iid=465, r_ui=4, est=4.205066390673955, details={'was_impossible': False}),
#  Prediction(uid=40, iid=466, r_ui=4, est=3.926704931597329, details={'was_impossible': False}),
#  Prediction(uid=40, iid=467, r_ui=4, est=3.9770945379749043, details={'was_impossible': False}),
#  Prediction(uid=40, iid=468, r_ui=4, est=3.920725128941004, details={'was_impossible': False}),
#  Prediction(uid=40, iid=469, r_ui=4, est=3.8963191874751413, details={'was_impossible': False}),
#  Prediction(uid=40, iid=470, r_ui=4, est=3.739770897202812, details={'was_impossible': False}),
#  Prediction(uid=40, iid=471, r_ui=4, est=4.40198775594097, details={'was_impossible': False}),
#  Prediction(uid=40, iid=472, r_ui=4, est=4.114485094854035, details={'was_impossible': False}),
#  Prediction(uid=40, iid=473, r_ui=4, est=3.2874532481778505, details={'was_impossible': False}),
#  Prediction(uid=40, iid=474, r_ui=4, est=4.4235903600601905, details={'was_impossible': False}),
#  Prediction(uid=40, iid=475, r_ui=4, est=4.946292330431961, details={'was_impossible': False}),
#  Prediction(uid=40, iid=476, r_ui=4, est=4.034180529802651, details={'was_impossible': False}),
#  Prediction(uid=40, iid=477, r_ui=4, est=4.197250845938138, details={'was_impossible': False}),
#  Prediction(uid=40, iid=479, r_ui=4, est=4.0083242957022485, details={'was_impossible': False}),
#  Prediction(uid=40, iid=480, r_ui=4, est=4.332614027221946, details={'was_impossible': False}),
#  Prediction(uid=40, iid=481, r_ui=4, est=3.815622203425201, details={'was_impossible': False}),
#  Prediction(uid=40, iid=482, r_ui=4, est=3.5739995711637387, details={'was_impossible': False}),
#  Prediction(uid=40, iid=483, r_ui=4, est=4.1821581564535935, details={'was_impossible': False}),
#  Prediction(uid=40, iid=484, r_ui=4, est=3.6805815645292372, details={'was_impossible': False}),
#  Prediction(uid=40, iid=485, r_ui=4, est=3.6307809548445946, details={'was_impossible': False}),
#  Prediction(uid=40, iid=486, r_ui=4, est=3.7313470237943895, details={'was_impossible': False}),
#  Prediction(uid=40, iid=487, r_ui=4, est=4.0879175902759854, details={'was_impossible': False}),
#  Prediction(uid=40, iid=488, r_ui=4, est=3.954020246434093, details={'was_impossible': False}),
#  Prediction(uid=40, iid=489, r_ui=4, est=3.264872551682539, details={'was_impossible': False}),
#  Prediction(uid=40, iid=490, r_ui=4, est=4.052345678840116, details={'was_impossible': False}),
#  Prediction(uid=40, iid=491, r_ui=4, est=4.06026714709717, details={'was_impossible': False}),
#  Prediction(uid=40, iid=492, r_ui=4, est=4.339466395683272, details={'was_impossible': False}),
#  Prediction(uid=40, iid=493, r_ui=4, est=4.140562242255862, details={'was_impossible': False}),
#  Prediction(uid=40, iid=494, r_ui=4, est=3.9379400518313172, details={'was_impossible': False}),
#  Prediction(uid=40, iid=495, r_ui=4, est=4.329378834478391, details={'was_impossible': False}),
#  Prediction(uid=40, iid=496, r_ui=4, est=3.904000908521416, details={'was_impossible': False}),
#  Prediction(uid=40, iid=498, r_ui=4, est=3.84667740076093, details={'was_impossible': False}),
#  Prediction(uid=40, iid=499, r_ui=4, est=3.8995197471478145, details={'was_impossible': False}),
#  Prediction(uid=40, iid=500, r_ui=4, est=4.0085101402215555, details={'was_impossible': False}),
#  Prediction(uid=40, iid=501, r_ui=4, est=4.4381401301769445, details={'was_impossible': False}),
#  Prediction(uid=40, iid=502, r_ui=4, est=3.342131254892788, details={'was_impossible': False}),
#  Prediction(uid=40, iid=504, r_ui=4, est=3.908292547957827, details={'was_impossible': False}),
#  Prediction(uid=40, iid=505, r_ui=4, est=3.653006956524508, details={'was_impossible': False}),
#  Prediction(uid=40, iid=506, r_ui=4, est=3.8966603576678516, details={'was_impossible': False}),
#  Prediction(uid=40, iid=507, r_ui=4, est=4.1367159312260045, details={'was_impossible': False}),
#  Prediction(uid=40, iid=508, r_ui=4, est=4.391296761006059, details={'was_impossible': False}),
#  Prediction(uid=40, iid=509, r_ui=4, est=4.25666474746935, details={'was_impossible': False}),
#  Prediction(uid=40, iid=510, r_ui=4, est=3.575796469747759, details={'was_impossible': False}),
#  Prediction(uid=40, iid=511, r_ui=4, est=3.902429653416274, details={'was_impossible': False}),
#  Prediction(uid=40, iid=512, r_ui=4, est=4.045110459506789, details={'was_impossible': False}),
#  Prediction(uid=40, iid=513, r_ui=4, est=3.5176408022038124, details={'was_impossible': False}),
#  Prediction(uid=40, iid=514, r_ui=4, est=4.062182799996142, details={'was_impossible': False}),
#  Prediction(uid=40, iid=516, r_ui=4, est=3.6503526186611865, details={'was_impossible': False}),
#  Prediction(uid=40, iid=517, r_ui=4, est=3.7596596257505124, details={'was_impossible': False}),
#  Prediction(uid=40, iid=518, r_ui=4, est=3.315494126205089, details={'was_impossible': False}),
#  Prediction(uid=40, iid=519, r_ui=4, est=3.088617992440522, details={'was_impossible': False}),
#  Prediction(uid=40, iid=520, r_ui=4, est=3.7507849548546037, details={'was_impossible': False}),
#  Prediction(uid=40, iid=521, r_ui=4, est=3.9585766696776274, details={'was_impossible': False}),
#  Prediction(uid=40, iid=522, r_ui=4, est=3.567943788428636, details={'was_impossible': False}),
#  Prediction(uid=40, iid=523, r_ui=4, est=3.9072893162026534, details={'was_impossible': False}),
#  Prediction(uid=40, iid=524, r_ui=4, est=4.304895379589186, details={'was_impossible': False}),
#  Prediction(uid=40, iid=526, r_ui=4, est=3.8382396712455322, details={'was_impossible': False}),
#  Prediction(uid=40, iid=528, r_ui=4, est=3.8136449446643894, details={'was_impossible': False}),
#  Prediction(uid=40, iid=529, r_ui=4, est=4.450559344483263, details={'was_impossible': False}),
#  Prediction(uid=40, iid=531, r_ui=4, est=4.0986252072771645, details={'was_impossible': False}),
#  Prediction(uid=40, iid=532, r_ui=4, est=3.68291828931362, details={'was_impossible': False}),
#  Prediction(uid=40, iid=533, r_ui=4, est=3.9209048779860005, details={'was_impossible': False}),
#  Prediction(uid=40, iid=535, r_ui=4, est=4.624919850711594, details={'was_impossible': False}),
#  Prediction(uid=40, iid=536, r_ui=4, est=3.7997041755956054, details={'was_impossible': False}),
#  Prediction(uid=40, iid=537, r_ui=4, est=3.773066454844548, details={'was_impossible': False}),
#  Prediction(uid=40, iid=538, r_ui=4, est=4.396266171894417, details={'was_impossible': False}),
#  Prediction(uid=40, iid=539, r_ui=4, est=4.000155437506751, details={'was_impossible': False}),
#  Prediction(uid=40, iid=540, r_ui=4, est=3.4743764481250405, details={'was_impossible': False}),
#  Prediction(uid=40, iid=541, r_ui=4, est=4.56357779684567, details={'was_impossible': False}),
#  Prediction(uid=40, iid=542, r_ui=4, est=3.349739436284292, details={'was_impossible': False}),
#  Prediction(uid=40, iid=543, r_ui=4, est=3.9263141730570097, details={'was_impossible': False}),
#  Prediction(uid=40, iid=544, r_ui=4, est=3.504878298382768, details={'was_impossible': False}),
#  Prediction(uid=40, iid=546, r_ui=4, est=2.772900599287778, details={'was_impossible': False}),
#  Prediction(uid=40, iid=547, r_ui=4, est=3.7747871567003433, details={'was_impossible': False}),
#  Prediction(uid=40, iid=548, r_ui=4, est=3.7883626040638343, details={'was_impossible': False}),
#  Prediction(uid=40, iid=549, r_ui=4, est=4.503282075542772, details={'was_impossible': False}),
#  Prediction(uid=40, iid=550, r_ui=4, est=3.783760846275897, details={'was_impossible': False}),
#  Prediction(uid=40, iid=551, r_ui=4, est=4.3039125370646145, details={'was_impossible': False}),
#  Prediction(uid=40, iid=552, r_ui=4, est=3.6612073417183493, details={'was_impossible': False}),
#  Prediction(uid=40, iid=553, r_ui=4, est=4.047309658417064, details={'was_impossible': False}),
#  Prediction(uid=40, iid=554, r_ui=4, est=3.8079660039107677, details={'was_impossible': False}),
#  Prediction(uid=40, iid=555, r_ui=4, est=4.365285618569662, details={'was_impossible': False}),
#  Prediction(uid=40, iid=556, r_ui=4, est=4.457623557362708, details={'was_impossible': False}),
#  Prediction(uid=40, iid=558, r_ui=4, est=3.4006185384563548, details={'was_impossible': False}),
#  Prediction(uid=40, iid=559, r_ui=4, est=4.347719965817674, details={'was_impossible': False}),
#  Prediction(uid=40, iid=561, r_ui=4, est=4.01589427343402, details={'was_impossible': False}),
#  Prediction(uid=40, iid=562, r_ui=4, est=4.463098930648426, details={'was_impossible': False}),
#  Prediction(uid=40, iid=563, r_ui=4, est=4.029712215988444, details={'was_impossible': False}),
#  Prediction(uid=40, iid=564, r_ui=4, est=3.9684891907352, details={'was_impossible': False}),
#  Prediction(uid=40, iid=565, r_ui=4, est=4.488825878012791, details={'was_impossible': False}),
#  Prediction(uid=40, iid=567, r_ui=4, est=4.135237784146748, details={'was_impossible': False}),
#  Prediction(uid=40, iid=568, r_ui=4, est=4.0981651808498905, details={'was_impossible': False}),
# ...
#  Prediction(uid=40, iid=1049, r_ui=4, est=4.09354605767927, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1050, r_ui=4, est=4.009475192271748, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1051, r_ui=4, est=3.912047596828554, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1053, r_ui=4, est=3.9066801054659743, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1054, r_ui=4, est=3.8489512840750977, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1055, r_ui=4, est=3.7182739837443837, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1056, r_ui=4, est=4.3830326429787965, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1057, r_ui=4, est=4.299751886583266, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1060, r_ui=4, est=4.69289247041717, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1061, r_ui=4, est=4.108851614184865, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1063, r_ui=4, est=4.231686156637253, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1064, r_ui=4, est=3.605606064480889, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1066, r_ui=4, est=4.579071470859281, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1067, r_ui=4, est=4.13760510303734, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1068, r_ui=4, est=4.13027206825087, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1069, r_ui=4, est=4.181849007959107, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1073, r_ui=4, est=4.165267221212995, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1076, r_ui=4, est=4.216500785903338, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1077, r_ui=4, est=4.531331073436793, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1078, r_ui=4, est=4.468906045976342, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1079, r_ui=4, est=4.400544821828315, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1080, r_ui=4, est=4.245014933920487, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1081, r_ui=4, est=4.1964498141363125, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1082, r_ui=4, est=4.279743296129397, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1083, r_ui=4, est=3.878951886839696, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1084, r_ui=4, est=4.381088605984455, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1085, r_ui=4, est=4.20768142550343, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1086, r_ui=4, est=4.51717109778798, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1087, r_ui=4, est=4.098484406894661, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1088, r_ui=4, est=4.018087695166933, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1089, r_ui=4, est=4.584418716696915, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1090, r_ui=4, est=4.404847642251262, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1091, r_ui=4, est=3.38664429099363, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1092, r_ui=4, est=3.939482773978289, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1093, r_ui=4, est=3.9953562266898883, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1094, r_ui=4, est=4.3653492119100035, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1095, r_ui=4, est=4.527493881598111, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1096, r_ui=4, est=4.719723377400685, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1097, r_ui=4, est=4.15896434185012, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1099, r_ui=4, est=4.08994328334395, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1100, r_ui=4, est=3.4152109318697472, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1101, r_ui=4, est=3.795306443210296, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1103, r_ui=4, est=4.422635175269914, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1104, r_ui=4, est=4.293207675250117, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1105, r_ui=4, est=3.7501543005809306, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1111, r_ui=4, est=4.467992093023697, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1112, r_ui=4, est=4.126288419656217, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1113, r_ui=4, est=3.661895183721291, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1114, r_ui=4, est=3.907762152787029, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1120, r_ui=4, est=4.4135726475940364, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1123, r_ui=4, est=4.3013125275696185, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1124, r_ui=4, est=4.104287478582961, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1125, r_ui=4, est=4.087073734585323, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1126, r_ui=4, est=3.583723607769837, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1127, r_ui=4, est=4.085430298233006, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1128, r_ui=4, est=4.026424256820564, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1129, r_ui=4, est=4.061736422564738, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1130, r_ui=4, est=4.075710618253371, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1131, r_ui=4, est=4.6109212706151, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1132, r_ui=4, est=4.197538844607578, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1133, r_ui=4, est=4.030971521549322, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1135, r_ui=4, est=3.9830939248093054, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1136, r_ui=4, est=4.7427162610530385, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1137, r_ui=4, est=4.119854542393831, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1145, r_ui=4, est=4.0666731218371215, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1147, r_ui=4, est=4.675080692848545, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1148, r_ui=4, est=4.748919420170946, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1150, r_ui=4, est=4.336721573707562, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1151, r_ui=4, est=4.165838318268676, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1152, r_ui=4, est=4.013282498188331, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1153, r_ui=4, est=4.05434045408862, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1154, r_ui=4, est=3.835565478545438, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1161, r_ui=4, est=4.46417616965564, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1162, r_ui=4, est=4.088706910985212, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1163, r_ui=4, est=3.930787740288936, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1164, r_ui=4, est=3.9860106300027938, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1165, r_ui=4, est=3.725011859434846, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1167, r_ui=4, est=3.6848129332362904, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1168, r_ui=4, est=4.0232751202761925, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1169, r_ui=4, est=4.1674653960993195, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1171, r_ui=4, est=4.154079787684675, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1172, r_ui=4, est=4.9623860936162, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1173, r_ui=4, est=4.0083175926466215, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1174, r_ui=4, est=4.088896907663976, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1175, r_ui=4, est=4.591171604542844, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1176, r_ui=4, est=4.219395180049039, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1178, r_ui=4, est=4.713511434966093, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1179, r_ui=4, est=4.200797764748846, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1180, r_ui=4, est=4.117072188371516, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1181, r_ui=4, est=4.043488818170638, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1183, r_ui=4, est=4.3720301626514635, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1184, r_ui=4, est=4.1475415953652, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1185, r_ui=4, est=4.407864306878993, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1186, r_ui=4, est=4.154664995542834, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1187, r_ui=4, est=4.0670636085376985, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1188, r_ui=4, est=4.066296930127201, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1189, r_ui=4, est=4.4665990082436124, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1190, r_ui=4, est=3.5131402247037005, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1191, r_ui=4, est=4.090706428917127, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1192, r_ui=4, est=4.640685741173711, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1193, r_ui=4, est=4.641214357952183, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1194, r_ui=4, est=4.391604421385649, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1196, r_ui=4, est=4.571782294236809, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1197, r_ui=4, est=4.637691514731397, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1198, r_ui=4, est=4.661346099415988, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1199, r_ui=4, est=4.461199563114641, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1200, r_ui=4, est=4.285171178527046, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1201, r_ui=4, est=4.4305604403683, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1202, r_ui=4, est=4.225204743971172, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1203, r_ui=4, est=4.742400712746148, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1204, r_ui=4, est=4.641230013557571, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1206, r_ui=4, est=4.32972063768194, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1207, r_ui=4, est=4.554346537390238, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1208, r_ui=4, est=4.426296474217677, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1209, r_ui=4, est=4.6958174078891615, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1210, r_ui=4, est=4.339308778348617, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1211, r_ui=4, est=4.776963836556052, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1212, r_ui=4, est=4.787394768870846, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1213, r_ui=4, est=4.54401490711375, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1214, r_ui=4, est=4.221274361380437, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1215, r_ui=4, est=4.28466526049283, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1216, r_ui=4, est=3.861162011579437, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1217, r_ui=4, est=4.831181068250068, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1218, r_ui=4, est=4.572536443310874, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1219, r_ui=4, est=4.6728772436077595, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1220, r_ui=4, est=4.375260621837259, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1221, r_ui=4, est=4.782345486722724, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1222, r_ui=4, est=4.50765695052858, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1223, r_ui=4, est=4.7527788453531405, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1224, r_ui=4, est=4.746100815104757, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1225, r_ui=4, est=4.734929516102533, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1226, r_ui=4, est=4.1916169679221245, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1227, r_ui=4, est=4.631767288764358, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1228, r_ui=4, est=4.77708858576395, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1230, r_ui=4, est=4.62532640039825, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1231, r_ui=4, est=4.489354803782137, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1232, r_ui=4, est=4.333221528788041, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1233, r_ui=4, est=4.777156576326394, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1234, r_ui=4, est=4.413374065519049, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1235, r_ui=4, est=4.2220114627942, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1236, r_ui=4, est=4.1651088432943455, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1237, r_ui=4, est=4.719000885328074, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1238, r_ui=4, est=4.43474150868375, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1240, r_ui=4, est=4.524912532711151, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1241, r_ui=4, est=3.8817516733967015, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1242, r_ui=4, est=4.187596582119068, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1243, r_ui=4, est=4.524066813852014, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1244, r_ui=4, est=4.452398702063096, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1245, r_ui=4, est=4.259596775166096, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1246, r_ui=4, est=4.5665198115888375, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1247, r_ui=4, est=4.6482786239074105, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1248, r_ui=4, est=4.673429328369306, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1249, r_ui=4, est=4.5276262376057534, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1250, r_ui=4, est=4.559644102904612, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1251, r_ui=4, est=4.105103807232589, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1252, r_ui=4, est=4.569210661339273, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1253, r_ui=4, est=4.376314981834582, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1254, r_ui=4, est=4.75412113196574, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1255, r_ui=4, est=4.190165231135596, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1256, r_ui=4, est=4.657461630183845, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1257, r_ui=4, est=4.4642391075665495, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1258, r_ui=4, est=4.4760309806331735, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1259, r_ui=4, est=4.7652631385718776, details={'was_impossible': False}),
#  Prediction(uid=40, iid=1260, r_ui=4, est=4.749361651461717, details={'was_impossible': False}),
#  ...]

# %%
pred_ratings=np.array([pred1.est for pred1 in pred])
i_max=pred_ratings.argmax()
iid=item_id_pred[i_max]
print("Top item for user has iid {0} with predicted rating {1}".format(iid,pred_ratings[i_max]))
# Out:
# Top item for user has iid 2064 with predicted rating 4.967871656202498
