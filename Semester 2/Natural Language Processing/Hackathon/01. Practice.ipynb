# %%
# pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\python\python312\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\python\python312\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\python\python312\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\python\python312\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('twitter_samples')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\I522400\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\twitter_samples.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\I522400\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\I522400\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\I522400\AppData\Roaming\nltk_data...
# True

# %%
from nltk.corpus import twitter_samples
import random

# Load twitter samples dataset
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# Combine the datasets and create labels
tweets = positive_tweets + negative_tweets
labels = ['Positive'] * len(positive_tweets) + ['Negative'] * len(negative_tweets)

# Shuffle the dataset
combined = list(zip(tweets, labels))
random.shuffle(combined)
tweets, labels = zip(*combined)

# %%
combined
# Out:
# [("@tammysoffices You can! :) Here's a quick rundown: https://t.co/ajnqMJww1e -Mary",
#   'Positive'),
#  ('IM NOT SCREENSHOTTING IM SO PROUD OF MYSELF :(((', 'Negative'),
#  ('I really really really really really really like you :) :)\n\n#PSYGustoKita http://t.co/0fRd6bgkjE',
#   'Positive'),
#  ("@monolifemusic @DJANORAK I'm getting there! It's been super slow because of the move. Definitely want a Mono Life remix when it's done :-))",
#   'Positive'),
#  ('@KjorObbinsL @wideglide96 @vivijo86 @beingsomebody11 @sophlicious84 @shaymc3796 @ShaymcSharon @ParaJanitor @kelseabellum  thanks :)',
#   'Positive'),
#  ('@MSaito6 @rekoinmanila @AdeccoWaytoWork \nI will keep fighting for what i wanted to be :) \n\n#KunoriforCEO #CEO1Month',
#   'Positive'),
#  ('Deepthroat was a good movie :)) https://t.co/rtz4SsXA0O', 'Positive'),
#  ("justinbieber I bet $20 to a friend that you will follow ✧｡ Chelny ｡✧ before the end of the month. Don't disappoint me! :(",
#   'Negative'),
#  ('@achiralk thanks for the feedback. Here I was thinking that perhaps Mobitel may be better off, heck, guess not :(',
#   'Negative'),
#  ("It's because too broke for the bomb weave I want. :(", 'Negative'),
#  ('@21dadoongie yes hopefully next year :((', 'Negative'),
#  ('@Ironlings_  Sorry Mr 25 :(', 'Negative'),
#  ('Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/RB8pMNgMEo.',
#   'Positive'),
#  ('Casillas should be there :( "@realmadriden: Manchester City vs Real Madrid: this is our starting XI #RMTour2015 http://t.co/s5a7H7pd9x"',
#   'Negative'),
#  ('@iperfectyonce @justinbieber its my biggest dream can u follow me brooo :((((',
#   'Negative'),
#  ("I didn't see you today :( but it's fine. The distance makes me want you more.",
#   'Negative'),
#  ('@WforWoman \nA6. If I was a Girl,\nMy Wardrobe would only and only have "W" in it :))\n#WSaleLove',
#   'Positive'),
#  ('#cakehamper baskets have arrived :) Best gonna be busy 2 get the finished products ready for you all to see #excited http://t.co/1jbVpcfnXB',
#   'Positive'),
#  ('Add my KIK - lorm823 #kik #kikmeguys #blonde #rp #kikmenow #indiemusic #selfshot :( http://t.co/W07JltA7Fy',
#   'Negative'),
#  ('We are thrilled to be on our first international assignment as aerial camera operators....Wales here we come #Boom : ) Never forget to smile',
#   'Positive'),
#  ('Etienne is making me sad :(', 'Negative'),
#  ('sorry for always changing my layout :(', 'Negative'),
#  ("@drcox63 I try, it's just the way my brain is hard-wired. I always feel like I don't do enough :(",
#   'Negative'),
#  ("@Jaaeeeeee lucky :( I was feeling hungry, but then I didn't wanna get out of bed either, so I gotta wait until mañana",
#   'Negative'),
#  ('i feel you :(( https://t.co/jliVpKmFwG', 'Negative'),
#  ('Soon... :) https://t.co/agyjS1mwiW', 'Positive'),
#  ('@AnnieCushing nice seeing it in Spanish... Well, Latin American Spanish :-)',
#   'Positive'),
#  ('@Danielle_Isla I could never go there ever after seeing that, so cruel :(',
#   'Negative'),
#  ('esnho: Why the "NODE15 - Advanced DirectX11 Shading Workshop P2" is uploaded and removed? :(',
#   'Negative'),
#  ('Ouucchhh one of my wisdom teeth are coming through :(', 'Negative'),
#  ('My poor noggin! Bumped it a few days ago and it still hurts a little. :( #feelslikeanidiot',
#   'Negative'),
#  ('Great marketing campaign from @UberUK - shame all the drivers are busy :( #UberIceCream  https://t.co/C0zXMuWeM1',
#   'Negative'),
#  ('KIK me guys : patml482 #kik #kikmenow #kikmeboys #likeforlike #orgasm #nakamaforever #sexygirlbypreciouslemmy :( http://t.co/dl1AgJykBH',
#   'Negative'),
#  ('I had a good dream. Its a sign that Im going to get along with my unknown roomie. :)',
#   'Positive'),
#  ("@Uber the app isn't working :( #wewanticecream", 'Negative'),
#  ('@fergieweather thanks mate, much appreciated :-)', 'Positive'),
#  ('@Flash_y0 GGs bro :) fun series', 'Positive'),
#  ('Can you please tell me :(', 'Negative'),
#  ("i hope Shamuon's doing all right in Tokyo. :(((", 'Negative'),
#  ('@IMKellyHoppen Actually, I would beg to differ on that one. Sometimes, less is more. :) #philosophical',
#   'Positive'),
#  ('@bel_pearson Cricket World Cup, Asian cup state of origin... now this?! Wow Matt is a lucky boy :-) have fun!',
#   'Positive'),
#  ('My cat loves to snuggle up right by my face &amp; I love it but can never breathe :(',
#   'Negative'),
#  ('@CG_Rated thtas what I asked :)', 'Positive'),
#  ("@MakeStronger3 hi here's my vid about Stydia if you can take a look :) https://t.co/k75kPT0aq1",
#   'Positive'),
#  ('@Gotham3 very sad view :(', 'Negative'),
#  ('My SNAPCHAT - ShirleyCam #snapchat #hornykik #dmme #kikchat #selfie #amazon #phonesex :( http://t.co/teCUf9c9yc',
#   'Negative'),
#  ('@Nigella_Lawson Lemons  bought for yogurt pot cake. Discovered yogurt out of date!  lemon version of liquorice pud possible do you think? :)',
#   'Positive'),
#  ('why didnt u :(', 'Negative'),
#  ("don't sleep. I'm here : (", 'Negative'),
#  ('@GoodMovesL25 @WWhimsicals @_Megan_H @Andrew_Murray91 @sonjaclarkuk @Epic_Liverpool @JusSweetEnough Good morning :-)',
#   'Positive'),
#  ("@SBS_MTV Are you sure that Chorong is the leader? #에이핑크 #더쇼 I can't be sure anymore :(",
#   'Negative'),
#  ('Bad day???:-(', 'Negative'),
#  ('@surayyaaa_ :(( I miss you so much', 'Negative'),
#  ('@Tulki Any help / advice / info you need - just yell :) You can normally catch us on here, erm, all the time ;)',
#   'Positive'),
#  ('@CharmingJedward you´re welcome!! :)', 'Positive'),
#  ("If you didn't get inspired by the sheer fact that Obama beat innumerable odds to become US President, ni shauri yako :-) #MemoToHaters",
#   'Positive'),
#  ('making Alyssa rub my tummy :)))', 'Positive'),
#  ('@joohyunvrl you are a goddess :D', 'Positive'),
#  ('Amelia didnt stalk my twitter :(', 'Negative'),
#  ("@IronMillTech Also, what is it you want me to do with this info? I shan't be ditching @ecotricity! And I'll die before I vote Tory...:)",
#   'Positive'),
#  ('@Chewy_Lemon Oh yeah, because Milo, Aurini and Juicebro are the fucking pillars of their respective communities. :D',
#   'Positive'),
#  ('@paradisecreated yup! Should be really cool :)', 'Positive'),
#  ("@zysuzyy Thanks zy, let's be friend yaa :)", 'Positive'),
#  ("I'm not the best, not the most perfect, but I promise to love you with my whole heart. :)",
#   'Positive'),
#  ('@ohanakian @KianLawley i hope he is okay :(', 'Negative'),
#  ('i was joking only man :(((((', 'Negative'),
#  ('can anyone give me money for the train so that i can see @littlemix today?! :(',
#   'Negative'),
#  ('@ewoksurewok just Americano :)', 'Positive'),
#  ('@hufflepuffjimin omg thats such a sweet thing to say thank you :-) yeah i used to go to saudi arabia a lot because of my dad',
#   'Positive'),
#  ('So, the enemies can simply go around it!:-) https://t.co/5pL57HsT53',
#   'Positive'),
#  ('#FF #HappyFriday @szekifer @phattony138 @djchiavistelli @DJ_CharlieD @Paul___Rayner the weekend is nearly here :-)',
#   'Positive'),
#  ('Dear Crush, You\'re the "Apple of my eye" :)', 'Positive'),
#  ('when u r not smart in real life so u have to act smart on the webz :-)',
#   'Positive'),
#  ("@irisharry_ Awww no :( I didn't mean to make you sad! - Mike", 'Negative'),
#  ('@wendykims @Joix05 @GiladMillo some people need not to talk-kama hawako around :( :( \nWaa Kimaaaaaani prisssss!',
#   'Negative'),
#  ('"@macykatemusic: You Know You Like It - DJ Snake - performed it at vid con todayyyyy :) https://t.co/ddaXAxtknE"',
#   'Positive'),
#  ('@natsouthby I want to rt that :(', 'Negative'),
#  ('@ayokejkt Visit my blog http://t.co/UzOAqroWKx thanks :D', 'Positive'),
#  ('@mussshiii @Takafofo so wat??:)', 'Positive'),
#  (':) where are you situated? @Hijay09', 'Positive'),
#  ('Morning all... ITS BACON ROLL FRIDAY :D', 'Positive'),
#  ('Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x14',
#   'Positive'),
#  ('@TomRPI @CatherineLW98  we got it working Tom; well done for doing it all yourself :D',
#   'Positive'),
#  ("@NiallOfficial from bad to good. My parents were also proud for being me today it's all bc of you guys. Thank you! X NOTICED ME PLEASE :((",
#   'Negative'),
#  ("@Parulcoolthougs I'm here if you want to talk :)", 'Positive'),
#  ("@eclaire605209 That's great! And good luck :) ^KW", 'Positive'),
#  ('@86_Siwonie thank you oppa :)', 'Positive'),
#  ('I miss ITB omigod :(', 'Negative'),
#  ('Yeeeeah ! :D …', 'Positive'),
#  ('@Donoxh oh my 😢 my friend of 8 years is helping me :(', 'Negative'),
#  ('MY STREAM IS SO PIXELATED :((((((', 'Negative'),
#  ('@smitty6253 @Banks @Fintech @Pgelis @DuenaBlomstrom @StuartHeyworth going to be alot easier one way than the other is my view :)',
#   'Positive'),
#  ("like a boy when it's up like that' and he laughed and then we hugged and I said bye and :(((((( I love him",
#   'Negative'),
#  ('So far so good. Ikaw musta cheatmate? :)  https://t.co/YzJt2feA1u',
#   'Positive'),
#  (':) Good Afternoon :D\n#TwitterFollowersWhatsUp\n#HappyFriedDay\n#KeepSafeAlways \n#LoveYeah\n#emojasp_here',
#   'Positive'),
#  ('A little doodle of the star of my comic, Summoner, which will be back up soon :) #art #doodle http://t.co/7bgF2Y1Zc2',
#   'Positive'),
#  ('i miss my kindergarten kids :(', 'Negative'),
#  ('@WaseemBadami amazing set of questions bhai keep it up:(( missing shan e ramzan and u :((',
#   'Negative'),
#  ('Gwss :(❤️❤️ — Thankyouu❤️. http://t.co/z0a6jTboH8', 'Negative'),
#  ("@Mvusi_ lol I'm still very fluent and people say I sound white :( but varsity ruined me. Sengenza typos and I use some words out of context.",
#   'Negative'),
#  ('@CreeperFartss come chill by the fire :)', 'Positive'),
#  ("@hanpdf it's you :)", 'Positive'),
#  ('@jasmine_chantay :(( okay!!x', 'Negative'),
#  ("@dullandwicked @_GrahamPatrick @JohnBoyStyle Has nobody told you about this side of twitter? It's in the T&amp;Cs. He owns you now. Sorry. :(",
#   'Negative'),
#  ('@tescomobile could you pick me up a sandwich then?:(', 'Negative'),
#  ('Views from our office are pretty awesome and this is the ugly side! The sea side is even prettier :) http://t.co/c3dDU2rxnv',
#   'Positive'),
#  ('without you :(', 'Negative'),
#  ('@IncreaseEnergy Thank you :)', 'Positive'),
#  ('@Dobboinaus thats it :)', 'Positive'),
#  (':( the world where alternis kills himself is really sad because they leave that place and everyone there just has to die',
#   'Negative'),
#  ('@malgotoja hi Maggie- afraid my knowledge of Mull is limited (nil!:)). Have a look at @walkhighlands web page- definitely best place to look',
#   'Positive'),
#  ('Oh how horrific :( https://t.co/IObpbythB8', 'Negative'),
#  ('@SpazzyTsukihara awww but i was going to ask for a dragon duck with mix of a cheetah :p',
#   'Positive'),
#  ("wow! :) Plus size model graces the cover of a women's running magazine http://t.co/dq91NI2rZY via @mashable http://t.co/fviD4vlDhq",
#   'Positive'),
#  ('@IamComet67P Thank you, sweetest &amp; kindest Comet! :-)', 'Positive'),
#  ('Stats for the day have arrived. 2 new followers and NO unfollowers :) via http://t.co/XX65KfaylK.',
#   'Positive'),
#  ('@JayMcGuiness nooo stay in UK IM HERE :(', 'Negative'),
#  ('#FollowFriday @StayfanChemin @CCI_75 @aandreup for being top influencers in my community this week :)',
#   'Positive'),
#  ('@iamsrk sir,please announce don 3!!! i am badly waiting for it!! :(',
#   'Negative'),
#  ("@lynshields lol. Well I can't buy those nachos then :(", 'Negative'),
#  ('#JusticeForSandraBland #SandraBland this is disturbing just shows the poor women was already dead in the mug shot :( https://t.co/K17rqTUbeH',
#   'Negative'),
#  ('"@Boy_Hugots: Never give up. The best things take time." weh :(',
#   'Negative'),
#  ('Common - Celebrate, never fails to get me in a good mood :)', 'Positive'),
#  (':( now im feeling lonely wth https://t.co/6NrxEGjSv3', 'Negative'),
#  ('Awh why :( were nice  https://t.co/5zAwc5Z37J', 'Negative'),
#  ('I just want to look good for you :)', 'Positive'),
#  ('I wish my band were shittier so we could get booked on Leno :(',
#   'Negative'),
#  ("@motaspopsicle i don't know :(((((", 'Negative'),
#  ("i love got7's outfit for just right &gt;:( its so fun", 'Negative'),
#  ('@nickhunterr Yes it is :D', 'Positive'),
#  ('@MorrisHub @sidmouthfolk Look forward to watching those! :)', 'Positive'),
#  ('So cute :(', 'Negative'),
#  ('My afternoon date. &lt;3 :)', 'Positive'),
#  ('i wish :( #ZaynIsComingBackOnJuly26', 'Negative'),
#  ('@ChloeGMoretz Chloe I watched "Let me in" yesterday and you were really awesome! Really talented and intelligent actress, beautiful too! :)',
#   'Positive'),
#  ('Bring your graphic design and web design skills to the next level :)\nLearn more:... http://t.co/2HIE5tcv2P',
#   'Positive'),
#  ('@Taitamco Oh, that MASA :-) got you! BTW, Entrepreneurship empowered you?',
#   'Positive'),
#  ("@PeterLawrey People still code in those languages?:) But you're right. For me as a Java guy, PHP's notion of references is equally confusing",
#   'Positive'),
#  ('@theroiceorven  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#   'Positive'),
#  ('Add me on the snapchat yall :) give me your @ names', 'Positive'),
#  ("why is got7's outfit for music bank so messy? :( the colour could have been better",
#   'Negative'),
#  ('@sainsburys guys a really unlucky one. The driver and I briefly checked eggs but my other half spotted this : ( http://t.co/WpCqJHhBVk',
#   'Negative'),
#  ("@MusicTubenl Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)",
#   'Positive'),
#  ('Me + Bed = Best couple ever :)', 'Positive'),
#  ('Just landed in GC!! Yeeew of to pre LAN :)', 'Positive'),
#  ('turtle net !!!! :-(((', 'Negative'),
#  ('Blog Post &gt; THE HUNGER GAMES: MOCKINGJAY - PART 2 (2015): No More Teasers :-) http://t.co/QGsQkvrDIi \n#TheHungerGames http://t.co/yOTeNaX7yR',
#   'Positive'),
#  ('the aaaAaaAAAAAAh sound kanye makes in hey mama is so cute :(', 'Negative'),
#  ('monica just went to davao. :( luckyyyy', 'Negative'),
#  ("@jadegordon @mc_frontalot I'm so glad you got to go! :)", 'Positive'),
#  ('@NickRomanTV @knovak832_novak well said, your right this episode was fantastic..:) #BATB clap clap clap',
#   'Positive'),
#  ('@baexrv pcy mine :-(', 'Negative'),
#  ('@ice_crystal @Elbow @MeatBingo @govindajeggy Thank you! :)', 'Positive'),
#  ('@AinsworthKeira did I not? Ah what a shame that is. Why am I not a shuffle queen like you :(',
#   'Negative'),
#  ('so thirsty :((', 'Negative'),
#  ('Clara and Yiling left me :(', 'Negative'),
#  ('@marilynemy_ good night :)', 'Positive'),
#  ("@woIfgaang it's the story of our life :( haha look who's talking",
#   'Negative'),
#  ('@Julia886 I try not to keep it in the house any more. Used to buy truckloads but not doing miss 13 any favours, so no more :(',
#   'Negative'),
#  ('who wants to ft me and Arianna :-)', 'Positive'),
#  ('@moby307 So true, yet many know this and choose to not heed the notion xx :(',
#   'Negative'),
#  ('@amsterdamartist \n        :(\n Edward Hopper http://t.co/Qx6GZjjNXF',
#   'Negative'),
#  ('good night :(', 'Negative'),
#  ('@lindseyasuer Hi! I see u like FourFiveSeconds and think u might like "Deaf Ears" https://t.co/nO9B1b1vtN .Plz let me know what u think :)',
#   'Positive'),
#  ("i need nate ruess' album :(", 'Negative'),
#  ("Bruce just won't smile :( http://t.co/UwldCQkcoq", 'Negative'),
#  ('@avonfvcks #NotAnApology PLEASE PICK ME :-)', 'Positive'),
#  ('@JuniorStyleLDN @Cricketlabelle @MelanieMse @GambadoChelsea @baby_bargainsUK @barbelinekids @TendreDeal A pleasure as always! :-)',
#   'Positive'),
#  ('20 ghanton se light nahi :))))))', 'Positive'),
#  ('You´ve got me in chains for your love :´( — a sentir-se incompleta',
#   'Negative'),
#  ('#docopenhagen i have a horse in my ass :( http://t.co/QouW0Uwd8O',
#   'Negative'),
#  ("The Sculptor's Pillar 2015 is now available in @DOTA2 store!\nGood thing they released it in store. :) #TI5 #dota2 http://t.co/KBM0p9jyZJ",
#   'Positive'),
#  ('@dowsingforsound @alex_elbro @camideasfest @ADFofficial @CambLiveTrust Saw ADF at WOMAD Gran Canaria yrs ago. Best gig ever! Crazy times :)',
#   'Positive'),
#  ("@JaydnNeal1 Aw bless you, this made me smile! I'm missing you too :(",
#   'Negative'),
#  ('time for sleep :)', 'Positive'),
#  ('@waterrat77 Thank you :-)', 'Positive'),
#  ('last chance :(', 'Negative'),
#  ('@Bhoxzniall fback? :)', 'Positive'),
#  ("@tracysharpy3 @Debbeedale Thank you for coming ladies, so lovely to see you both :) We don't know either!!",
#   'Positive'),
#  ('@pascale_blakey Great, thanks lovely :-). Almost 40 responses in the first hour!!! So delighted. Some really great comments on what next.',
#   'Positive'),
#  ('Photoset: sadomasochistsparadise: Wynter bottoms- and an outtake :) Sadomasochist’s Paradise Cuties http://t.co/GNW1lwjFK1',
#   'Positive'),
#  ('@JessicaTM23 happy belated birthday cikaaa☺wish you all the best o:) maaf telat ngucapinnya :D',
#   'Positive'),
#  ("Ugh, well I could still say that I'm lucky because I am Sapiosexual. :((((",
#   'Negative'),
#  ('Said I was going to sleep a hour ago &amp; im still awake :-)', 'Positive'),
#  ('@BhaktisBanter  #FlipkartFashionFriday\nMulticolored Maxi Dress paired wid Wedges to make ur Life Bright&amp;Colorful :)\nhttp://t.co/xtzhIBkXsu',
#   'Positive'),
#  ('I hear so many frogs this morning :((((((', 'Negative'),
#  ('I love blue eyes :(', 'Negative'),
#  ('@SAVEREUX1 @TheRoofGardens The band were great! Thank you for coming, was lovely to see you :)',
#   'Positive'),
#  ('@_Halie13_ thanks for being so great!:) ❤️😘', 'Positive'),
#  ('@filadelfiaaa you need to stop being so obsessed over me this is getting creepy :-(',
#   'Negative'),
#  ('@lh_JM88 and now me too :( hubby will be delighted to return home lol',
#   'Negative'),
#  ('Char im really sick :(( one *font size 8* minion float *font size 12* for the sick kid pls :((',
#   'Negative'),
#  ('Annnd, now not going to Winchester {:-(', 'Negative'),
#  ("@davidrmoloney thanks for that. You've made my day! :) Let's organise a meeting soon. Are you based in London?",
#   'Positive'),
#  ('Snapchat me : sexyjudy19 #snapchat #kikmeboys #tagsforlikes #pussy #gay #indiemusic #sexo :) http://t.co/rSAOyu7Vzu',
#   'Positive'),
#  ('@Wichita1771 you awake? :p', 'Positive'),
#  ("@howeverhood @bubblegumcam one year later and we haven't even met :(",
#   'Negative'),
#  ('@Eric_Yeomans I stashed 3 of your closer-chasing specs in a league I am chasing saves...so yes...the walls have ears! :-)',
#   'Positive'),
#  ('I love Baekhyun because I love it when he eyesmiles :)', 'Positive'),
#  ('i need more :( donghyuk stans :( in :( my :( tl :((((( where u guys at',
#   'Negative'),
#  ('sad but true ano yung tbh? :( -_-', 'Negative'),
#  ('@seunjinbing @NGVMelbourne I can’t, thesis :(', 'Negative'),
#  ('@RoySangwooKim congrats, Roy! :D', 'Positive'),
#  ("@KumonePina_bot Just for that, you won't get a cupcake!! &gt;:(",
#   'Negative'),
#  ('@kargadouri FOLLOWED ME THANKS, AND\n@justinbieber PLEASE FOLLOWED ME TOO :(',
#   'Negative'),
#  ("@LaraKBaker Great view! It's a shame about the weather though :-(",
#   'Negative'),
#  ("@kungfuman316\nWell, Gel didn't know, I think... but yeah Alison might. :p",
#   'Positive'),
#  ("INITIAL TEE's\nPM for ORDERS :) http://t.co/2AxBuaPKMS", 'Positive'),
#  ('@AisyahZen I ALSO WANT :( Craving fr donutsss', 'Negative'),
#  ("It's a v nice day. What happened was surreal :)", 'Positive'),
#  ('@jenniferseon yo stop bragging not everybody got the skrillah to travel :(',
#   'Negative'),
#  ('@BhaktisBanter this lovely black &amp; red Maxi dress :) \n#FlipkartFashionFriday http://t.co/aNUBjZs98p',
#   'Positive'),
#  ('@cynthiariojas_ :( I did that once and I got grounded BC they think if I do that I sneak people in',
#   'Negative'),
#  ('IM HOPING :(( https://t.co/Q5slQJWgDT', 'Negative'),
#  ('Finally get to be in bed. :) good night, tweeties!', 'Positive'),
#  ("@aurorakween you don't fwm :(", 'Negative'),
#  ('Yoohoo! Shattering all records #BajrangiBhaijaanStorm #SuperHappy :D http://t.co/wQSegYjWil',
#   'Positive'),
#  ("ladygaga I bet $20 to a friend that you will follow ✧｡ Chelny ｡✧ before the end of the month. Don't disappoint me! :(",
#   'Negative'),
#  ('@UberUK im swiping right but dont see anything :(', 'Negative'),
#  ('@Sukihaikal hahaha okay thank you :)', 'Positive'),
#  ('i wanna watch paper tOWNS :-((((', 'Negative'),
#  ('if you wanna follow my personal is @thaiees !!!! bye guysss :))))',
#   'Positive'),
#  ('@NotJagath are you a member of හෙල හවුල by any chance? :D @Chevindu',
#   'Positive'),
#  ('@ArianeBeeston Thank you! But evil. :)', 'Positive'),
#  ('alright &amp; last winner will be @bizzleftdemi :) dm me ur email',
#   'Positive'),
#  ("@Niallll_1Dx it's a cool video i love it...:) thank u", 'Positive'),
#  ("@ashak21 dudeeeeeee I'm so happy you like them :))))) tell me which are your favorites",
#   'Positive'),
#  ('i smell like you :-(', 'Negative'),
#  ('lol forgot about mubank today :(', 'Negative'),
#  ('Woaah Chris Brown :(((', 'Negative'),
#  ("@KarlreMarks Say hello to 'overgeneralization'! :-)", 'Positive'),
#  ('Looking for fun? SNAPCHAT : LilyButle18 #snapchat #kikmenow #amateur #kikmeboys #seduce #hannibal #kiksexting :( http://t.co/y8RcKiqSZ3',
#   'Negative'),
#  ('@brighteyedmgc hoLY FUCK are u okay / text me if u need anythin !!! :-(',
#   'Negative'),
#  ('I feel like having a relapse :-)', 'Positive'),
#  ("@czagnzls It's one of those days I wish @ibetreyes was here :))",
#   'Positive'),
#  ("@RyanGage Ooh what's that you're reading? New Humanist, that sounds interesting. Have you seen The Happy Reader magazine? :)",
#   'Positive'),
#  ('Please follow me back @1DThisIsUs @onedirection :) x *10', 'Positive'),
#  ('Missed 11:11 :( btw my wish was for @carterreynolds to follow me♥ #LoveYouTillTheEndCarter ☺',
#   'Negative'),
#  ('@Stacyyy24 Happy Birthday :)', 'Positive'),
#  ('@yezzer Visual Studio 2015? it just got out. switched to it already and broke a lot of code :(',
#   'Negative'),
#  ('@MercedesBenzInd The only reason I would hand it back - spare tyre in the boot.. Otherwise it was true Star :-)',
#   'Positive'),
#  ("i'm such a terrible daughter :-(", 'Negative'),
#  ('i miss them already :(', 'Negative'),
#  ('@maureenagena Yeeeey, welcome to the club. Its been one and a half years off whatsapp.. and i donot regret it.. :)',
#   'Positive'),
#  ('@OSWreview "The Mega Powers Expelled" :-)', 'Positive'),
#  ("@TvilleSocialMed can't wait to speak at #PBEvent. See you there. :)",
#   'Positive'),
#  ('This gives me the chills :(', 'Negative'),
#  ('@CoolBlindTech Thanks for the follow! :)', 'Positive'),
#  ('@FrogzLegzMummy @clubtrayfishing @FieldLeisure @TeamFell Morning All, Thanks for joining us and a Happy Friday to you! :-)',
#   'Positive'),
#  ("Rain like cats and dogs..... Can't go anywhere.. Water on the road everywhere.. :(",
#   'Negative'),
#  ('Waited for nothing :-(((((((((((', 'Negative'),
#  ('35 more eps until I catch up wirh arc v!!! : )', 'Positive'),
#  ("@matty_lam @SkyFootball I'm not watching because I'm working :( but I'm not interested in man city anyway 😂 hope they lose",
#   'Negative'),
#  ('@jeffer_jen @LloydPfc nope but just had another check today and I have a hernia :(',
#   'Negative'),
#  ('@GlenOcsko sounds good! Can you DM me your email address? Will suggest some dates for a coffee! :)',
#   'Positive'),
#  ('@beckparsons1 no im on a 24 hour sleep on sunday :( xx', 'Negative'),
#  ('@dxuntlesslarry fback? :)', 'Positive'),
#  ("Sometimes it's all about choosing between your ego and your relationship. :)",
#   'Positive'),
#  ("I'd planned to do a nice scamper but I slept through my alarm. For two hours. I suppose I needed the sleep so I ain't mad :)",
#   'Positive'),
#  ('Heechul Oppa :)\nMy #TeenChoice for #ChoiceInternationalArtist is #SuperJunior!',
#   'Positive'),
#  ('NSTP Class tomorrow :(', 'Negative'),
#  ('@Ripap70 Hi ;-) If you want a free guide use the ZonzoFox App using this link http://t.co/PSbF2rELHn Have a nice stay :-)',
#   'Positive'),
#  ('Are you holding back \nlike the way you do :(', 'Negative'),
#  ('Yeh Real Madrid walay bhi bohat wailay hain. Pre-season friendly pe itna shor machaya hua hai mein samjha cup final hai :(',
#   'Negative'),
#  ('Morning everyone, have a lovely day and a fab weekend :-) x', 'Positive'),
#  ('I got in my feels and Ariel body slapped me literally body slammed me :(',
#   'Negative'),
#  ("@The_ScriptNinja I'm good thanks hope all well with you and yours :-)) xx",
#   'Positive'),
#  ('Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/WCuHrpnFDK.',
#   'Positive'),
#  ('Ah ma guy. You know the thing. "@ceafive: the weather is set for more sleep but responsibilities. :-("',
#   'Negative'),
#  ('ANGRY GRANDPA PLAYS MINECRAFT (ANIMATION) #Minecraft http://t.co/2lqMgmagKr ← Click Aqui :D http://t.co/j2UaGkU9T4',
#   'Positive'),
#  ("@InspectorsClews Oh of course, that's how I understand it. I noticed the issue as well. And Phileas Club inc tomorrow! :)",
#   'Positive'),
#  ('@ClaireGibbsUK fantastic!!! Brilliant news :)', 'Positive'),
#  ('@mistytewest Happy to save the day :) Hope you enjoyed your meal Sam!',
#   'Positive'),
#  ('@WeeklyChris I just want your followback? :( but why you always makes SNOB :(\nSakit sa Heart &lt;/3',
#   'Negative'),
#  ("I'm really excited for our picnic tmrw :-)", 'Positive'),
#  ('@PB_Furniture @whittakerdesig1 @smart_bn @Klick_Business @HartleysRooms @REDlineCC @RedBizUK @earlybiz Woooo! Happy Friday friends :) #ff',
#   'Positive'),
#  ("@Wanli_Minho he said i'm his ideal type in weekly idol and make a love pose for me &gt;&lt; i will tell him if i meet him. Don't worry :)",
#   'Positive'),
#  ('MY kik - plawnew837 #kik #kikmenow #amateur #sfs #snapme #summer #hottie :( http://t.co/2HnzstgnOa',
#   'Negative'),
#  ('My room is way too hot :-(', 'Negative'),
#  ("@ImJoanneT Ahh no what did you get done?? I hope you're okay :(",
#   'Negative'),
#  ('@pannusf10 Never showed it much. :)', 'Positive'),
#  ("@deeziyah no Dublin :(( I'm so sorry I know how it feels the same thing sorta happened to me",
#   'Negative'),
#  ('Hey @ToughChelseaG, I knew the blonde hair was a swerve! :) http://t.co/mpmnNl6vLt',
#   'Positive'),
#  ("@luminousljp WAIT WHATS HIS SNPCAHT if you don't mind me asking :-)",
#   'Positive'),
#  ('@BabySyasya_97 i need translator :(', 'Negative'),
#  ("@ISupportTony You're obviously getting better at your tweets :-)",
#   'Positive'),
#  ('Yach.. telat.. huvvft..., :( https://t.co/nrzfh7Roja', 'Negative'),
#  ('@misslittlevip yes..but its not!! :)', 'Positive'),
#  ('@ThessaNaomi THANK YOU SO MUCH MOM FOR GETTING @sadcuddleashton TICKETS :)',
#   'Positive'),
#  ('didnt took photos with you :-(', 'Negative'),
#  ('Stats for the week have arrived. 1 new follower and NO unfollowers :) via http://t.co/OE2D7PDVx4.',
#   'Positive'),
#  ('And Ernie :(', 'Negative'),
#  ('2 APs no study hall? HAHA great :)))', 'Positive'),
#  ('Delph injured already :( #MCFC', 'Negative'),
#  ("@cIaricestarling i know right... :( i hope it's worth it bc i really wanna see hugh as wolverine again &lt;3",
#   'Negative'),
#  ('how did i go to sleep at 12 last night but rn im up :(', 'Negative'),
#  ('@jakface_mcgee Thank you! :D :D', 'Positive'),
#  ("This fucking bad link isn't working and I can't watch the match! :(",
#   'Negative'),
#  ('@DrRamcharan55 u started the comparative religion rant as well :) after all ur a STUDENT of it. I guess the last benchers probably (1/5)',
#   'Positive'),
#  ('Follow me on twitter! :)) @JMviray_ #Follow #Me https://t.co/sznN5mdV2l',
#   'Positive'),
#  ('3 days without talking with Bae :(', 'Negative'),
#  ('@taeserasera OMG! What happened? :(', 'Negative'),
#  ("Woke up with another migraine. :( ... Need proper rest but at moment I can't.",
#   'Negative'),
#  ("Me : kian I love you \nKian : I LOVE YOUUUUUU\n:( I can't get over today omg",
#   'Negative'),
#  ("I really want to pierce my cupid's bow :(", 'Negative'),
#  ('@twigtwisters thanks for the info :)', 'Positive'),
#  ('@iamBugti_18 &lt;------ff__special\nAcha banda hai ✌ tweets bhi achi krta hai\nHandsome bhi hai 😂\nMust follow :)',
#   'Positive'),
#  ('@WforWoman \n9) shopping will be like fries without ketchup. Tasteless :(\n\n#WSaleLove',
#   'Negative'),
#  ('I was chewing my toy and Stella came over and went for me. lots of noise and teeth and mum yelled at her and threw her out of room :(',
#   'Negative'),
#  ('DAT RP THO. thank you so much you guys for celebrating one month of partnership with me!!! ty @MadMorphTV for the raid! :D',
#   'Positive'),
#  ("I have #SleepingWithSirens tickets Oct 17th in Ok #BRINGMETHEHORIZON  new tour and is playing Dallas the 18th I've seen them 2 times but :(",
#   'Negative'),
#  ("JACOB IT'S @GwendoBocquet BDAY AND SHE GOT TIX FOR US IN PARIS OMG PLEASE WISH HER!! #FIRST50EUROPE 🇫🇷 :D",
#   'Positive'),
#  ('Short, routine #quest from #Borderlands :) #wanderrook http://t.co/NAPmqm2do6',
#   'Positive'),
#  ('Today I finally have time to work on Xcylin again :D', 'Positive'),
#  ('@mariaburtea @5SOS_Nightly wow you really hate me :))))', 'Positive'),
#  ("Hi,i'm definetly so exited ^^ I'm going to New york.:)", 'Positive'),
#  ("@VincentTong007 Can't wait to be out there again. Just a few weeks now! :D",
#   'Positive'),
#  ('@FatalFerret caaaannntttt :(', 'Negative'),
#  ('#AM to CA. Retweet domg nanti difollow ?( :D', 'Positive'),
#  ('@V4Violetta Or that. I guess I need to build my content around my image inventory a little bit then :)',
#   'Positive'),
#  ('@MSOpinion glad you liked :) @sureshbabu_', 'Positive'),
#  ('Is now not an opportune time 2 collapse chaotic Cosas? &lt;--- note the alliteration :-)  @NomalangaSA @barrybateman @AndileMlondo',
#   'Positive'),
#  ('@diegxdelrey is this on ur computer? mine did it too :(', 'Negative'),
#  ('@stylesandjord and a month since i saw them :(', 'Negative'),
#  ('@craigyboi seems to be everywhere today :(', 'Negative'),
#  ('@unit02chainz oops I meant those tiny chat days oooops :-(', 'Negative'),
#  ('wish I had a nice booty :-((((', 'Negative'),
#  ('You Lose :D', 'Positive'),
#  ('@Hanan_nisaS mind to follow back? :)', 'Positive'),
#  ('MY snapchat : LynetteLowe #snapchat #kikhorny #interracial #bestoftheday #naked #goodmusic #sexysasunday :( http://t.co/66GRccvHOM',
#   'Negative'),
#  ('I am actually enjoying Nagato Yuki-chan no Shoushitsu more than I thought I would :D',
#   'Positive'),
#  ("@bandq_help that's ok :( is there any reason why the vouchers can't be used online??",
#   'Negative'),
#  ("it's not okay now, but i will be okay :)", 'Positive'),
#  ('@x123456789tine @5SOS_FAHUpdates gotta love timezones :p', 'Positive'),
#  ('@nicoleezzy halaaaang :( just done crying.', 'Negative'),
#  ("I'm too tan :-(((", 'Negative'),
#  ('"@Manuellatchgn: Goodbye twitter. I will not be there for a long time. :)" Goodbye Manuella',
#   'Positive'),
#  ("@GabyInTheFields Consider yourself lucky! my favourite character didn't even make it to the season finale in The 100 :(",
#   'Negative'),
#  ('@RyanCooperXZ same here :(', 'Negative'),
#  ('Konga"@BeemanNONI: Well... "@_topeh: ni wa*"@iCUM_Thrice: Ode ni e"@_topeh: K "@iCUM_Thrice: I need to be disvirgined..like seriously! :(""',
#   'Negative'),
#  ("@maddylovve_ @kriseldagarza no she's talking about me lmao :(", 'Negative'),
#  ('@im_soexcited @alamocitycon Btw, about that honeymoon :) These are for you. http://t.co/fVYAV8v0yO',
#   'Positive'),
#  ('@aldriannetabang  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#   'Positive'),
#  ('@stelcoco Larry is real :)', 'Positive'),
#  ('@DrNomanSheikh nice :)', 'Positive'),
#  ("I can't ever listen to @PARTYOMO the same again :(", 'Negative'),
#  ('@hesaffection are you the owner of the user @hesIovely ? : )', 'Positive'),
#  ('Video: sararocs: I am so angry at the world :( http://t.co/eGuM20hTok',
#   'Negative'),
#  ('GOING DOWN FOR REAL! :)', 'Positive'),
#  ('therealgolden47  thanks for the follow !! hope you enjoy my work :-) :-) :-) :-) :-) #girlfriendsmya… https://t.co/8G7sXiNBNL',
#   'Positive'),
#  ('go zumba somewhere else please, me studying :(', 'Negative'),
#  ('SO MUCH EDITING TO DO. SO LITTLE TIME. :-(', 'Negative'),
#  ("@AmeAmeSakura especially when you don't like it :( I can't do the same song over and over again :/",
#   'Negative'),
#  ('finished downloading more than 10 movies and one complete tv series from last night. Now… WHERE.DO.I.START. :)))))) #moviemarathon',
#   'Positive'),
#  ('pleaseeeee. :(', 'Negative'),
#  ('@itsAllieFx If you need someone to talk to, I am always here :) Keep your head up.',
#   'Positive'),
#  ('Sometimes just sometimes I drown half a bottle of Nyquil down my throat just for it to have no effect on me :(',
#   'Negative'),
#  ('@JayMcGuiness  :-( please notice meowkd', 'Negative'),
#  ('If you wanna see you more beautiful then rotate your photo !\nIt works.....\n:p\n:v',
#   'Positive'),
#  ('@marcherlord1 Leave a note on the fridge :)', 'Positive'),
#  ('@TinyKyrus So youre not gonna guess whats inside my box? :(((', 'Negative'),
#  ("@Memz_Dogi i'm joining right now :D", 'Positive'),
#  ("@practicallyhaz same :(. now it's a mixture of being so proud of them for how far they've come but also missing those days :(",
#   'Negative'),
#  ('@annajudithk Because they hate me | :(', 'Negative'),
#  ('@HungryLionSA TV Game as a kid :) #BirthdayMonth', 'Positive'),
#  ('@RichyCee93 £20 deposit to secure one :)', 'Positive'),
#  ('they are everywhere :( https://t.co/T0VTMpqams', 'Negative'),
#  ('My Rumbelle feels are just too overwhelming... :((', 'Negative'),
#  ('@VikkFollows #StarSquad ⭐ Can I get a follow? Please Vikk I fna :)',
#   'Positive'),
#  ('@otraclace where you live in the summer :D', 'Positive'),
#  ('@dialoglk I wanna hang out with fellow tweeps and roar the lions to victory #TweepsMatchOut I want to hang out with my twitter family! :(',
#   'Negative'),
#  ('@FOOLISHTEENLOU fback? :)', 'Positive'),
#  ("@sweetnuskie i just did, i don't get it tbh :p but Ellie with superpowers is what i live for so i'm happy :p",
#   'Positive'),
#  ("@Varun_dvn Okeyyyyyy VDDDD :)));))))  So excited can't wait ... ! ! Love selfeeee pics on insta :) ♥♥ special coco .. 🙆🙌😛😄😄😁😂😂🐒😁😝❤ #dishoom",
#   'Positive'),
#  ('@JAOlivar0731  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#   'Positive'),
#  ('#ff to our new members! @BaileyWalshLLP @backuptech @TheLondonDeliCo :)',
#   'Positive'),
#  ('@beat_trees thank you Beatriz :)', 'Positive'),
#  ("@SILV3R I can also provide this, just pop over to my office and i'll provide the required service, with a smile! :D",
#   'Positive'),
#  ('@cloverness :( I hope something holds your interest soon!', 'Negative'),
#  ('HOME ALONE :D', 'Positive'),
#  ('@AlxznDr19 Oh hey Granny :D How are you.', 'Positive'),
#  ('@wotjustin UR ACTUALLY WATCHING (but is it for me smh #what #a #bff #yes #hashtags #bc #u #love #me jk omfg im so hyper :-( )',
#   'Negative'),
#  ("This is so beautiful :) via disney.arts by the talented elmoprinssi  :)\n_ \n\nDon't forget to… https://t.co/UwsFDaeyzB",
#   'Positive'),
#  ("@robertsammons it's released online but not on the album that I know of :(",
#   'Negative'),
#  ('@teenpunklou yup, same.. I thought it was going to be on sale at 8 am, and it wnt on sale at 9:30 I bought it at 9:48... :(',
#   'Negative'),
#  ("Ugh, I think I'm getting sick. :(", 'Negative'),
#  ('Some good advice for a Friday :) http://t.co/FJUd2N7gmc', 'Positive'),
#  ("@otraclace i don't live in a city but I live near whangarei :)",
#   'Positive'),
#  ('@bjj1212 Great to hear! Let us know which recipe you enjoy the most :)',
#   'Positive'),
#  ('Any brands wanting me to review BEAUTY products on my blog? mail me at: ladolcevitainluxembourg@hotmail.com #prrequest #journorequest :)',
#   'Positive'),
#  ('So lonely that sometimes i call my own number to get a busy tone. ;_; :(',
#   'Negative'),
#  ('@GetOutKids This is brilliant :)', 'Positive'),
#  ('@practicallyhaz the bittersweetness :(', 'Negative'),
#  ("Wet holiday Friday :( Console yourself in our cafe with Sophie Grigson's amazing carrot cake! http://t.co/WfzvRXz1Id",
#   'Negative'),
#  ('my heart is hurt ... :( :(', 'Negative'),
#  ("@angelhairhes some people aren't like you, Fra... some of them are kinda selfish :(",
#   'Negative'),
#  ("I'm so sick aahhhh i hate this feeling :-(", 'Negative'),
#  ('@AWSSupport Thanks - can someone maybe look at case 1451834461 fast  - I totally fucked up and its mad expensive :(',
#   'Negative'),
#  ('what happen to the kaussies? :(', 'Negative'),
#  ('@Garfyville In Bath? :) Even we don’t have wheelie bins, nowhere to put them @paulmutton',
#   'Positive'),
#  ("It's the #Halesowen #BlackCountryFair tomorrow! Are any of our followers going? Come and say hello - our stand is on the High Street :-)",
#   'Positive'),
#  ('thanks mom :)', 'Positive'),
#  ('Have to be up in 4 hours :))))))', 'Positive'),
#  ('@blackannesee Get better soon...... :(', 'Negative'),
#  ('@Nayritje okie :(', 'Negative'),
#  ("@itsAmarantha I can't wait &lt;3 :(", 'Negative'),
#  ("@babypuffinator i've typed worse things, it's all good :p", 'Positive'),
#  ('@rodtamepoet  "Rod Tame is embracing his inner actor with aplomb" :-) Congratulations mate',
#   'Positive'),
#  ('@Markisskill didnt have the money at the time :( but would have',
#   'Negative'),
#  ('penge bestfriend :( #PSYGustoKita', 'Negative'),
#  ('@S0LV0 @omgNova @sonicretro Sorry!!! :(', 'Negative'),
#  ('I love my relationship :-) http://t.co/pVd5n3deoS', 'Positive'),
#  ('Foot pain just woke me up, nooooooo :(', 'Negative'),
#  ('My stomach is killing me :(', 'Negative'),
#  ('@infinityandbion funny mo :(', 'Negative'),
#  ('No of Billionaires (1645) in the world is more than No of Islands (1190) in Maldives. Dheena, Fasgadah Alvadhaau. :( https://t.co/4hAaC51bQz',
#   'Negative'),
#  ("@captaintn @JAYBUMAOMGY @satgotlloco @longlivesamd don't kick my bae :((",
#   'Negative'),
#  ('wtf stereo kicks :(', 'Negative'),
#  ('Give it all. :D', 'Positive'),
#  ('@thefreejinn @Blush_Channel deleicious food followed by sound 8 hrs. sleep for which i never get time :(',
#   'Negative'),
#  ('Confession :) nice', 'Positive'),
#  ('Nominiere @Red_Foxus @ZeX_Aquila und @B3comeLegend :)', 'Positive'),
#  ('I had a dream that I met Karlie Kloss &amp; she was so so sweet &amp; she wanted to take like a bunch of goofy photos with me. :(',
#   'Negative'),
#  ('Start middle and finished :) http://t.co/k715EtENT3', 'Positive'),
#  ('Gtg again :(((', 'Negative'),
#  ('@keelzy81 you know, I actually got suspended for smoking, can you believe it? Teenage me was such a fucking cliche :(',
#   'Negative'),
#  ('My birthday is a week today! :D', 'Positive'),
#  ('pamper day :) (@ Great Cuts Angelo Justin in Quezon City) https://t.co/pWvwQ8xg1C',
#   'Positive'),
#  ('Dang starting next week I have "work" :(', 'Negative'),
#  ('not feeling well :(', 'Negative'),
#  ('@MaverickLowe @CTC_Cyclists Yep but oh so common of infra, still being rolled out now, in this Country :-(',
#   'Negative'),
#  ('@Aremay oh you and your FACTS :p', 'Positive'),
#  ('@Dodi_Behiri congrats :) exciting', 'Positive'),
#  ('Best ATP players (Wimbledon 2015): Federer, Nadal, Monfils.\nMost handsome ATP players: Cilic, Cilic, Cilic. :)',
#   'Positive'),
#  ("@mz_chocl8bear dude I didn't get the dm :(", 'Negative'),
#  ('watching where we are concert film :)', 'Positive'),
#  ("@NEEDTOBREATHE love you..sad I wasn't up front :(", 'Negative'),
#  ('I wish my Parents would live forever. :(', 'Negative'),
#  ('@bunbun78 great shot - safe trip back to HK - love that place :-)',
#   'Positive'),
#  ('Nice weather if ur a fucking duck :(', 'Negative'),
#  ('@HostMyOffice @NigelPWhittaker @lemezma @TWBC_Business @_TheBunkerJL Right back atchya!  Have a great day everyone :)',
#   'Positive'),
#  ('@BEINGASANOCEAN please come to San Antonio again soon :(', 'Negative'),
#  ('BUT I HAVE IT ALREADY HE SOLD IT LIKE 2 WEEKS AGO :( https://t.co/FtgBvFN30O',
#   'Negative'),
#  ('Looking for fun? SNAPCHAT - jennyjean22 #snapchat #hornykik #ebony #trade #models #elfindelmundo #webcamsex :( http://t.co/s0wlxvFdeV',
#   'Negative'),
#  ('@baileymac02 miss youu :(', 'Negative'),
#  ('i wanna go to vidcon :(', 'Negative'),
#  ('Spent the whole day watching videos of #AlDub over and over again. Ang cute nila! :( I ship. @aldenrichards02  @mainedcm',
#   'Negative'),
#  ('maroon cocktail dresses http://t.co/Ioj5YzNRwu #MidiDresses for @filipinaniah :) http://t.co/Vj1U5fIzBw',
#   'Positive'),
#  ('@justinbieber :) back at ya', 'Positive'),
#  ('Had my few hours beauty sleep, ready for few hours at Pure Organisation Offices then weekend off :-) Oh and...I... http://t.co/dCNoUH9s5R',
#   'Positive'),
#  ('Aishhh... the stream getting slow and more viewer... :((*', 'Negative'),
#  ('Towering over the ladies. :) #tb #eid https://t.co/F7oS1h3Alz', 'Positive'),
#  ('@1017nelle aww bestfriend look at you :)', 'Positive'),
#  ('I want my phone baaack :(((', 'Negative'),
#  ('Not strong at moment... but me get better so can protect! :D', 'Positive'),
#  ('@RohYB_ @Glanny_ @_wattie yeah :(', 'Negative'),
#  ('@kiwivickiBSc @BrezzyHayter sadly must be :(', 'Negative'),
#  ('This is so me :-) http://t.co/9aqyX0UxuV', 'Positive'),
#  ('Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x11',
#   'Positive'),
#  ('@zayndrome i cant find it :(', 'Negative'),
#  ('#VictoriaSecret #store is #open in #Finland #Helsinki #airport . Got to get a plane ticket to somewhere :)',
#   'Positive'),
#  ('Soooo burnt.... :-(', 'Negative'),
#  ('@darrenwho_ why is naya there whats happening. my link keeps doing the spinny loading wheel but never playing anything :(',
#   'Negative'),
#  ('My summer sleep schedule is back :(((', 'Negative'),
#  ("@MonicaTerryEM I'll have a look in the library and book stores first anyway! :)",
#   'Positive'),
#  ("didn't bring key :(", 'Negative'),
#  ("@grace_phipps you're so inactive :((", 'Negative'),
#  ('@cottypne @PaulPNE70 @TrekkingPaul @charlvdh @FcPNE @PNEShirley @mandajohnstone @YvonneOrr @Gem_Pnefc @kimramshead morning Emma :)',
#   'Positive'),
#  ('is this better or should i just change it back omg :(', 'Negative'),
#  ('@lindseytsutsui AWW BUT ITS OK CUZ WE MAKE MISTAKES TOO :)', 'Positive'),
#  ("@ghostfinder no worries :) I don't blame you haha! X", 'Positive'),
#  ("@ealilovic Don't get your hope up, you must travel a million years to get there in the first place :) #fls #sorry",
#   'Positive'),
#  ("@annnalucz i'm not going :( kailan ba? may tix ka?", 'Negative'),
#  ('@Miss_Dyna_Mite hi 5 back to you :) :)', 'Positive'),
#  ('@Uber_AHM and I have it :) http://t.co/sWLUm7Vtrz', 'Positive'),
#  ('@MIKEYGEE110 I cant work out if this is sarcasm or not :), i know some Chelsea supports think hes useless but when he comes on he does ok.',
#   'Positive'),
#  ('Gutted for Reynold. The kind of desserts he has done this season :(',
#   'Negative'),
#  ('wwoooo late nite drawings everyone come watch :) https://t.co/iWTWzRFrKt',
#   'Positive'),
#  ("@indiaquinn I didnt see your/ millie's guinea pigs :((", 'Negative'),
#  ('@Wilpy1 Too late. :(', 'Negative'),
#  ('@LouiseR97054900 Happy Friday for you too :) @toonstra65 @_emeraldeye_  @lisamarti76 @Dahlizma  @miss_steele89 @LouMWrites @ASeguda',
#   'Positive'),
#  ('@sanahaq17 okay :D', 'Positive'),
#  ('WHY MUST THE VIDEO STOP THO :(', 'Negative'),
#  ('@kalourd you right...the sinuend is kak. Not working :(', 'Negative'),
#  ('@ihyrina i feel you girl. :(((', 'Negative'),
#  ('zzzz missed my stop :(', 'Negative'),
#  ('@lesholly20 @NorthEastHour you can Lesley :)', 'Positive'),
#  ('Scurri - the most agile #shipping solution available on the market. \nBook a free demo at http://t.co/AybllZWAqF :-) \n#retail #delivery #SME',
#   'Positive'),
#  ('@karinatuano shiiiit. Kamiss beh 😭😭 Thank you bby. :* I miss you :( love you mwa.',
#   'Negative'),
#  ("@GeekPlanetDave He said you've got too much time on your hands :( #RogerWatch",
#   'Negative'),
#  ('@Movieespeech Hey and thank you for following :)', 'Positive'),
#  ('@devjoshi10 dev I.m verry sad cause you on twitter and than me off :(',
#   'Negative'),
#  ("@fwmkian Happy Birthday Gorgeous Hopefully i'll see you at the fair :)",
#   'Positive'),
#  ('@DrakesRest likewise on the incredible food folks - keep up the great work! :D',
#   'Positive'),
#  ('If you see #ZephBot , this is a bot :p', 'Positive'),
#  ('@GhalibMK Not sure. Just need to firm stuff up in my diary but will let you know. Potentially August :)',
#   'Positive'),
#  ('@hewitsonwalker thanks for the follow have a great day :)', 'Positive'),
#  ('@CathsStrawberry I thought your work was  seasonal, you will have really busy days. Ok so deal for weekends and in your toilet breaks :p',
#   'Positive'),
#  ('#ShareTheLove @hotwifecleo @_PetPuK_ @omaro22omaro for being top HighValue members this week :)',
#   'Positive'),
#  ('lol! selos :)) https://t.co/X8nV7tp9S8', 'Positive'),
#  ('only I would drop 10 wine bottles &amp; spill some of the wine all over myself @ work :-)',
#   'Positive'),
#  ('Seventh spot na lang :( #OTWOLGrandTrailer', 'Negative'),
#  ('@Afl2277 thanks. :)', 'Positive'),
#  ('Hi BAM ! @BarsAndMelody \nCan you follow my bestfriend @969Horan696 ? \nShe loves you a lot :) \nSee you in Warsaw &lt;3 \nLove you &lt;3 x7',
#   'Positive'),
#  ("@JacobAndrade33 @MillerKaapke can we all be gay together at least. Don't leave me out alone :(",
#   'Negative'),
#  ('Snapchat me guys - IvyPowel19 #snapchat #kik #chat #xxx #kikmeboys #newmusic #sexchat :) http://t.co/zhvSuU4H8M',
#   'Positive'),
#  ("Let's play this :) http://t.co/mJRbZhkOA9", 'Positive'),
#  ('@nerazktm I have no idea :) cc @ameetdhakal  :)', 'Positive'),
#  ("@qistnaa for once i used 'u' :-)", 'Positive'),
#  ('@revivalcth 2 OF THOSE TIMES ITS BEEN OUT OF MY CONTROL :( AND I HAVENT BEEN ABLE TO :(:( i miss it :(:(',
#   'Negative'),
#  ("@_sarah_mae omg you can't just tell this and don't say more :p can't wait to know !!!! ❤️",
#   'Positive'),
#  ('@obscurro hmm is this tweet antagonistic? I literally do sing the obs song :(',
#   'Negative'),
#  ('almost 2/3 done with this. Sa lahat ng araw, bakit naging saturday pa finals ko :((',
#   'Negative'),
#  ('@OrbaniDiana ok good to hear. Keep it up! :-)', 'Positive'),
#  ('7pm on a Friday and I am dead :(', 'Negative'),
#  ("Future didn't show up :(", 'Negative'),
#  ('wifi is fast af at my school even faster than at home :((', 'Negative'),
#  ('what happened to gyu :-(', 'Negative'),
#  ("I should've been asleep 3 or 4 hours ago :(", 'Negative'),
#  ('guys stop please :(\n\n#ZaynIsComingBackOnJuly26 http://t.co/4gbLRYagWh',
#   'Negative'),
#  ("@charmsham i can't able to view pics da.. :( wat pic is this?", 'Negative'),
#  ('As RBI in making of caged parrot. \n1ly election commission, CAG r left, once d power is striped gujarat model will complete \nVery sad :(',
#   'Negative'),
#  ("@zoomtv @kdruls @mishrasugandha is your channel's show #PlanetBollywoodNews 's full epi available online?! :)",
#   'Positive'),
#  ("@Worthless_Bums SM1 wasn't that bad. I mean, I only got mutilated by a robot that shot through a wall I didn't know could be destroyed...&gt;:(",
#   'Negative'),
#  ("Training felt harder today..that's what happens going to bed too late n waking up earlier than usual :( #RatBagLater",
#   'Negative'),
#  ('Bullshit......:((', 'Negative'),
#  ('SUNGGYU FELL ON STAGE :(', 'Negative'),
#  ('@PiperDonut thanks haha but i only tell the truth to you :):):)',
#   'Positive'),
#  ("@sneaksontaylor no it's not :(", 'Negative'),
#  ('shakes my head repeatedly. nu-uh, jace, i love you the mostest! &gt; : (',
#   'Negative'),
#  ('@EdeLabayog yup thank you! Huhu mahirap? :(', 'Negative'),
#  ('"@justinbieber: :)"why baby?😘😘😘', 'Positive'),
#  ("@tessasmith4evr @BlueBellEMS we'll steel some from the @BlueBellEMS next Wednesday and see what it's like!:)",
#   'Positive'),
#  ("Sterling's gonna be so good at City :(", 'Negative'),
#  ('@Woodgate @littlewok Enjoy :)', 'Positive'),
#  ('@martyabbott936 @HomewoodSteve @Dazz747 @Eddie_Aviation @plane_spotters @pilotsimon208 @NicolaNeyhaul @thispiggy Thanks Marty. Gd weekend :)',
#   'Positive'),
#  ('@bridgetminamore did it thrice :)', 'Positive'),
#  ("@Kandelamison You're welcome - thanks for following back! :-)", 'Positive'),
#  ('Off to somewhere later :)))', 'Positive'),
#  ("Looking for offline #TheSims4 game guides? We've got you covered! :) http://t.co/hR3NFHrO4J",
#   'Positive'),
#  ('@HiddlesSupport So much :(', 'Negative'),
#  ('@nws1886 Yeah ... I got this shit in a bag. "Laughing in the face of anxiety" har har har. I think ! :( how\'s it go, chum? Out this weekend?',
#   'Negative'),
#  ('we just face timing :) http://t.co/UoqAstlhxO', 'Positive'),
#  ('@Aimeemuthoni I miss you :( Still in Juja?', 'Negative'),
#  ('Leggete qui per la chat Larry :)\n-Mar http://t.co/gEj5b3qPqS', 'Positive'),
#  ('thirdwheeling these lovebirds :( http://t.co/kMrSV4YCz0', 'Negative'),
# ...
#  ("Naw :( Deep Dreamed my novel hoping there'd be invisible page beasts scuttling around but there's just worm tracks http://t.co/feTHZT8bfs",
#   'Negative'),
#  ('going home soon :(', 'Negative'),
#  ('@RFarghaly123 FOLLOWED ME THANKS, AND\n@justinbieber PLEASE FOLLOWED ME TOO :(',
#   'Negative'),
#  ('Such a positive, beautiful light :( #RIPSandraBland #JusticeForSandraBland #SandraBland  https://t.co/GP21Mwg1Os',
#   'Negative'),
#  ("@booogley because you're breaking out of your shell :-)", 'Positive'),
#  ('sudden mood-dump :(', 'Negative'),
#  ('Yeah I screwed up again :-( and this time I thought I did something good good',
#   'Negative'),
#  ('Inside Out will happen today! :D', 'Positive'),
#  ('@noodles78 Message us right here Nicola and we can forward this on :) Brighten up our day :D Helen',
#   'Positive'),
#  ('@MyriadPhoto Thanks for the retweet :)', 'Positive'),
#  ("@lancepriebe Is there any chance you could add a keybind feature to Wild Warfare? Because I can't change my controlls so I can't play.. :(",
#   'Negative'),
#  ('@JackJcnes text: :( why', 'Negative'),
#  ('Heeeeyyy. Can all of you follow my fan account? @KINGT0MLINS0N \n\nThank you! :)',
#   'Positive'),
#  ("They didn't care that I was a Muslim :(", 'Negative'),
#  ('I miss Geneva so much! England aint got half the sun :(', 'Negative'),
#  ("https://t.co/Y43d1EwWTw #MadonnaMadeMTV C'mon, ur turn #MadonnaFamily #MadonnaFans :) One more time, let's all do it. Just a few tweets each",
#   'Positive'),
#  ('@SANDEUL203092 fine!! :(', 'Negative'),
#  ('@sophiasam013 @leiwaleyn i hate you both :((((', 'Negative'),
#  ('THROWBACKS :( http://t.co/WEbrI8gAgM', 'Negative'),
#  ("@OscarTrue89 no sorry I'm fully booked :-( xx", 'Negative'),
#  ('@alma @iamrrr ON LOOP... Bad news for the people I have to provide feedback too though :(',
#   'Negative'),
#  ('just want to play video games/watch movies with someone :(', 'Negative'),
#  ("I can't sleep :( http://t.co/7IiyoPYtXl", 'Negative'),
#  ("she's so cute :( http://t.co/BtE6DMoxYT", 'Negative'),
#  ("@ddlovato @Vevo bad :( I don't like it. This video is  too many perverse.",
#   'Negative'),
#  ('@MandaAssa awww thanks hey, a million :). Enjoy your weekend hey',
#   'Positive'),
#  ('What could be more fun than a sexy girl? TWO sexy girls :) 👉 http://t.co/S7kW8WESbs 👈😘 http://t.co/p7EnTlcsum',
#   'Positive'),
#  ('#FollowFriday Thank you @TimModise @LifeWithThami @Mkokstad for being top influencers in my community this week :-)',
#   'Positive'),
#  ('I JUST WANT MYUNGSOO, GYU, HOYA AND YEOL FOR ONCE :((', 'Negative'),
#  ('@laineyni @s_geary1 @susie22784334 @sharont2501 @britvix @vanessaclark11 @Wils21568249 @wolfenskjerven Same to you and everyone else.:-) xx',
#   'Positive'),
#  ('@zaynmalik please come back! We Love You So Much! &lt;3 :( \n#ZaynComeBackTo1D \n#ZaynIsComingBackOnJuly26 \n#zayniscomingback',
#   'Negative'),
#  ("@PXC_Macavity In case you didn't.. it's on my Facebook wall. :p",
#   'Positive'),
#  ('All guys want from me is dick pics and all I want is to have a meaningful conversation about things we have in common :(((',
#   'Negative'),
#  ('FeyTyaz Follback ya :)', 'Positive'),
#  ("i'm so tired :(", 'Negative'),
#  ('i miss my king,future,boss, and RAIN :( http://t.co/RZTM0VKIlM',
#   'Negative'),
#  (':-( ugly af :-( https://t.co/bHIXkuNqPS', 'Negative'),
#  ('I cant stream :(', 'Negative'),
#  ('SNAPCHAT : ShoshannaVassil #snapchat #kik #addmeonsnapchat #dmme #xxx #mpoints #hotel :) http://t.co/Kne2p4yFUq',
#   'Positive'),
#  ("@peterpalmer52 Hi Peter, We've not had pens for 2 years now. We just can't get them. There's not even spares in the office anymore either :(",
#   'Negative'),
#  ('Best night of my life!!!:)', 'Positive'),
#  ('@mattbarker14 Nice to hear you want to switch to us :). Our Pro Kit would be the best choice for you if you follows this link it will',
#   'Positive'),
#  ('@Its__Tatiii You too girl hmu sometime :)', 'Positive'),
#  ('@Jussstify :( zokay (Russian accent)', 'Negative'),
#  ("@SP3CTACL3S she's my friend :(", 'Negative'),
#  ('@jaimelesgyozas ah mince :(', 'Negative'),
#  ('Thq a lot for Ur continous support @actor_jayamravi to Thalaivar @dhanushkraja bro:):):)',
#   'Positive'),
#  ('so teen top actually performed under the rain yesterday.... fk are they ok :((( but im still v proud of them la!!!',
#   'Negative'),
#  ('@ollyofficial how are you Olly? :)', 'Positive'),
#  ('I need a massage :((', 'Negative'),
#  ("@FTlove4good One more 'thank you' to FT fandom from my side too :)",
#   'Positive'),
#  ("@nottswcentre Those cakes look AMAZING! Can't believe I'm missing it! :(",
#   'Negative'),
#  ('@stairwaytoalex sorry for saying your leg black in a venomous way :-(',
#   'Negative'),
#  ('@natalielms95 @jxhun @SharonMelaniex  why is this so accurate :-((((',
#   'Negative'),
#  ('"zayn is coming back on july 26"\nsrsly guys? how many times did you say that?? :-((',
#   'Negative'),
#  ('@peter_osoro me too :-) ^Caro', 'Positive'),
#  ('@belittle4u  I may find this very confusing :)\n*just a simple wolf*',
#   'Positive'),
#  ('@ReetAwwsum Great! Did you reserve for Windows 10? :) ^MM', 'Positive'),
#  ('@halfwaytohemmo We do love to help! http://t.co/X31Iw7dile :) /E',
#   'Positive'),
#  ("@_pigglywiggly @Omundson The mango lassi's from Monty's are marvellous :D. Though I suspect that's not what you meant....",
#   'Positive'),
#  ("@JohnTorode1 @BBCOne @MasterChefUK think it'll be sam but would love it to be @Rylan !!  He's made the biggest improvement from the start :)",
#   'Positive'),
#  ('You always be part of me, I am part of you and defenitely...♬ @MOHDBINTANG :p',
#   'Positive'),
#  ('I want Yongbe green suede supreme hat :(', 'Negative'),
#  ('#FollowFriday @digitalplace2be @intlboost @_lafontpresse for being top supports in my community this week :)',
#   'Positive'),
#  ('@Murrayyyyyyyy aha yesss! Who are you most looking forward to seeing?:)',
#   'Positive'),
#  ('@akocjermy19  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)',
#   'Positive'),
#  ('@imdanielpadilla hi!!!!!! love u :( :(', 'Negative'),
#  ('"@TeamBaiLonaOFC: Rt to be in Bailona group chat , \n\nMention  @imJANExoxo to be approve FANBASE :)"',
#   'Positive'),
#  ('that means i will be on the low limit table for a while xD :((((',
#   'Negative'),
#  ('@bluexxdream i miss you :(', 'Negative'),
#  ('Still confused on what to enroll this sem. :(', 'Negative'),
#  ('@bsuzysk 404 not found! :(', 'Negative'),
#  ('@MissHayley1988 @djdarrenjones :( *hugs*', 'Negative'),
#  ('@Nobicate Doh! 500+ Subscribers are needed :) Please let us know once you reached this number.',
#   'Positive'),
#  ('I regret nothing :)', 'Positive'),
#  ('Today’s job (another facking #Intel). Extra mega careful not to get bent socket pins :-( #PCGaming #PCUpgrade http://t.co/VeJNS9FBfn',
#   'Negative'),
#  ('@OloapZurc yup. i think so too. gotta avoid BB and IC. I really hope they have a repack :(',
#   'Negative'),
#  ('@jvkho9997 thanks yots. Labyo miss you :((', 'Negative'),
#  ("@StephanieAlys That's great Stephanie! Good luck with your training :) #findyourfit",
#   'Positive'),
#  ('@MartinGarrix CAN YOU FOLLOW ME ALREADY :((', 'Negative'),
#  ('Feel free to share with others.  :-) http://t.co/c2W7znBQ0P', 'Positive'),
#  ('* ✫ ✧ ˚ @Louis_Tomlinson ✧ · ✵ ⊹\nThank you for always putting\na smile on my face\nMind following me? :)\nHave a nice day x\n1710',
#   'Positive'),
#  ('@labelsforlunch such a cute bag! :) #freebiefriday', 'Positive'),
#  ('Yasss. Still dont get paid til August 6th :( lol still got hella clothes though',
#   'Negative'),
#  ('@ShevoyzOfficial \n@MADrigaaaal  @TheConconFelix \n@Kalangitan  @khenlizardo  and Dan\nGod bless you all.  Meet and Greet soon :)',
#   'Positive'),
#  ('@JayMcGuiness  :-( please notice mew', 'Negative'),
#  ('@PetiteMistress DO IT! I want to start one for making small games, but I feel like I need to get a jump start before asking for support :(',
#   'Negative'),
#  ('@cliffords_ass @Michael5SOS awww... dont worry dear, you will get used to it :)',
#   'Positive'),
#  ('@ArrieBar @BBlogRT @FemaleBloggerRT Love it all :) wow!! Picked up a Cala brush myself the other day!',
#   'Positive'),
#  ("left @TheColtRising wasn't a good fit for the team, goodluck in the future guys! :)",
#   'Positive'),
#  ('SNAPCHAT : TammiRossM #snapchat #kikgirl #kikchat #wet #wife #indiemusic #sexy :( http://t.co/dEGAKDzsjN',
#   'Negative'),
#  ('@MartinaSancehz Jouch. Por que? :(', 'Negative'),
#  ('Horrible weather to be going to work in :(', 'Negative'),
#  ('I just wanna go to your house rn and give you a big big hug. :(((',
#   'Negative'),
#  ('Add me on Snapchat : NicoleaPage #snapchat #kiksex #kikmeboys #makeup #kikmeboys #free #camsex :( http://t.co/iVcyNmm8vP',
#   'Negative'),
#  ("@lunatroye but snow is cold and gross and ew it's just a big mess because everyone just scrapes it into piles anyway :(",
#   'Negative'),
#  ("@ZaynReport @MakeYouKnowLove what's mean? I don't understand nothing :(",
#   'Negative'),
#  ('@OTRJSJ offers you my mixtape. will you talk to me more now : ( suckmejimin.',
#   'Negative'),
#  ('I want IHOP :(', 'Negative'),
#  ('Have work in 5 hours... :(', 'Negative'),
#  ('@cshottubhire @whittakerdesig1 @GEM_Business67 @Oldham_Hour Tank u, have a great one hope ur busy :)',
#   'Positive'),
#  ('Those friends know themselves :)', 'Positive'),
#  ('@MariajoseCleri1 FOLLOWED ME THANKS, AND\n@justinbieber PLEASE FOLLOWED ME TOO :(',
#   'Negative'),
#  ("dude i'm so fckin okay with you avoiding me all over again :(", 'Negative'),
#  ('So many people are dying while returning to Dhaka after celebrating Eid. :(\n\nGuess traffic jam is in fact a... http://t.co/lR3JUxPtJG',
#   'Negative'),
#  ('I hit my thumb :(.', 'Negative'),
#  ('Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/kjV6NWyPKo.',
#   'Positive'),
#  ("@KEEMSTARx yo dude. Fancy helping a fan out? I wanna grow a yt channel but can't purchase an Elgato :(",
#   'Negative'),
#  ('@bekhyungh @cunyelo pinter :-)', 'Positive'),
#  ('♛♛♛\n》》》》 \nI LOVE YOU SO MUCH.\nI BELİEVE THAT HE WİLL FOLLOW.\nPLEASE FOLLOW ME PLEASE JUSTİN @justinbieber :( x15.345\n》》》》ＳＥＥ ＭＥ\n♛♛♛',
#   'Negative'),
#  ('@laurenecurrann snakes on you??:(', 'Negative'),
#  ('@cyrilthecynic Hey, for any further information you can give Argos card a ring on 0345 640 70 70 :)\n\nNad',
#   'Positive'),
#  ('@courtneypink07 Haha I know right :( He needs a good talking to that Xur does!',
#   'Negative'),
#  ('Never seeing your dad until midnight bc he worked hard as fuck :( #GrowingUpPoor',
#   'Negative'),
#  ('I think I might endit my London photos &amp; vids into a Minecon &amp; a London video :) just to look at and remember the great time. *-*',
#   'Positive'),
#  ("@IAmDaniel0 well my kids broke up now so don't have to get up early :)",
#   'Positive'),
#  ('@danvpeterson Enjoy! And sorry about my hastily typed message! :)',
#   'Positive'),
#  ('@_bushraaaaaa So tell me how it is that Whitey and his culture rules the world? :)',
#   'Positive'),
#  ("can't sleep, fmt 4 dat dm :)))", 'Positive'),
#  ("Bye Wellington, you've been awesome, I hope we meet again. :) http://t.co/m7p3IvKggR",
#   'Positive'),
#  ('Baby :( http://t.co/UR8ZwngzJZ', 'Negative'),
#  ("What the hell is going wrong :( I don't understand why people choose to hurt each other https://t.co/hIBjz4fC2r",
#   'Negative'),
#  ("There's a meeting on Sunday and genesis isn't back from Mexico yet :(",
#   'Negative'),
#  ('SNAPCHAT : TammiRossM #snapchat #kikgirl #kikchat #wet #wife #indiemusic #sexy :( http://t.co/IzW9wFL5Zv',
#   'Negative'),
#  ('Season 11 set ♡ Have a nice Friday #SPNFamily ! :)) #SPN11 #AlwaysKeepFighting #JaredPadalecki #JensenAckles http://t.co/mGAYutmknZ',
#   'Positive'),
#  ("@maggiemontalvan I knowwww my runny nose isn't letting me sleep :(",
#   'Negative'),
#  ('@proudtobangkiki thanks :) #CJRadaCOMATEada', 'Positive'),
#  ('i dont know :(', 'Negative'),
#  ('Rettweet :-) http://t.co/zBOvLw0y5S', 'Positive'),
#  ('@eyeammarkk omg :( not gonna happen , yeah we wish..', 'Negative'),
#  ('@DanLauraCurtis  Get well soon Dan. and big hugs :)', 'Positive'),
#  ('Gamer Follow Train!\nFollow Me\nRetweet this\nFollow all who retweeted\nGain active followers :) 110',
#   'Positive'),
#  ('Lol the person i want to hug i cant :( lmbo dangit i miss people to much , cant help it though',
#   'Negative'),
#  ('@grlwthdragontat @leokalyan awesome! :)', 'Positive'),
#  ('Thanks Kalin :) http://t.co/ihELksfJjT', 'Positive'),
#  ("@NautiPawz Thankies! :D It's fucking hot! :D xx", 'Positive'),
#  ("WHY..... :(( not that I hate jong or dongwoo is just that all the photocards I've been getting is WH, DW &amp; SJ http://t.co/zEQNiFVHUT",
#   'Negative'),
#  ('@hwsoh thanks bro :D', 'Positive'),
#  ('i love you :(  http://t.co/1q9EZyGWXI', 'Negative'),
#  ('one of my favourite mutuals just unfollowed me :((', 'Negative'),
#  ('some girl came up to me and was like "you are so beautiful :-(" I want to dieididieieiei she\'s so cute',
#   'Negative'),
#  ('Nirame ya geng :( (with fikri, Anna, and 6 others at Tirtagangga Hotel) — https://t.co/46fL7vHiL3',
#   'Negative'),
#  ("If you're reading this, you're beautiful. \nLike this if you just read this :)",
#   'Positive'),
#  ('http://t.co/GYecoPRjXm bring you :) Boatbound Brings Luxury Yachting To The Masses - http://t.co/QaIPTxrUKm #tech /via @BuzzFeed',
#   'Positive'),
#  ('glad you &lt;3 it :) @Skythedeath', 'Positive'),
#  ("And he didn't even get to spend much time  with him :(( and he loses him, I wish anything could've happened if it mean Sirius could stay +",
#   'Negative'),
#  ('@HRLori Thanks Lori! :)', 'Positive'),
#  ("The moment I decide to log onto the account I haven't been on in years is the moment I saw the best thing ever :) http://t.co/pu6B5jodur",
#   'Positive'),
#  ('@binkle yeah really I shoulda had my hippo ones on :)', 'Positive'),
#  ('i have to go :(', 'Negative'),
#  ('@jonny_ives we saw this and thought you might need an upgrade as the girls are getting bigger :) http://t.co/AzDWGWAPBb',
#   'Positive'),
#  ("@SMARTCares it wasn't indicated on the SMS I received. :(", 'Negative'),
#  ('An apartment makeover? http://t.co/ctLa1jppdb great ideas for factory living :)',
#   'Positive'),
#  ('Anybody here with a collection of all Suits episodes from all seasons? Pa-copy. :(',
#   'Negative'),
#  ('#FollowFriday @CCIdeLYON @CCI_95 @CPNERI_ESIGROUP for being top engaged members in my community this week :)',
#   'Positive'),
#  ('@CaballeroSerena you actually need to stop tweeting and driving! :-)))))))',
#   'Positive'),
#  ('@eydiespi there is no surprise :(', 'Negative'),
#  ('@DoctorKarl the angels must have you confused with another doctor :) #besteverdoctorwhoepisode',
#   'Positive'),
#  ('I ATE YOUR LAST COOKIE SHIR0 &gt;:D', 'Positive'),
#  ('Dang that is some rad @AbzuGame #fanart! :D https://t.co/bI8k8tb9ht',
#   'Positive'),
#  ("@OTRADaily Hey it'd be great if you share my blog.. I started writing blogs :) check it out and let me know how's it https://t.co/gGs070b6BH",
#   'Positive'),
#  ('@sweettoothmarti should keep you going for a few mins lol :-)))))',
#   'Positive'),
#  ('first time to go to school without my bracelets :(( it feels odd',
#   'Negative'),
#  ('who cares? :D haha', 'Positive'),
#  ('This is great! Irish literature is really inaccessible to most of us without Irish :)',
#   'Positive'),
#  ('@DrtyChimichanga Awesome! :D', 'Positive'),
#  ("@sakuraflower20 why you're upset? Is that something wrong with me? :(",
#   'Negative'),
#  ("@annarlonsdale When she asked to go to the bathroom :-( I'm really enjoying the show though.",
#   'Negative'),
#  ("@oconnor_max YAY! Can't wait! Hope I can keep up - been swimming more than riding recently, but will do my best :)",
#   'Positive'),
#  ('@aangelayap easy :D', 'Positive'),
#  ('@jaimestein @nicolevanzanten @amberturnau woot!! Cool peeps :)',
#   'Positive'),
#  ("@ShahidsSuperFan Miss you too :( I'm so busy these week. How are you ?",
#   'Negative'),
#  ('its not the same. :(((((', 'Negative'),
#  ('@PlanetRockRadio Sam I have seen rush 19 times. Would have been 20 in Toronto until my flight was cancelled on day of the show :( stuart',
#   'Negative'),
#  ('Nooooooooo her last day is today :(', 'Negative'),
#  ('I have loved you since we were eighteen @iqbaale :)', 'Positive'),
#  ...]

# %%
from nltk.tokenize import word_tokenize

sample_text = "NLTK is a powerful library for NLP."
tokens = word_tokenize(sample_text)
print(tokens)
# Out:
# ['NLTK', 'is', 'a', 'powerful', 'library', 'for', 'NLP', '.']

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [word for word in tokens if word.lower() not in stop_words]

filtered_tokens = remove_stopwords(tokens)
print(filtered_tokens)
# Out:
# ['NLTK', 'powerful', 'library', 'NLP', '.']

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(stemmed_tokens)
print(lemmatized_tokens)
# Out:
# ['nltk', 'power', 'librari', 'nlp', '.']
# ['NLTK', 'powerful', 'library', 'NLP', '.']

# %%
from nltk.probability import FreqDist

all_words = [word.lower() for tweet in tweets for word in word_tokenize(tweet)]
all_words_freq = FreqDist(all_words)

# Select the top 2000 words as features
word_features = list(all_words_freq.keys())[:2000]

def document_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# Create feature sets for training and testing
feature_sets = [(document_features(word_tokenize(tweet)), label) for (tweet, label) in zip(tweets, labels)]
train_set, test_set = feature_sets[1000:], feature_sets[:1000]

# %%
from nltk.classify import NaiveBayesClassifier

classifier = NaiveBayesClassifier.train(train_set)

# %%
import nltk.classify.util

accuracy = nltk.classify.util.accuracy(classifier, test_set)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 99.30%

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#              contains()) = True           Positi : Negati =     68.0 : 1.0
#              contains(() = True           Negati : Positi =     64.8 : 1.0
#            contains(sad) = True           Negati : Positi =     27.1 : 1.0
#           contains(miss) = True           Negati : Positi =     20.4 : 1.0
#          contains(loves) = True           Positi : Negati =     18.2 : 1.0
#      contains(community) = True           Positi : Negati =     17.6 : 1.0
#        contains(arrived) = True           Positi : Negati =     17.0 : 1.0
#           contains(blog) = True           Positi : Negati =     15.6 : 1.0
#           contains(glad) = True           Positi : Negati =     15.6 : 1.0
#         contains(thanks) = True           Positi : Negati =     12.7 : 1.0

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
text = "NLTK is a great library for text processing!"
sentiment_scores = sid.polarity_scores(text)
print(sentiment_scores)
# Out:
# {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.6588}

# %%
# Classifying a new sentence using the trained classifier
test_sentence = "This is an amazing movie!"
test_features = document_features(word_tokenize(test_sentence))
classification = classifier.classify(test_features)
print(classification)
# Out:
# Positive
