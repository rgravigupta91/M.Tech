# %% [markdown]
# #### Import the necessary libraries.

# %%
import pandas                             as      pd
import numpy                              as      np
import matplotlib.pyplot                  as      plt
import seaborn                            as      sns
from   IPython.display                    import  display
from   pylab                              import  rcParams 
from   datetime                           import  datetime, timedelta
from statsmodels.tsa.stattools            import  adfuller
from statsmodels.tsa.stattools            import  pacf
from statsmodels.tsa.stattools            import  acf
from statsmodels.graphics.tsaplots        import  plot_pacf
from statsmodels.graphics.tsaplots        import  plot_acf
from statsmodels.graphics.gofplots        import  qqplot
from statsmodels.tsa.seasonal             import  seasonal_decompose
#from statsmodels.tsa.arima_model          import  ARIMA
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax   import  SARIMAX
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# #### Read the data set in a Time Series with proper Time frequency or period.

# %%
df = pd.read_csv('MaunaLoa.csv',parse_dates=['Year-Month'],index_col='Year-Month')
df.head(15)
# Out:
#             CO2 ppm
# Year-Month
# 1965-01-01   319.32
# 1965-02-01   320.36
# 1965-03-01   320.82
# 1965-04-01   322.06
# 1965-05-01   322.17
# 1965-06-01   321.95
# 1965-07-01   321.20
# 1965-08-01   318.81
# 1965-09-01   317.82
# 1965-10-01   317.37
# 1965-11-01   318.93
# 1965-12-01   319.09
# 1966-01-01   319.94
# 1966-02-01   320.98
# 1966-03-01   321.81

# %% [markdown]
# # Plot the Time Series Data.

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,8

# %%
df.plot();
#plt.ylim(0,400)
plt.grid()

# %% [markdown]
# # Plot a boxplot to understand the variation of Carbon Dioxide in parts per million with respect to months across years.

# %%
sns.boxplot(x=df.index.month,y=df['CO2 ppm'])
plt.grid();

# %% [markdown]
# # Plot a graph of monthly Carbon Dioxide in parts per million across years.

# %%
monthly_co2ppm_across_years = pd.pivot_table(df, values = 'CO2 ppm', columns = df.index.year, sort=False, index = df.index.month_name())
monthly_co2ppm_across_years
# Out:
# Year-Month    1965    1966    1967    1968    1969    1970    1971    1972  \
# Year-Month
# January     319.32  319.94  321.65  321.88  323.40  324.60  326.12  326.93
# February    320.36  320.98  321.81  322.47  324.21  325.57  326.61  327.83
# March       320.82  321.81  322.36  323.17  325.33  326.55  327.16  327.95
# April       322.06  323.03  323.67  324.23  326.31  327.80  327.92  329.91
# May         322.17  323.36  324.17  324.88  327.01  327.80  329.14  330.22
# June        321.95  323.11  323.39  324.75  326.24  327.54  328.80  329.25
# July        321.20  321.65  321.93  323.47  325.37  326.28  327.52  328.11
# August      318.81  319.64  320.29  321.34  323.12  324.63  325.62  326.39
# September   317.82  317.86  318.58  319.56  321.85  323.12  323.61  324.97
# October     317.37  317.25  318.60  319.45  321.31  323.11  323.80  325.32
# November    318.93  319.06  319.98  320.45  322.31  323.99  325.10  326.54
# December    319.09  320.26  321.25  321.92  323.72  325.09  326.25  327.71
#
# Year-Month    1973    1974    1975    1976    1977    1978    1979    1980
# Year-Month
# January     328.73  329.45  330.45  331.63  332.81  334.66  335.89  337.81
# February    329.69  330.89  330.97  332.46  333.23  335.07  336.44  338.16
# March       330.47  331.63  331.64  333.36  334.55  336.33  337.63  339.88
# April       331.69  332.85  332.87  334.45  335.82  337.39  338.54  340.57
# May         332.65  333.28  333.61  334.82  336.44  337.65  339.06  341.19
# June        332.24  332.47  333.55  334.32  335.99  337.57  338.95  340.87
# July        331.03  331.34  331.90  333.05  334.65  336.25  337.41  339.25
# August      329.36  329.53  330.05  330.87  332.41  334.39  335.71  337.19
# September   327.60  327.57  328.58  329.24  331.32  332.44  333.68  335.49
# October     327.29  327.57  328.31  328.87  330.73  332.25  333.69  336.63
# November    328.28  328.53  329.41  330.18  332.05  333.59  335.05  337.74
# December    328.79  329.69  330.63  331.50  333.53  334.76  336.53  338.36

# %%
monthly_co2ppm_across_years.plot()
plt.grid()
plt.legend(loc='best');

# %% [markdown]
# # Decompose the Time Series to understand the various components.

# %%
decomposition = seasonal_decompose(df,model='additive')
#decomposition.observed
#decomposition.seasonal
#decomposition.trend
#decomposition.trend.head(12)
decomposition.plot();

# %% [markdown]
# ## stationarity test

# %%
sns.boxplot(x=df.index.year,y=df['CO2 ppm'])
plt.grid();

# %%
observations= df
test_result = adfuller(observations)

# %%
test_result
# Out:
# (1.2696771490032237,
#  0.9964336403294772,
#  12,
#  179,
#  {'1%': -3.4674201432469816,
#   '5%': -2.877826051844538,
#   '10%': -2.575452082332012},
#  144.00145013189137)

# %% [markdown]
# ## applying differencing

# %%
df_diff = df.diff(periods=1).dropna()
observations= df_diff.values
test_result = adfuller(observations)
test_result
# Out:
# (-4.750106971676847,
#  6.768699865173965e-05,
#  11,
#  179,
#  {'1%': -3.4674201432469816,
#   '5%': -2.877826051844538,
#   '10%': -2.575452082332012},
#  144.25602170016555)

# %% [markdown]
# # Check the ACF and PACF of the training data.

# %%
plot_acf(df,lags=30);

# %%
plot_pacf(df);

# %%
plot_acf(df_diff);
#acf(df_diff)
#acf(df_diff,nlags=36)

# %%
#partial auto co-relation
plot_pacf(df_diff);

# %% [markdown]
# ## Train-Test split

# %%
train_end=datetime(1978,12,1)
test_end=datetime(1980,12,1)

# %%
train             = df[:train_end] 
test              = df[train_end + timedelta(days=1):test_end]

# %% [markdown]
# ## Selecting an order of ARIMA model for data with the lowest Akaike Information Criteria (AIC).

# %%
import itertools
p = q = range(0, 4)
d= range(1,2)
pdq = list(itertools.product(p, d, q))
print('parameter combinations for the Model')
for i in range(1,len(pdq)):
    print('Model: {}'.format(pdq[i]))
# Out:
# parameter combinations for the Model
# Model: (0, 1, 1)
# Model: (0, 1, 2)
# Model: (0, 1, 3)
# Model: (1, 1, 0)
# Model: (1, 1, 1)
# Model: (1, 1, 2)
# Model: (1, 1, 3)
# Model: (2, 1, 0)
# Model: (2, 1, 1)
# Model: (2, 1, 2)
# Model: (2, 1, 3)
# Model: (3, 1, 0)
# Model: (3, 1, 1)
# Model: (3, 1, 2)
# Model: (3, 1, 3)

# %%
dfObj1 = pd.DataFrame(columns=['param', 'AIC'])
dfObj1
# Out:
# Empty DataFrame
# Columns: [param, AIC]
# Index: []

# %%
for param in pdq:
            try:
                mod = ARIMA(train, order=param)
                results_Arima = mod.fit()
                print('ARIMA{} - AIC:{}'.format(param, results_Arima.aic))
                dfObj1 = dfObj1.append({'param':param, 'AIC': results_Arima.aic}, ignore_index=True)

            except:
                continue
# Out:
# ARIMA(0, 1, 0) - AIC:521.6866087381227
# ARIMA(0, 1, 1) - AIC:427.2089971236799
# ARIMA(0, 1, 2) - AIC:386.71116114025926
# ARIMA(0, 1, 3) - AIC:370.1183497636364
# ARIMA(1, 1, 0) - AIC:412.1550050106317
# ARIMA(1, 1, 1) - AIC:394.2494988510245
# ARIMA(1, 1, 2) - AIC:379.5240045466983
# ARIMA(1, 1, 3) - AIC:372.0013093529383
# ARIMA(2, 1, 0) - AIC:373.2794540954644
# ARIMA(2, 1, 1) - AIC:332.32841192201295
# ARIMA(2, 1, 2) - AIC:333.9885262034079
# ARIMA(2, 1, 3) - AIC:336.23080880420673
# ARIMA(3, 1, 0) - AIC:356.01656397685235
# ARIMA(3, 1, 1) - AIC:334.0121904477379
# ARIMA(3, 1, 2) - AIC:335.5236233647461
# ARIMA(3, 1, 3) - AIC:337.0482811392801

# %%
dfObj1.sort_values(by=['AIC'])
# Out:
#         param         AIC
# 9   (2, 1, 1)  332.328412
# 10  (2, 1, 2)  333.988526
# 13  (3, 1, 1)  334.012190
# 14  (3, 1, 2)  335.523623
# 11  (2, 1, 3)  336.230809
# 15  (3, 1, 3)  337.048281
# 12  (3, 1, 0)  356.016564
# 3   (0, 1, 3)  370.118350
# 7   (1, 1, 3)  372.001309
# 8   (2, 1, 0)  373.279454
# 6   (1, 1, 2)  379.524005
# 2   (0, 1, 2)  386.711161
# 5   (1, 1, 1)  394.249499
# 4   (1, 1, 0)  412.155005
# 1   (0, 1, 1)  427.208997
# 0   (0, 1, 0)  521.686609

# %%
model = ARIMA(train, order=(2,1,3))

results_Arima = model.fit()

print(results_Arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                CO2 ppm   No. Observations:                  168
# Model:                 ARIMA(2, 1, 3)   Log Likelihood                -162.115
# Date:                Fri, 16 Dec 2022   AIC                            336.231
# Time:                        21:00:27   BIC                            354.939
# Sample:                    01-01-1965   HQIC                           343.824
#                          - 12-01-1978
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4422      0.089     16.157      0.000       1.267       1.617
# ar.L2         -0.7611      0.089     -8.548      0.000      -0.936      -0.587
# ma.L1         -0.7110      0.124     -5.745      0.000      -0.954      -0.468
# ma.L2          0.0986      0.120      0.820      0.412      -0.137       0.334
# ma.L3         -0.1859      0.102     -1.816      0.069      -0.387       0.015
# sigma2         0.4028      0.045      8.871      0.000       0.314       0.492
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.79   Jarque-Bera (JB):                 0.91
# Prob(Q):                              0.37   Prob(JB):                         0.63
# Heteroskedasticity (H):               0.70   Skew:                             0.17
# Prob(H) (two-sided):                  0.19   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Predict on the Test Set using this model and evaluate the model on the test set using RMSE and MAPE

# %%
pred_start=test.index[0]
pred_end=test.index[-1]

# %%
ARIMA_predictions=results_Arima.predict(start=pred_start, end=pred_end)

# %%
ARIMA_predictions
# Out:
# 1979-01-01    335.746732
# 1979-02-01    336.092913
# 1979-03-01    335.948025
# 1979-04-01    335.475580
# 1979-05-01    334.904519
# 1979-06-01    334.440561
# 1979-07-01    334.206121
# 1979-08-01    334.221162
# 1979-09-01    334.421299
# 1979-10-01    334.698478
# 1979-11-01    334.945881
# 1979-12-01    335.091701
# 1980-01-01    335.113686
# 1980-02-01    335.034401
# 1980-03-01    334.903325
# 1980-04-01    334.774642
# 1980-05-01    334.688827
# 1980-06-01    334.663017
# 1980-07-01    334.691111
# 1980-08-01    334.751274
# 1980-09-01    334.816653
# 1980-10-01    334.865149
# 1980-11-01    334.885323
# 1980-12-01    334.877505
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
ARIMA_pred=ARIMA_predictions.cumsum()
#ARIMA_pred

# %%
plt.plot(train,label='Training Data')
plt.plot(test,label='Test Data')
plt.plot(test.index,ARIMA_predictions,label='Predicted Data - ARIMA')
plt.legend(loc='best')
plt.grid();

# %%
test.columns
# Out:
# Index(['CO2 ppm'], dtype='object')

# %%
test.head()
# Out:
#             CO2 ppm
# Year-Month
# 1979-01-01   335.89
# 1979-02-01   336.44
# 1979-03-01   337.63
# 1979-04-01   338.54
# 1979-05-01   339.06

# %%
ARIMA_predictions.head()
# Out:
# 1979-01-01    335.746732
# 1979-02-01    336.092913
# 1979-03-01    335.948025
# 1979-04-01    335.475580
# 1979-05-01    334.904519
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
ARIMA_predictions_df = pd.DataFrame(ARIMA_predictions)

# %%
ARIMA_predictions_df.head()
# Out:
#             predicted_mean
# 1979-01-01      335.746732
# 1979-02-01      336.092913
# 1979-03-01      335.948025
# 1979-04-01      335.475580
# 1979-05-01      334.904519

# %%
ARIMA_predictions_df['predicted_mean']
# Out:
# 1979-01-01    335.746732
# 1979-02-01    336.092913
# 1979-03-01    335.948025
# 1979-04-01    335.475580
# 1979-05-01    334.904519
# 1979-06-01    334.440561
# 1979-07-01    334.206121
# 1979-08-01    334.221162
# 1979-09-01    334.421299
# 1979-10-01    334.698478
# 1979-11-01    334.945881
# 1979-12-01    335.091701
# 1980-01-01    335.113686
# 1980-02-01    335.034401
# 1980-03-01    334.903325
# 1980-04-01    334.774642
# 1980-05-01    334.688827
# 1980-06-01    334.663017
# 1980-07-01    334.691111
# 1980-08-01    334.751274
# 1980-09-01    334.816653
# 1980-10-01    334.865149
# 1980-11-01    334.885323
# 1980-12-01    334.877505
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
residuals = test['CO2 ppm'] - ARIMA_predictions_df['predicted_mean']

# %%
qqplot(residuals,line="s");

# %%
from sklearn.metrics import  mean_squared_error

rmse = mean_squared_error(test['CO2 ppm'],ARIMA_predictions_df['predicted_mean'], squared=False)
 
print(rmse)
# Out:
# 3.371770506606991

# %%
def MAPE(y_true, y_pred):
    return np.mean((np.abs(y_true-y_pred))/(y_true))*100

# %%
mape=MAPE(test['CO2 ppm'].values,ARIMA_predictions_df['predicted_mean'].values)
print(mape)
# Out:
# 0.8234293516746082

# %% [markdown]
# ## SARIMA Model

# %% [markdown]
# ### we will find the model parameters based on AIC criteria. Parameters will be  generated using combination for the given range.

# %%
import itertools
p = q = range(0, 3)
d= range(1,2)
pdq = list(itertools.product(p, d, q))

model_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Model...')
print('Model: {}{}'.format(pdq[1], model_pdq[1]))
print('Model: {}{}'.format(pdq[1], model_pdq[2]))
print('Model: {}{}'.format(pdq[2], model_pdq[3]))
print('Model: {}{}'.format(pdq[2], model_pdq[4]))
# Out:
# Examples of parameter combinations for Model...
# Model: (0, 1, 1)(0, 1, 1, 12)
# Model: (0, 1, 1)(0, 1, 2, 12)
# Model: (0, 1, 2)(1, 1, 0, 12)
# Model: (0, 1, 2)(1, 1, 1, 12)

# %% [markdown]
# ### Creating an empty Dataframe with column names only where the model and AIC scores will be saved

# %%
dfObj2 = pd.DataFrame(columns=['param','seasonal', 'AIC'])
dfObj2
# Out:
# Empty DataFrame
# Columns: [param, seasonal, AIC]
# Index: []

# %%
import statsmodels.api as sm
for param in pdq:
    for param_seasonal in model_pdq:
        mod = sm.tsa.statespace.SARIMAX(train,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            
        results_SARIMA = mod.fit()
        print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_SARIMA.aic))
        dfObj2 = dfObj2.append({'param':param,'seasonal':param_seasonal ,'AIC': results_SARIMA.aic}, ignore_index=True)
# Out:
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:169.5026390080524
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:76.60024513106538
# SARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:63.668610704536704
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:101.77574384550147
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:73.06883156314025
# SARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:63.39376878404886
# SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:78.32111628951127
# SARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:64.7713520537352
# SARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:64.0921131510954
# SARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:165.13652038660632
# SARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:66.2925068981281
# SARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:62.33158586070941
# SARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:98.4577031121515
# SARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:64.95051921007558
# SARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:60.48473972992478
# SARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:76.1432098087794
# SARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:59.415580794585054
# SARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:63.916454064657806
# SARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:165.52202447881263
# SARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:67.80754692918605
# SARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:64.82791369532322
# SARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:100.45279055039194
# SARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:66.90306406064823
# SARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:62.44190308960396
# SARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:78.13595230505796
# SARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:61.284543153548455
# SARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:64.22810382240526
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:166.71196721930528
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:66.74512056438422
# SARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:59.09437708229308
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:91.95181129978829
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:66.92350170804289
# SARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:59.50468038015689
# SARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:76.34396285667928
# SARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:63.02895209586502
# SARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:61.47608564898898
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:159.2970284974985
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:67.96801084586008
# SARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:63.88068827888856
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:93.78365997726686
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:66.2892709378905
# SARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:61.582935118335485
# SARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:78.17392437930428
# SARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:65.21088854752632
# SARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:64.50516731803997
# SARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:160.17965598159998
# SARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:69.6643411824007
# SARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:64.33046908629771
# SARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:95.0924375305241
# SARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:67.90099617649611
# SARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:62.349389092510215
# SARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:79.89241270317318
# SARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:67.23190145250707
# SARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:66.30567077213675
# SARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:167.60617939467943
# SARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:68.71938205193956
# SARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:60.94622528549664
# SARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:93.7221425135238
# SARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:67.33617424424699
# SARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:61.478024694366894
# SARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:78.80874136375334
# SARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:70.4697026411195
# SARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:64.42240235695886
# SARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:165.63272977376948
# SARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:69.31315728886284
# SARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:66.2836894269787
# SARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:95.69274554310151
# SARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:68.58503083757529
# SARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:67.06909336976122
# SARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:80.73953855299169
# SARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:72.37659853691183
# SARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:83.77963419893653
# SARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:161.39936365747053
# SARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:69.82170512506086
# SARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:65.8936372691889
# SARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:95.99223454495859
# SARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:69.15503979581301
# SARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:63.402971100707774
# SARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:81.78476331678657
# SARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:69.68148164786038
# SARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:66.50054911853431

# %% [markdown]
# ### Sorting parameters for best AIC score

# %%
dfObj2.sort_values(by=['AIC'])
# Out:
#         param       seasonal         AIC
# 29  (1, 1, 0)  (0, 1, 2, 12)   59.094377
# 16  (0, 1, 1)  (2, 1, 1, 12)   59.415581
# 32  (1, 1, 0)  (1, 1, 2, 12)   59.504680
# 14  (0, 1, 1)  (1, 1, 2, 12)   60.484740
# 56  (2, 1, 0)  (0, 1, 2, 12)   60.946225
# ..        ...            ...         ...
# 18  (0, 1, 2)  (0, 1, 0, 12)  165.522024
# 63  (2, 1, 1)  (0, 1, 0, 12)  165.632730
# 27  (1, 1, 0)  (0, 1, 0, 12)  166.711967
# 54  (2, 1, 0)  (0, 1, 0, 12)  167.606179
# 0   (0, 1, 0)  (0, 1, 0, 12)  169.502639
#
# [81 rows x 3 columns]

# %%
model = sm.tsa.statespace.SARIMAX(train,
                                order=(1,1,0),
                                seasonal_order=(1,1,2,12),
                                )
model_Sarima = model.fit()
print(model_Sarima.summary())
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                 CO2 ppm   No. Observations:                  168
# Model:             SARIMAX(1, 1, 0)x(1, 1, [1, 2], 12)   Log Likelihood                 -42.065
# Date:                                 Fri, 16 Dec 2022   AIC                             94.131
# Time:                                         21:01:35   BIC                            109.348
# Sample:                                     01-01-1965   HQIC                           100.312
#                                           - 12-01-1978
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2664      0.072     -3.699      0.000      -0.408      -0.125
# ar.S.L12      -0.6905      0.613     -1.126      0.260      -1.893       0.512
# ma.S.L12      -0.3735      5.793     -0.064      0.949     -11.728      10.981
# ma.S.L24      -0.6217      3.922     -0.159      0.874      -8.308       7.065
# sigma2         0.0817      0.479      0.171      0.865      -0.858       1.021
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 0.97
# Prob(Q):                              0.87   Prob(JB):                         0.61
# Heteroskedasticity (H):               0.55   Skew:                             0.02
# Prob(H) (two-sided):                  0.03   Kurtosis:                         2.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
SARIMA_predictions=model_Sarima.predict(start=pred_start, end=pred_end)

# %%
plt.plot(train,label='Training Data')
plt.plot(test,label='Test Data')
plt.plot(test.index,SARIMA_predictions,label='Predicted Data - SARIMA')
plt.legend(loc='best')
plt.grid();

# %% [markdown]
# ### finding RSMA and MAPE

# %%
from sklearn.metrics import  mean_squared_error
rmse = mean_squared_error(test['CO2 ppm'],SARIMA_predictions, squared=False)
print(rmse)
# Out:
# 0.8213789499910458

# %%
mape = MAPE(test['CO2 ppm'],SARIMA_predictions)
print(mape)
# Out:
# 0.18461311230296018

# %%
model_Sarima.plot_diagnostics(figsize=(16, 8))
plt.show()

# %% [markdown]
# ## fitting model on whole data

# %%
model = sm.tsa.statespace.SARIMAX(df,
                                order=(1,1,0),
                                seasonal_order=(1,1,2,12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_Sarima = model.fit()
print(model_Sarima.summary())
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                 CO2 ppm   No. Observations:                  192
# Model:             SARIMAX(1, 1, 0)x(1, 1, [1, 2], 12)   Log Likelihood                 -39.857
# Date:                                 Fri, 16 Dec 2022   AIC                             89.714
# Time:                                         21:01:36   BIC                            104.899
# Sample:                                     01-01-1965   HQIC                            95.882
#                                           - 12-01-1980
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2668      0.085     -3.120      0.002      -0.434      -0.099
# ar.S.L12      -0.5808      0.223     -2.603      0.009      -1.018      -0.144
# ma.S.L12      -0.3017      0.240     -1.258      0.208      -0.771       0.168
# ma.S.L24      -0.4384      0.218     -2.010      0.044      -0.866      -0.011
# sigma2         0.0944      0.009     10.987      0.000       0.078       0.111
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                14.27
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             0.38
# Prob(H) (two-sided):                  0.68   Kurtosis:                         4.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Forecast with confidence interval

# %%
forecast = model_Sarima.forecast(steps=24)

# %%
forecast
# Out:
# 1981-01-01    339.589037
# 1981-02-01    340.167598
# 1981-03-01    341.227873
# 1981-04-01    342.311254
# 1981-05-01    342.846994
# 1981-06-01    342.507077
# 1981-07-01    341.130712
# 1981-08-01    339.208836
# 1981-09-01    337.517373
# 1981-10-01    337.486304
# 1981-11-01    338.716824
# 1981-12-01    339.895359
# 1982-01-01    340.994987
# 1982-02-01    341.593296
# 1982-03-01    342.692636
# 1982-04-01    343.751765
# 1982-05-01    344.284442
# 1982-06-01    343.940750
# 1982-07-01    342.554429
# 1982-08-01    340.615463
# 1982-09-01    338.924181
# 1982-10-01    338.987696
# 1982-11-01    340.205041
# 1982-12-01    341.323481
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
pred95 = model_Sarima.get_forecast(steps=24)

# %%
pred95=pred95.conf_int()

# %%
pred95
# Out:
#             lower CO2 ppm  upper CO2 ppm
# 1981-01-01     338.986505     340.191568
# 1981-02-01     339.420455     340.914740
# 1981-03-01     340.337379     342.118367
# 1981-04-01     341.302865     343.319642
# 1981-05-01     341.731827     343.962161
# 1981-06-01     341.294816     343.719339
# 1981-07-01     339.828498     342.432926
# 1981-08-01     337.822512     340.595159
# 1981-09-01     336.051755     338.982991
# 1981-10-01     335.945468     339.027141
# 1981-11-01     337.104273     340.329374
# 1981-12-01     338.214151     341.576567
# 1982-01-01     339.227026     342.762948
# 1982-02-01     339.748190     343.438402
# 1982-03-01     340.772170     344.613102
# 1982-04-01     341.759119     345.744410
# 1982-05-01     342.222055     346.346829
# 1982-06-01     341.810926     346.070573
# 1982-07-01     340.359234     344.749624
# 1982-08-01     338.356789     342.874138
# 1982-09-01     336.603763     341.244598
# 1982-10-01     336.607136     341.368256
# 1982-11-01     337.765820     342.644261
# 1982-12-01     338.826979     343.819983

# %%
axis = df.plot(label='Observed', figsize=(15, 8))
forecast.plot(ax=axis, label='Forecast', alpha=0.7)
axis.fill_between(forecast.index, pred95['lower CO2 ppm'], pred95['upper CO2 ppm'], color='k', alpha=.15)
axis.set_xlabel('Year-Months')
axis.set_ylabel('CO2 ppm')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # END
