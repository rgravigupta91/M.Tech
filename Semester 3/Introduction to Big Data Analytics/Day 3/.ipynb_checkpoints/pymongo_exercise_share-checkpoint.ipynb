# %%
from pymongo import MongoClient
from pprint import pprint

# %%
# 1. Connect to MongoD
client = MongoClient("mongodb://localhost:27017/")

# %%
# 2. Create or access the database
db=client["salesdb"]

# %%
# Create collection - salesdata_collection
salesdata = db["salesdata_collection"]

# insert one document in the collection
salesdata.insert_one({"sales_id":1,
"country":"India",
"Product_detail" : {"product_id": 100,
                    "Amount": 5000,"Vendor_code":13, 
                    "Vendor_description": "this vendor is expert in providing mobile phones"}})
# Out:
# InsertOneResult(ObjectId('680b13ba196ab22dc9801bdc'), acknowledged=True)

# %%
# To list all collections under db
db.list_collection_names()
# Out:
# ['salesdata_collection']

# %%
# To print multiple documents from the collection
for document in salesdata.find():
    pprint(document)
# Out:
# pymongo.collection.Collection

# %%
# Filter and find the given conditional document from the collection
query={"sales_id":1}
result=salesdata.find(query)
for i in result:
    pprint(i)
# Out:
# {'Product_detail': {'Amount': 5000,
#                     'Vendor_code': 13,
#                     'Vendor_description': 'this vendor is expert in providing '
#                                           'mobile phones',
#                     'product_id': 100},
#  '_id': ObjectId('680b13ba196ab22dc9801bdc'),
#  'country': 'India',
#  'sales_id': 1}

# %%
# manually inserting ObjectId also #  objectid is a 24-digit hexadecimal strings
from bson import ObjectId
result = salesdata.insert_one({"_id":ObjectId("5955f4bb212e8fb45ca200d0"),
"sales_id":2,
"country":"India",
"Product_detail" : {"product_id": 101,
                    "Amount": 6000,"Vendor_code":13, 
                    "Vendor_description": "this vendor is expert in providing mobile phones"}})

# %%
result.inserted_id
result.acknowledged
# Out:
# True

# %%
# What are the Advantages and disadvantages of including  _id:ObjectId ?
# Advantages - Automatic Uniqueness, Efficient Indexing, Time-based Component, No manual mgmt
# Disadvantages - Size, Lack of readability(Hexa), No precise timestamp (default every minute),
# No suitable for few distributed system

# %%
from random import randint

# %%
# Inserting multiple documents

productcollection = db['product_feedback']

productlist = []
product_name = ['Mobile','TV','Washing machine', 'Refrigerator', 'Microwave Oven','Induction cooker','AC']
company_name = ['LG', 'Samsung', 'Bosch','Siemens','Whirlpool','Electrolux','Haier','Videocon']
for x in range(1, 1001):
    sale = {
        'name' : product_name[randint(0, (len(product_name)-1))],
        'rating' : randint(1, 5),
        'brand' : company_name[randint(0, (len(company_name)-1))] 
    }
    productlist.append(sale)

print(productlist)
# Out:
# [{'name': 'Microwave Oven', 'rating': 5, 'brand': 'Haier'}, {'name': 'Refrigerator', 'rating': 2, 'brand': 'Bosch'}, {'name': 'Mobile', 'rating': 3, 'brand': 'Electrolux'}, {'name': 'Washing machine', 'rating': 2, 'brand': 'Siemens'}, {'name': 'AC', 'rating': 2, 'brand': 'Samsung'}, {'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}, {'name': 'Refrigerator', 'rating': 4, 'brand': 'Whirlpool'}, {'name': 'Induction cooker', 'rating': 3, 'brand': 'Samsung'}, {'name': 'Induction cooker', 'rating': 5, 'brand': 'Siemens'}, {'name': 'Washing machine', 'rating': 3, 'brand': 'Electrolux'}, {'name': 'AC', 'rating': 4, 'brand': 'Electrolux'}, {'name': 'TV', 'rating': 5, 'brand': 'Samsung'}, {'name': 'AC', 'rating': 1, 'brand': 'Siemens'}, {'name': 'Microwave Oven', 'rating': 2, 'brand': 'Bosch'}, {'name': 'Microwave Oven', 'rating': 4, 'brand': 'Samsung'}, {'name': 'Induction cooker', 'rating': 5, 'brand': 'Electrolux'}, {'name': 'Washing machine', 'rating': 3, 'brand': 'Videocon'}, {'name': 'Induction cooker', 'rating': 2, 'brand': 'Bosch'}, {'name': 'Induction cooker', 'rating': 3, 'brand': 'Samsung'}, {'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}, {'name': 'Mobile', 'rating': 3, 'brand': 'Bosch'}, {'name': 'Induction cooker', 'rating': 3, 'brand': 'Siemens'}, {'name': 'Washing machine', 'rating': 5, 'brand': 'Siemens'}, {'name': 'AC', 'rating': 4, 'brand': 'Whirlpool'}, {'name': 'Refrigerator', 'rating': 2, 'brand': 'Samsung'}, {'name': 'AC', 'rating': 2, 'brand': 'Samsung'}, {'name': 'AC', 'rating': 2, 'brand': 'Bosch'}, {'name': 'TV', 'rating': 1, 'brand': 'Electrolux'}, {'name': 'AC', 'rating': 1, 'brand': 'Bosch'}, {'name': 'AC', 'rating': 5, 'brand': 'LG'}, {'name': 'Induction cooker', 'rating': 4, 'brand': 'LG'}, {'name': 'Refrigerator', 'rating': 4, 'brand': 'Siemens'}, {'name': 'Washing machine', 'rating': 3, 'brand': 'LG'}, {'name': 'Mobile', 'rating': 3, 'brand': 'Videocon'}, {'name': 'TV', 'rating': 3, 'brand': 'Siemens'}, {'name': 'Mobile', 'rating': 1, 'brand': 'Haier'}, {'name': 'Microwave Oven', 'rating': 3, 'brand': 'Haier'}, {'name': 'TV', 'rating': 3, 'brand': 'LG'}, {'name': 'Refrigerator', 'rating': 2, 'brand': 'Videocon'}, {'name': 'Mobile', 'rating': 3, 'brand': 'Videocon'}, {'name': 'TV', 'rating': 3, 'brand': 'Whirlpool'}, {'name': 'TV', 'rating': 5, 'brand': 'Videocon'}, {'name': 'Induction cooker', 'rating': 1, 'brand': 'Whirlpool'}, {'name': 'Refrigerator', 'rating': 3, 'brand': 'Haier'}, {'name': 'Refrigerator', 'rating': 4, 'brand': 'Electrolux'}, {'name': 'Mobile', 'rating': 4, 'brand': 'Bosch'}, {'name': 'TV', 'rating': 1, 'brand': 'LG'}, {'name': 'Mobile', 'rating': 3, 'brand': 'Bosch'}, {'name': 'Refrigerator', 'rating': 2, 'brand': 'Electrolux'}, {'name': 'TV', 'rating': 2, 'brand': 'Bosch'}, {'name': 'Induction cooker', 'rating': 1, 'brand': 'LG'}, {'name': 'Microwave Oven', 'rating': 1, 'brand': 'Bosch'}, {'name': 'Refrigerator', 'rating': 3, 'brand': 'Bosch'}, {'name': 'TV', 'rating': 3, 'brand': 'Bosch'}, {'name': 'AC', 'rating': 5, 'brand': 'Bosch'}, {'name': 'Microwave Oven', 'rating': 2, 'brand': 'Whirlpool'}, {'name': 'AC', 'rating': 3, 'brand': 'Haier'}, {'name': 'Washing machine', 'rating': 3, 'brand': 'Haier'}, {'name': 'Induction cooker', 'rating': 3, 'brand': 'Videocon'}, {'name': 'AC', 'rating': 4, 'brand': 'Videocon'}, {'name': 'Washing machine', 'rating': 5, 'brand': 'Bosch'}, {'name': 'TV', 'rating': 3, 'brand': 'Samsung'}, {'name': 'Washing machine', 'rating': 2, 'brand': 'Videocon'}, {'name': 'Mobile', 'rating': 1, 'brand': 'Electrolux'}, {'name': 'AC', 'rating': 2, 'brand': 'Siemens'}, {'name': 'AC', 'rating': 4, 'brand': 'Videocon'}, {'name': 'Washing machine', 'rating': 5, 'brand': 'Samsung'}, {'name': 'Induction cooker', 'rating': 1, 'brand': 'Electrolux'}, {'name': 'AC', 'rating': 3, 'brand': 'LG'}, {'name': 'Induction cooker', 'rating': 5, 'brand': 'LG'}, {'name': 'Microwave Oven', 'rating': 1, 'brand': 'Siemens'}, {'name': 'Refrigerator', 'rating': 4, 'brand ...

# %%
result = productcollection.insert_many(productlist)

# %%
# 
for item in productcollection.find():
    pprint(item)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801bdd'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bde'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bdf'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801be0'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801be1'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801be2'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be3'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801be4'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801be5'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be6'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801be7'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801be8'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be9'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bea'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801beb'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bec'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bed'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801bee'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bef'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf0'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf1'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf2'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf3'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf4'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf5'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf6'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf7'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf8'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf9'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfa'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfb'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfc'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfd'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfe'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801bff'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c00'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c01'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c02'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c03'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c04'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c05'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c06'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c07'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c08'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c09'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c0a'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c0b'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c0c'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c0d'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c0e'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c0f'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c10'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c11'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c12'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c13'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c14'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c15'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c16'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c17'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c18'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c19'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1a'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1b'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1c'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1d'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1e'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1f'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c20'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c21'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c22'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c23'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c24'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c25'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c26'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c27'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c28'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c29'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2a'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2b'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2c'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2d'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2e'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2f'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c30'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c31'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c32'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c33'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c34'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c35'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c36'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c37'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c38'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c39'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3a'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3b'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3c'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3d'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3e'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3f'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c40'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c41'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c42'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c43'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c44'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c45'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c46'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c47'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c48'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c49'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4a'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4b'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4c'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4d'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4e'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4f'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c50'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c51'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c52'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c53'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c54'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c55'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c56'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c57'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c58'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c59'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5a'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5b'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5c'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5d'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5e'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5f'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c60'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c61'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c62'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c63'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c64'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c65'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c66'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c67'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c68'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c69'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c6a'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c6b'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c6c'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c6d'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c6e'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c6f'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c70'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c71'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c72'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c73'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c74'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c75'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c76'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c77'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c78'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c79'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7a'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7b'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7c'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7d'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7e'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7f'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c80'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c81'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c82'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c83'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c84'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c85'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c86'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c87'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c88'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c89'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8a'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8b'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8c'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8d'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8e'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8f'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c90'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c91'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c92'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c93'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c94'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c95'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c96'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c97'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c98'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c99'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9a'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9b'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9c'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9d'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9e'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9f'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca0'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca1'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca2'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca3'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca4'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca5'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca6'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca7'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca8'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca9'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801caa'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cab'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cac'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cad'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cae'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801caf'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb0'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb1'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb2'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb3'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb4'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb5'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb6'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb7'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb8'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb9'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cba'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cbb'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cbc'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cbd'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cbe'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cbf'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc0'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc1'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc2'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc3'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc4'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc5'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc6'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc7'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc8'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc9'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cca'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ccb'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ccc'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ccd'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cce'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ccf'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd0'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd1'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd2'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd3'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd4'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd5'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd6'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd7'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd8'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd9'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cda'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdb'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdc'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdd'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cde'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdf'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce0'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce1'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce2'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce3'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce4'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce5'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce6'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce7'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce8'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce9'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cea'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ceb'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cec'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ced'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cee'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cef'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf0'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf1'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf2'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf3'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf4'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf5'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf6'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf7'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf8'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf9'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cfa'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cfb'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cfc'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cfd'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cfe'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cff'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d00'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d01'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d02'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d03'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d04'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d05'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d06'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d07'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d08'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d09'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0a'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0b'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0c'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0d'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0e'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0f'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d10'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d11'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d12'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d13'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d14'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d15'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d16'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d17'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d18'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d19'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1a'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1b'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1c'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1d'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1e'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1f'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d20'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d21'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d22'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d23'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d24'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d25'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d26'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d27'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d28'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d29'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2a'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2b'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2c'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2d'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2e'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2f'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d30'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d31'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d32'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d33'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d34'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d35'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d36'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d37'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d38'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d39'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3a'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3b'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3c'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3d'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3e'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3f'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d40'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d41'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d42'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d43'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d44'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d45'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d46'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d47'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d48'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d49'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4a'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4b'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4c'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4d'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4e'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4f'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d50'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d51'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d52'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d53'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d54'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d55'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d56'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d57'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d58'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d59'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5a'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5b'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5c'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5d'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5e'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5f'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d60'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d61'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d62'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d63'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d64'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d65'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d66'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d67'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d68'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d69'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6a'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6b'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6c'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6d'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6e'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6f'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d70'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d71'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d72'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d73'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d74'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d75'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d76'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d77'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d78'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d79'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7a'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7b'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7c'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7d'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7e'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7f'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d80'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d81'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d82'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d83'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d84'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d85'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d86'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d87'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d88'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d89'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8a'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8b'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8c'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8d'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8e'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8f'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d90'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d91'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d92'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d93'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d94'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d95'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d96'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d97'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d98'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d99'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9a'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9b'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9c'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9d'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9e'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9f'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801da0'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801da1'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801da2'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801da3'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da4'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da5'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801da6'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da7'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da8'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801da9'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801daa'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dab'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dac'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dad'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dae'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801daf'),
#  'brand': 'Electrolux',
# ...
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2a'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2b'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2c'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2d'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2e'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2f'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f30'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f31'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f32'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f33'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f34'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f35'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f36'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f37'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f38'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f39'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3a'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3b'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3c'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3d'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3e'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3f'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f40'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f41'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f42'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f43'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f44'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f45'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f46'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f47'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f48'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f49'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4a'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4b'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4c'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4d'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4e'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4f'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f50'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f51'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f52'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f53'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f54'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f55'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f56'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f57'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f58'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f59'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5a'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5b'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5c'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5d'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5e'),
#  'brand': 'Bosch',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5f'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f60'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f61'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f62'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f63'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f64'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f65'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f66'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f67'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f68'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f69'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6a'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6b'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6c'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6d'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6e'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6f'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f70'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f71'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f72'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f73'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f74'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f75'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f76'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f77'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f78'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f79'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7a'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7b'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7c'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7d'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7e'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7f'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f80'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f81'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f82'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f83'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f84'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f85'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f86'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f87'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f88'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f89'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f8a'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f8b'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f8c'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f8d'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f8e'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f8f'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f90'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f91'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f92'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f93'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f94'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f95'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f96'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f97'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f98'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f99'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9a'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9b'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9c'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9d'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9e'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9f'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa0'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa1'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa2'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa3'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa4'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa5'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa6'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa7'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa8'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa9'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801faa'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fab'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fac'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fad'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fae'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801faf'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb0'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb1'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb2'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb3'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb4'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb5'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb6'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb7'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb8'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb9'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fba'),
#  'brand': 'Samsung',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbb'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbc'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbd'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbe'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbf'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc0'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc1'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc2'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc3'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc4'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 1}

# %%
# To see how many documents in collection
count = productcollection.count_documents({})  # Empty query matches all documents
count
# Out:
# 1000

# %%
# Find all documents where the product name is 'Mobile':
query={"name":"Mobile"}
res=productcollection.find(query)
for item in res:
    pprint(item)

# %%
# Find the number of documents for the given condition where name=Mobile
count=productcollection.count_documents(query)
count
# Out:
# 136

# %%
# search product with specific rating
query={"rating":5}
res=productcollection.find(query)
for i in res:
    pprint(i)

count=productcollection.count_documents(query)
print(count)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801bdd'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be2'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be5'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be8'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bec'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf0'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf3'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfa'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c06'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c13'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c19'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1f'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c22'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c27'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2a'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c31'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c36'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3c'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3d'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c42'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c46'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c55'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c56'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c59'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c62'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c65'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c79'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7a'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7c'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8a'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9e'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9f'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca0'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801caf'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb1'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb9'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc1'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc2'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cca'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ccf'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd0'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd7'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd9'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdc'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdf'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce2'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce6'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf1'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf3'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d03'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d04'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0d'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0f'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d11'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d14'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1a'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d21'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d27'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d28'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d29'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2e'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d31'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d36'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d42'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4a'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4f'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d50'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5d'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d60'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d61'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d62'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6d'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d79'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7d'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7e'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d85'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d87'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d89'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d92'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9a'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da6'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da7'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da9'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dac'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dad'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801daf'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db6'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db7'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db9'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbc'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbd'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbf'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc1'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc6'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc8'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc9'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd4'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801de5'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dea'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dee'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801df5'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e02'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e0f'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e27'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2f'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e36'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3b'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3f'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e49'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e4a'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e4c'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e5b'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e6a'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e73'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e74'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e76'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e7d'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e88'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8a'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8b'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8f'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e99'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea4'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea5'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea6'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eaa'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eac'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ead'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eb4'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eb8'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ebd'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ec7'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed0'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed5'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed9'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ede'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ee0'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ee6'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ee9'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eea'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef2'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef5'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801efa'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801efb'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801efc'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f00'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f04'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f08'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0a'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0e'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f11'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f18'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f1b'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f20'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2a'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2e'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f31'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f35'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f38'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3c'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3e'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f41'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f42'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4b'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f50'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f55'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f56'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f57'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5a'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5f'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f61'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f65'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f72'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f77'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7e'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f81'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f90'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f92'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f95'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9a'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa1'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801faa'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fad'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb1'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb2'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbd'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbf'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc2'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# 188

# %%
# Search Products with Rating Above 4
query={"rating":{"$gt":4}}  # "$gt" stands for 'greater than'

res=productcollection.find(query)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801bdd'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be2'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be5'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801be8'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bec'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf0'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf3'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfa'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c06'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c13'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c19'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1f'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c22'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c27'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c2a'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c31'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c36'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3c'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3d'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c42'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c46'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c55'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c56'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c59'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c62'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c65'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c79'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7a'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7c'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8a'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9e'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9f'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca0'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801caf'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb1'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb9'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc1'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc2'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cca'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ccf'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd0'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd7'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd9'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdc'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cdf'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce2'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce6'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf1'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf3'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d03'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d04'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0d'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d0f'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d11'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d14'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1a'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d21'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d27'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d28'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d29'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2e'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d31'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d36'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d42'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4a'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4f'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d50'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5d'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d60'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d61'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d62'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d6d'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d79'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7d'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7e'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d85'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d87'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d89'),
#  'brand': 'Videocon',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d92'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9a'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da6'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da7'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801da9'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dac'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dad'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801daf'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db6'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db7'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db9'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbc'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbd'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbf'),
#  'brand': 'Haier',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc1'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc6'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc8'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc9'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd4'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801de5'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dea'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dee'),
#  'brand': 'Samsung',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801df5'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e02'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e0f'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e27'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2f'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e36'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3b'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3f'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e49'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e4a'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e4c'),
#  'brand': 'Haier',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e5b'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e6a'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e73'),
#  'brand': 'LG',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e74'),
#  'brand': 'Siemens',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e76'),
#  'brand': 'Videocon',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e7d'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e88'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8a'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8b'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8f'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e99'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea4'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea5'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea6'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eaa'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eac'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ead'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eb4'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eb8'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ebd'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ec7'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed0'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed5'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed9'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ede'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ee0'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ee6'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ee9'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eea'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef2'),
#  'brand': 'Haier',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef5'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801efa'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801efb'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801efc'),
#  'brand': 'Whirlpool',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f00'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f04'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f08'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0a'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0e'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f11'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f18'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f1b'),
#  'brand': 'Whirlpool',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f20'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2a'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2e'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f31'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f35'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f38'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3c'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3e'),
#  'brand': 'Haier',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f41'),
#  'brand': 'Videocon',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f42'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4b'),
#  'brand': 'Videocon',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f50'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f55'),
#  'brand': 'Electrolux',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f56'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f57'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5a'),
#  'brand': 'Whirlpool',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5f'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f61'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f65'),
#  'brand': 'Siemens',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f72'),
#  'brand': 'Siemens',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f77'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7e'),
#  'brand': 'Samsung',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f81'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f90'),
#  'brand': 'Siemens',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f92'),
#  'brand': 'Whirlpool',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f95'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f9a'),
#  'brand': 'Bosch',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa1'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801faa'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fad'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb1'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb2'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbd'),
#  'brand': 'LG',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fbf'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc2'),
#  'brand': 'Siemens',
#  'name': 'Induction cooker',
#  'rating': 5}

# %%
# Search for products with name 'Refrigerator' and rating 3
query={"name":"Refrigerator","rating":3}
res=productcollection.find(query)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801c08'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c11'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c32'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c43'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4b'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c60'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c63'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c72'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c73'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce4'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf0'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1d'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d2b'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d5e'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d75'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801da2'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dc7'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd0'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd2'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfc'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e0c'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e21'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e69'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e79'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e85'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e9a'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801eb1'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ebf'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801edd'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801edf'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f06'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f09'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3a'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f85'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb5'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}

# %%
# Addioanl constrain with limiting 2 documents
res=productcollection.find(query).limit(2)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801c08'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c11'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}

# %%
# Search for product
# -- The product name is either "Mobile" or
# -- The product rating is greater than 4.
query = {
    "$or":[
        {"name":"Mobile"},
        {"rating":{"$gt":4}}
           ]
        }        
res=productcollection.find(query).limit(2)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801bdd'),
#  'brand': 'Haier',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801bdf'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 3}

# %%
# which brand has got maximum 5/5 rating
    # Filter out documents with a rating of 5.
    # Group the data by brand.
    # Count the number of 5/5 ratings for each brand.
    # Sort the results by the count in descending order.
    # Limit the output to show only the top brand.

# %%
query=[
     # Step 1: Filter documents with a rating of 5
    {"$match":{"rating":5}},  #Filter documents with a rating of 5
    
    # Step 2: Group by brand and count the number of 5/5 ratings
    {"$group":{
        "_id":"$brand",    # Group by brand
        "count":{"$sum":1} # count the number of 5 ratings for each brand
    }}, 
     # Step 3: Sort by count in descending order to get the brand with the most 5/5 ratings
    {"$sort": {"count": -1}}, 
    # {"$sort": {"count": -1,"brand": 1}}, For multiple column
     # Step 4: Limit to the top 1 result (most 5/5 ratings)
    {"$limit": 2}
]
result = productcollection.aggregate(query)

for i in result:
    pprint(i)
# Out:
# {'_id': 'Haier', 'count': 31}
# {'_id': 'Whirlpool', 'count': 28}

# %%
# update those records where product name is AC to "Air conditioner
productcollection.update_many({"name":"AC"},{"$set":{"name":"Air Conditioner"}})
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801be1'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801be7'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801be9'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf4'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf6'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf7'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c13'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c15'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c18'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1d'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1e'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c21'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c25'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c30'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c36'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c37'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c38'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c39'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3f'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c40'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c44'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c46'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4a'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4c'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4d'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c50'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c65'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c68'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7d'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c84'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c88'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c95'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9d'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca6'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801caa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cae'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb1'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb5'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cba'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc9'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cca'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cce'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd4'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce0'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ceb'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf3'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d09'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d11'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d17'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d18'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d23'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d26'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d29'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d37'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d43'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d46'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d48'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4b'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d57'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d61'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d80'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d87'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d93'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9e'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da4'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da5'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dad'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801db9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbc'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbd'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd7'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ddb'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de0'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de7'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801df5'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfa'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfd'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e15'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e17'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2b'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2d'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3f'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e58'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e5d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e63'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e71'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e72'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8f'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e93'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e94'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e99'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ead'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eba'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ebd'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ec0'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed0'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed5'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eda'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef8'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f01'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f02'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f04'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0c'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f25'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2a'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3e'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f45'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f46'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f53'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5f'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f64'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6a'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6b'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f70'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f73'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f80'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f86'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f93'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f96'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa4'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fad'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb7'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc1'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}

# %%
# To list the updated record
for i in productcollection.find({"name":"Air Conditioner"}):
    pprint(i)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801be1'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801be7'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801be9'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf4'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf6'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf7'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c13'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c15'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c18'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1d'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1e'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c21'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c25'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c30'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c36'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c37'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c38'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c39'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3f'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c40'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c44'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c46'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4a'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4c'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4d'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c50'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c65'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c68'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7d'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c84'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c88'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c95'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9d'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca6'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801caa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cae'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb1'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb5'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cba'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc9'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cca'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cce'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd4'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce0'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ceb'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf3'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d09'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d11'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d17'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d18'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d23'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d26'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d29'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d37'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d43'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d46'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d48'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4b'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d57'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d61'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d80'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d87'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d93'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9e'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da4'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da5'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dad'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801db9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbc'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbd'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd7'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ddb'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de0'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de7'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801df5'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfa'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfd'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e15'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e17'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2b'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2d'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3f'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e58'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e5d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e63'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e71'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e72'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8f'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e93'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e94'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e99'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ead'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eba'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ebd'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ec0'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed0'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed5'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eda'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef8'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f01'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f02'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f04'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0c'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f25'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2a'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3e'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f45'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f46'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f53'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5f'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f64'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6a'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6b'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f70'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f73'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f80'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f86'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f93'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f96'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa4'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fad'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb7'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc1'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}

# %%
# Load the json file from folder Open the database pes and load the employees.json
db=client['pes']

# %%
emp=db["test"]
for i in emp.find():
    pprint(i)
# Out:
# {'_id': ObjectId('680b83c9c78d8da0b16b5123'),
#  'department': 'HR',
#  'designation': 'Recruiter',
#  'emp_id': 101,
#  'joining_date': '2020-03-15',
#  'name': 'Alice Johnson',
#  'salary': 55000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5124'),
#  'department': 'Finance',
#  'designation': 'Accountant',
#  'emp_id': 102,
#  'joining_date': '2019-07-01',
#  'name': 'Bob Smith',
#  'salary': 60000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5125'),
#  'department': 'IT',
#  'designation': 'Software Engineer',
#  'emp_id': 103,
#  'joining_date': '2021-01-10',
#  'name': 'Charlie Lee',
#  'salary': 75000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5126'),
#  'department': 'Marketing',
#  'designation': 'Content Writer',
#  'emp_id': 104,
#  'joining_date': '2022-05-22',
#  'name': 'Diana Patel',
#  'salary': 48000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5127'),
#  'department': 'Sales',
#  'designation': 'Sales Executive',
#  'emp_id': 105,
#  'joining_date': '2020-11-30',
#  'name': 'Edward Jones',
#  'salary': 52000}

# %% [markdown]
# ### Case Study

# %%
# Import business_data.json for further exercises
db=client["salesdb"]
business=db["business_data"]
res=business.find({})
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680b8bcdc78d8da0b16b512b'),
#  'cuisine': 'Vegetarian',
#  'name': 'Fun Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b512c'),
#  'cuisine': 'Fast Food',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b512d'),
#  'cuisine': 'Indian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b512e'),
#  'cuisine': 'Italian',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b512f'),
#  'cuisine': 'Chinese',
#  'name': 'City Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5130'),
#  'cuisine': 'Mexican',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5131'),
#  'cuisine': 'Vegetarian',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5132'),
#  'cuisine': 'Indian',
#  'name': 'State Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5133'),
#  'cuisine': 'American',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5134'),
#  'cuisine': 'Pizza',
#  'name': 'Big Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5135'),
#  'cuisine': 'Vegetarian',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5136'),
#  'cuisine': 'Italian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5137'),
#  'cuisine': 'Chinese',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5138'),
#  'cuisine': 'Mexican',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5139'),
#  'cuisine': 'American',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b513a'),
#  'cuisine': 'Fast Food',
#  'name': 'City Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b513b'),
#  'cuisine': 'Pizza',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b513c'),
#  'cuisine': 'Italian',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b513d'),
#  'cuisine': 'Chinese',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b513e'),
#  'cuisine': 'Vegetarian',
#  'name': 'Fun Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b513f'),
#  'cuisine': 'Mexican',
#  'name': 'State Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5140'),
#  'cuisine': 'Pizza',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5141'),
#  'cuisine': 'Vegetarian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5142'),
#  'cuisine': 'American',
#  'name': 'Big Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5143'),
#  'cuisine': 'Fast Food',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5144'),
#  'cuisine': 'Indian',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5145'),
#  'cuisine': 'Chinese',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5146'),
#  'cuisine': 'Italian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5147'),
#  'cuisine': 'Mexican',
#  'name': 'City Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5148'),
#  'cuisine': 'Fast Food',
#  'name': 'State Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5149'),
#  'cuisine': 'Vegetarian',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b514a'),
#  'cuisine': 'American',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b514b'),
#  'cuisine': 'Chinese',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b514c'),
#  'cuisine': 'Indian',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b514d'),
#  'cuisine': 'Fast Food',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b514e'),
#  'cuisine': 'Italian',
#  'name': 'Big Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b514f'),
#  'cuisine': 'Mexican',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5150'),
#  'cuisine': 'Vegetarian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5151'),
#  'cuisine': 'American',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5152'),
#  'cuisine': 'Pizza',
#  'name': 'Fun Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5153'),
#  'cuisine': 'Indian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5154'),
#  'cuisine': 'Fast Food',
#  'name': 'State Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5155'),
#  'cuisine': 'Vegetarian',
#  'name': 'City Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5156'),
#  'cuisine': 'Chinese',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5157'),
#  'cuisine': 'Italian',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5158'),
#  'cuisine': 'Pizza',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680b8bcdc78d8da0b16b5159'),
#  'cuisine': 'Indian',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680b8bcdc78d8da0b16b515a'),
#  'cuisine': 'Fast Food',
#  'name': 'Big Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680b8bcdc78d8da0b16b515b'),
#  'cuisine': 'Mexican',
#  'name': 'Salty Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680b8bcdc78d8da0b16b515c'),
#  'cuisine': 'American',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}

# %% [markdown]
# 1. Find the orders which has the low review i.e. 1

# %% [markdown]
# 2. Find the Top 5 Highest Rated Businesses

# %% [markdown]
# 3.Count the Number of Businesses in Each Cuisine Category

# %% [markdown]
# 4.Find Businesses Offering "Pizza" Cuisine with a Rating of 4 or 5
