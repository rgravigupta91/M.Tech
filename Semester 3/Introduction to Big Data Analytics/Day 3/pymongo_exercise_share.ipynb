# %%
from pymongo import MongoClient
from pprint import pprint

# %%
# 1. Connect to MongoD
client = MongoClient("mongodb://localhost:27017/")

# %%
# 2. Create or access the database
db=client["salesdb"]

# %%
# Create collection - salesdata_collection
salesdata = db["salesdata_collection"]

# insert one document in the collection
salesdata.insert_one({"sales_id":1,
"country":"India",
"Product_detail" : {"product_id": 100,
                    "Amount": 5000,"Vendor_code":13, 
                    "Vendor_description": "this vendor is expert in providing mobile phones"}})
# Out:
# InsertOneResult(ObjectId('680c873b016bb6e9179c22dc'), acknowledged=True)

# %%
# To list all collections under db
db.list_collection_names()
# Out:
# ['salesdata_collection']

# %%
# To print multiple documents from the collection
for document in salesdata.find():
    pprint(document)
# Out:
# {'Product_detail': {'Amount': 5000,
#                     'Vendor_code': 13,
#                     'Vendor_description': 'this vendor is expert in providing '
#                                           'mobile phones',
#                     'product_id': 100},
#  '_id': ObjectId('680c873b016bb6e9179c22dc'),
#  'country': 'India',
#  'sales_id': 1}

# %%
# Filter and find the given conditional document from the collection
query={"sales_id":1}
result=salesdata.find(query)
for i in result:
    pprint(i)
# Out:
# {'Product_detail': {'Amount': 5000,
#                     'Vendor_code': 13,
#                     'Vendor_description': 'this vendor is expert in providing '
#                                           'mobile phones',
#                     'product_id': 100},
#  '_id': ObjectId('680c873b016bb6e9179c22dc'),
#  'country': 'India',
#  'sales_id': 1}

# %%
# manually inserting ObjectId also #  objectid is a 24-digit hexadecimal strings
from bson import ObjectId
result = salesdata.insert_one({"_id":ObjectId("5955f4bb212e8fb45ca200d0"),
"sales_id":2,
"country":"India",
"Product_detail" : {"product_id": 101,
                    "Amount": 6000,"Vendor_code":13, 
                    "Vendor_description": "this vendor is expert in providing mobile phones"}})

# %%
result.inserted_id
# Out:
# ObjectId('5955f4bb212e8fb45ca200d0')

# %%
result.acknowledged
# Out:
# True

# %%
# What are the Advantages and disadvantages of including  _id:ObjectId ?
# Advantages - Automatic Uniqueness, Efficient Indexing, Time-based Component, No manual mgmt
# Disadvantages - Size, Lack of readability(Hexa), No precise timestamp (default every minute),
# No suitable for few distributed system

# %%
from random import randint

# %%
# Inserting multiple documents

productcollection = db['product_feedback']

productlist = []
product_name = ['Mobile','TV','Washing machine', 'Refrigerator', 'Microwave Oven','Induction cooker','AC']
company_name = ['LG', 'Samsung', 'Bosch','Siemens','Whirlpool','Electrolux','Haier','Videocon']
for x in range(1, 1001):
    sale = {
        'name' : product_name[randint(0, (len(product_name)-1))],
        'rating' : randint(1, 5),
        'brand' : company_name[randint(0, (len(company_name)-1))] 
    }
    productlist.append(sale)

print(productlist)
# Out:
# [{'name': 'Induction cooker', 'rating': 4, 'brand': 'Bosch'}, {'name': 'Microwave Oven', 'rating': 1, 'brand': 'Samsung'}, {'name': 'Refrigerator', 'rating': 3, 'brand': 'Samsung'}, {'name': 'TV', 'rating': 1, 'brand': 'Samsung'}, {'name': 'Refrigerator', 'rating': 4, 'brand': 'Whirlpool'}, {'name': 'Induction cooker', 'rating': 1, 'brand': 
),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2631'),
#  'brand': 'Whirlpool',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2634'),
#  'brand': 'Electrolux',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2638'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2639'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c263d'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c263e'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2642'),
#  'brand': 'Electrolux',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2652'),
#  'brand': 'Videocon',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2659'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c265d'),
#  'brand': 'Bosch',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c265e'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c265f'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2662'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2663'),
#  'brand': 'LG',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c266a'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c266c'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c266e'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2671'),
#  'brand': 'Bosch',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2675'),
#  'brand': 'Electrolux',
#  'name': 'Mobile',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2679'),
#  'brand': 'LG',
#  'name': 'Microwave Oven',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2687'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c2692'),
#  'brand': 'LG',
#  'name': 'TV',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26a3'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26aa'),
#  'brand': 'Samsung',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26ae'),
#  'brand': 'Bosch',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26af'),
#  'brand': 'Videocon',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26b1'),
#  'brand': 'Siemens',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26b3'),
#  'brand': 'Electrolux',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26b8'),
#  'brand': 'Haier',
#  'name': 'Induction cooker',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26b9'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26bb'),
#  'brand': 'Bosch',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26bd'),
#  'brand': 'LG',
#  'name': 'AC',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26c2'),
#  'brand': 'Whirlpool',
#  'name': 'Washing machine',
#  'rating': 5}
# {'_id': ObjectId('680c88b7016bb6e9179c26c4'),
#  'brand': 'Electrolux',
#  'name': 'TV',
#  'rating': 5}

# %%
# Search for products with name 'Refrigerator' and rating 3
query={"name":"Refrigerator","rating":3}
res=productcollection.find(query)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680c88b7016bb6e9179c22df'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2302'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2318'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2377'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c23b3'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c23c5'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c23d4'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c23df'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c23fb'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2499'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c24cb'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c24db'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c24e5'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c24f8'),
#  'brand': 'LG',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c251d'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2530'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2557'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c256d'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2579'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2585'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c25af'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c25bb'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c25c0'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c25c6'),
#  'brand': 'Siemens',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c25e2'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c25fd'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c263c'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c264c'),
#  'brand': 'Bosch',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2655'),
#  'brand': 'Electrolux',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2680'),
#  'brand': 'Videocon',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c268d'),
#  'brand': 'Whirlpool',
#  'name': 'Refrigerator',
#  'rating': 3}

# %%
# Addioanl constrain with limiting 2 documents
res=productcollection.find(query).limit(2)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680c88b7016bb6e9179c22df'),
#  'brand': 'Samsung',
#  'name': 'Refrigerator',
#  'rating': 3}
# {'_id': ObjectId('680c88b7016bb6e9179c2302'),
#  'brand': 'Haier',
#  'name': 'Refrigerator',
#  'rating': 3}

# %%
# Search for product
# -- The product name is either "Mobile" or
# -- The product rating is greater than 4.
query = {
    "$or":[
        {"name":"Mobile"},
        {"rating":{"$gt":4}}
           ]
        }        
res=productcollection.find(query).limit(2)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680c88b7016bb6e9179c22e3'),
#  'brand': 'Samsung',
#  'name': 'Mobile',
#  'rating': 4}
# {'_id': ObjectId('680c88b7016bb6e9179c22e9'),
#  'brand': 'Samsung',
#  'name': 'TV',
#  'rating': 5}

# %%
# which brand has got maximum 5/5 rating
    # Filter out documents with a rating of 5.
    # Group the data by brand.
    # Count the number of 5/5 ratings for each brand.
    # Sort the results by the count in descending order.
    # Limit the output to show only the top brand.

# %%
query=[
     # Step 1: Filter documents with a rating of 5
    {"$match":{"rating":5}},  #Filter documents with a rating of 5
    
    # Step 2: Group by brand and count the number of 5/5 ratings
    {"$group":{
        "_id":"$brand",    # Group by brand
        "count":{"$sum":1} # count the number of 5 ratings for each brand
    }}, 
     # Step 3: Sort by count in descending order to get the brand with the most 5/5 ratings
    {"$sort": {"count": -1}}, 
    # {"$sort": {"count": -1,"brand": 1}}, For multiple column
     # Step 4: Limit to the top 1 result (most 5/5 ratings)
    {"$limit": 1}
]
result = productcollection.aggregate(query)

for i in result:
    pprint(i)
# Out:
# {'_id': 'Haier', 'count': 31}
# {'_id': 'Whirlpool', 'count': 28}

# %%
# update those records where product name is AC to "Air conditioner
productcollection.update_many({"name":"AC"},{"$set":{"name":"Air Conditioner"}})
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801be1'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801be7'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801be9'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf4'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf6'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf7'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c13'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c15'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c18'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1d'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1e'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c21'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c25'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c30'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c36'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c37'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c38'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c39'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3f'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c40'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c44'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c46'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4a'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4c'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4d'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c50'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c65'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c68'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7d'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c84'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c88'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c95'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9d'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca6'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801caa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cae'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb1'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb5'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cba'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc9'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cca'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cce'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd4'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce0'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ceb'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf3'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d09'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d11'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d17'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d18'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d23'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d26'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d29'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d37'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d43'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d46'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d48'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4b'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d57'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d61'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d80'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d87'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d93'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9e'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da4'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da5'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dad'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801db9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbc'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbd'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd7'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ddb'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de0'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de7'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801df5'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfa'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfd'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e15'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e17'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2b'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2d'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3f'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e58'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e5d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e63'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e71'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e72'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8f'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e93'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e94'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e99'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ead'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eba'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ebd'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ec0'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed0'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed5'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eda'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef8'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f01'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f02'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f04'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0c'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f25'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2a'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3e'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f45'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f46'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f53'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5f'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f64'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6a'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6b'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f70'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f73'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f80'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f86'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f93'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f96'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa4'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fad'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb7'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc1'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}

# %%
# To list the updated record
for i in productcollection.find({"name":"Air Conditioner"}):
    pprint(i)
# Out:
# {'_id': ObjectId('680b2e6a196ab22dc9801be1'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801be7'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801be9'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf4'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf6'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf7'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801bf9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801bfa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c13'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c15'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c18'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1d'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c1e'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c21'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c25'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c30'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c36'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c37'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c38'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c39'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c3f'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c40'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c44'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c46'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4a'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4c'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c4d'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c50'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c5b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c65'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c68'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7d'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801c7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c84'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c88'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801c8b'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801c95'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9d'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801c9e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ca6'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801caa'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801cae'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb1'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cb5'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cba'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801cc9'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cca'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801cce'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801cd4'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce0'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ce8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ceb'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801cf3'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d09'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d11'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d17'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d18'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d1a'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d23'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d26'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d29'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d37'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d3f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d43'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d46'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d48'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d4b'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d57'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801d61'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d7b'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d80'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d87'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801d8f'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801d93'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801d97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801d9e'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da4'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801da5'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801dad'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801db8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801db9'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbc'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dbd'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dd7'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ddb'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de0'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801de7'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801df5'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfa'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801dfd'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e04'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e15'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e17'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2b'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e2d'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e3f'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e58'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801e5d'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e63'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801e71'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e72'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e8f'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801e93'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801e94'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801e99'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ea4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ead'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eba'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801ebd'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ec0'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed0'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801ed5'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801eda'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801ef8'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f01'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f02'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f04'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0c'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f0e'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f25'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f2a'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f3e'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f45'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f46'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f4e'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f53'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f5f'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f64'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6a'),
#  'brand': 'Bosch',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f6b'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f70'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f73'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f7e'),
#  'brand': 'Samsung',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801f80'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f86'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 3}
# {'_id': ObjectId('680b2e6a196ab22dc9801f93'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801f96'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801f97'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa4'),
#  'brand': 'Siemens',
#  'name': 'Air Conditioner',
#  'rating': 4}
# {'_id': ObjectId('680b2e6a196ab22dc9801fa8'),
#  'brand': 'Whirlpool',
#  'name': 'Air Conditioner',
#  'rating': 1}
# {'_id': ObjectId('680b2e6a196ab22dc9801fad'),
#  'brand': 'Electrolux',
#  'name': 'Air Conditioner',
#  'rating': 5}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb4'),
#  'brand': 'LG',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fb7'),
#  'brand': 'Haier',
#  'name': 'Air Conditioner',
#  'rating': 2}
# {'_id': ObjectId('680b2e6a196ab22dc9801fc1'),
#  'brand': 'Videocon',
#  'name': 'Air Conditioner',
#  'rating': 3}

# %%
# Load the json file from folder Open the database pes and load the employees.json
db=client['pes']

# %%
emp=db["test"]
for i in emp.find():
    pprint(i)
# Out:
# {'_id': ObjectId('680b83c9c78d8da0b16b5123'),
#  'department': 'HR',
#  'designation': 'Recruiter',
#  'emp_id': 101,
#  'joining_date': '2020-03-15',
#  'name': 'Alice Johnson',
#  'salary': 55000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5124'),
#  'department': 'Finance',
#  'designation': 'Accountant',
#  'emp_id': 102,
#  'joining_date': '2019-07-01',
#  'name': 'Bob Smith',
#  'salary': 60000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5125'),
#  'department': 'IT',
#  'designation': 'Software Engineer',
#  'emp_id': 103,
#  'joining_date': '2021-01-10',
#  'name': 'Charlie Lee',
#  'salary': 75000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5126'),
#  'department': 'Marketing',
#  'designation': 'Content Writer',
#  'emp_id': 104,
#  'joining_date': '2022-05-22',
#  'name': 'Diana Patel',
#  'salary': 48000}
# {'_id': ObjectId('680b83c9c78d8da0b16b5127'),
#  'department': 'Sales',
#  'designation': 'Sales Executive',
#  'emp_id': 105,
#  'joining_date': '2020-11-30',
#  'name': 'Edward Jones',
#  'salary': 52000}

# %% [markdown]
# ### Case Study

# %%
# Import business_data.json for further exercises
db=client["pes"]
business=db["business_data"]
res=business.find({})
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680ca1eba6b3fc4a165629a2'),
#  'cuisine': 'Vegetarian',
#  'name': 'Fun Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a3'),
#  'cuisine': 'Fast Food',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a4'),
#  'cuisine': 'Indian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a5'),
#  'cuisine': 'Italian',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a6'),
#  'cuisine': 'Chinese',
#  'name': 'City Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a7'),
#  'cuisine': 'Mexican',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a8'),
#  'cuisine': 'Vegetarian',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a9'),
#  'cuisine': 'Indian',
#  'name': 'State Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629aa'),
#  'cuisine': 'American',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ab'),
#  'cuisine': 'Pizza',
#  'name': 'Big Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ac'),
#  'cuisine': 'Vegetarian',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ad'),
#  'cuisine': 'Italian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ae'),
#  'cuisine': 'Chinese',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629af'),
#  'cuisine': 'Mexican',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b0'),
#  'cuisine': 'American',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b1'),
#  'cuisine': 'Fast Food',
#  'name': 'City Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b2'),
#  'cuisine': 'Pizza',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b3'),
#  'cuisine': 'Italian',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b4'),
#  'cuisine': 'Chinese',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b5'),
#  'cuisine': 'Vegetarian',
#  'name': 'Fun Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b6'),
#  'cuisine': 'Mexican',
#  'name': 'State Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b7'),
#  'cuisine': 'Pizza',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b8'),
#  'cuisine': 'Vegetarian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b9'),
#  'cuisine': 'American',
#  'name': 'Big Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ba'),
#  'cuisine': 'Fast Food',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bb'),
#  'cuisine': 'Indian',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bc'),
#  'cuisine': 'Chinese',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bd'),
#  'cuisine': 'Italian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629be'),
#  'cuisine': 'Mexican',
#  'name': 'City Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bf'),
#  'cuisine': 'Fast Food',
#  'name': 'State Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c0'),
#  'cuisine': 'Vegetarian',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c1'),
#  'cuisine': 'American',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c2'),
#  'cuisine': 'Chinese',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c3'),
#  'cuisine': 'Indian',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c4'),
#  'cuisine': 'Fast Food',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c5'),
#  'cuisine': 'Italian',
#  'name': 'Big Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c6'),
#  'cuisine': 'Mexican',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c7'),
#  'cuisine': 'Vegetarian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c8'),
#  'cuisine': 'American',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c9'),
#  'cuisine': 'Pizza',
#  'name': 'Fun Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ca'),
#  'cuisine': 'Indian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cb'),
#  'cuisine': 'Fast Food',
#  'name': 'State Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cc'),
#  'cuisine': 'Vegetarian',
#  'name': 'City Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cd'),
#  'cuisine': 'Chinese',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ce'),
#  'cuisine': 'Italian',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cf'),
#  'cuisine': 'Pizza',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d0'),
#  'cuisine': 'Indian',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d1'),
#  'cuisine': 'Fast Food',
#  'name': 'Big Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d2'),
#  'cuisine': 'Mexican',
#  'name': 'Salty Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d3'),
#  'cuisine': 'American',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}

# %% [markdown]
# 1. Find the orders which has the low review i.e. 1

# %%
query = {"rating":1}
projection={"cuisine":1,"_id":0}
res = business.find(query,projection)
for i in res:
    pprint(i)
# Out:
# {'cuisine': 'Vegetarian'}
# {'cuisine': 'Chinese'}
# {'cuisine': 'Italian'}
# {'cuisine': 'American'}
# {'cuisine': 'Italian'}
# {'cuisine': 'American'}
# {'cuisine': 'Vegetarian'}
# {'cuisine': 'Italian'}

# %% [markdown]
# 2. Find the Top 5 Highest Rated Businesses

# %%
query = {}
projection={"name":1,"rating":1,"_id":0}
res = business.find(query,projection).sort("rating",-1).limit(5)
for i in res:
    pprint(i)
# Out:
# {'name': 'Big Pvt Ltd', 'rating': 5}
# {'name': 'Pizza Pvt Ltd', 'rating': 5}
# {'name': 'Kitchen Pvt Ltd', 'rating': 5}
# {'name': 'Pizza Pvt Ltd', 'rating': 5}
# {'name': 'HomeFood Pvt Ltd', 'rating': 5}

# %%
query = [{"$sort":{"rating":-1}}]
res = business.aggregate(query)
for i in res:
    pprint(i)
# Out:
# {'_id': ObjectId('680ca1eba6b3fc4a165629b2'),
#  'cuisine': 'Pizza',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a3'),
#  'cuisine': 'Fast Food',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c0'),
#  'cuisine': 'Vegetarian',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c8'),
#  'cuisine': 'American',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629af'),
#  'cuisine': 'Mexican',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a7'),
#  'cuisine': 'Mexican',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bb'),
#  'cuisine': 'Indian',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b5'),
#  'cuisine': 'Vegetarian',
#  'name': 'Fun Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d3'),
#  'cuisine': 'American',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ab'),
#  'cuisine': 'Pizza',
#  'name': 'Big Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c4'),
#  'cuisine': 'Fast Food',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629be'),
#  'cuisine': 'Mexican',
#  'name': 'City Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cb'),
#  'cuisine': 'Fast Food',
#  'name': 'State Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cf'),
#  'cuisine': 'Pizza',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 5}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a9'),
#  'cuisine': 'Indian',
#  'name': 'State Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b0'),
#  'cuisine': 'American',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a2'),
#  'cuisine': 'Vegetarian',
#  'name': 'Fun Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ba'),
#  'cuisine': 'Fast Food',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c3'),
#  'cuisine': 'Indian',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c6'),
#  'cuisine': 'Mexican',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ca'),
#  'cuisine': 'Indian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b7'),
#  'cuisine': 'Pizza',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a6'),
#  'cuisine': 'Chinese',
#  'name': 'City Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d1'),
#  'cuisine': 'Fast Food',
#  'name': 'Big Pvt Ltd',
#  'rating': 4}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b1'),
#  'cuisine': 'Fast Food',
#  'name': 'City Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b8'),
#  'cuisine': 'Vegetarian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a5'),
#  'cuisine': 'Italian',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bf'),
#  'cuisine': 'Fast Food',
#  'name': 'State Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b4'),
#  'cuisine': 'Chinese',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cc'),
#  'cuisine': 'Vegetarian',
#  'name': 'City Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ac'),
#  'cuisine': 'Vegetarian',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d0'),
#  'cuisine': 'Indian',
#  'name': 'Tastey Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c5'),
#  'cuisine': 'Italian',
#  'name': 'Big Pvt Ltd',
#  'rating': 3}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bc'),
#  'cuisine': 'Chinese',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c9'),
#  'cuisine': 'Pizza',
#  'name': 'Fun Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c2'),
#  'cuisine': 'Chinese',
#  'name': 'Lazy Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a4'),
#  'cuisine': 'Indian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629aa'),
#  'cuisine': 'American',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ad'),
#  'cuisine': 'Italian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b6'),
#  'cuisine': 'Mexican',
#  'name': 'State Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629cd'),
#  'cuisine': 'Chinese',
#  'name': 'HomeFood Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629d2'),
#  'cuisine': 'Mexican',
#  'name': 'Salty Pvt Ltd',
#  'rating': 2}
# {'_id': ObjectId('680ca1eba6b3fc4a165629bd'),
#  'cuisine': 'Italian',
#  'name': 'Kitchen Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629a8'),
#  'cuisine': 'Vegetarian',
#  'name': 'Sandwich Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ce'),
#  'cuisine': 'Italian',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b9'),
#  'cuisine': 'American',
#  'name': 'Big Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629b3'),
#  'cuisine': 'Italian',
#  'name': 'Ghar ka khana Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629ae'),
#  'cuisine': 'Chinese',
#  'name': 'Home Mane Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c1'),
#  'cuisine': 'American',
#  'name': 'Pizza Pvt Ltd',
#  'rating': 1}
# {'_id': ObjectId('680ca1eba6b3fc4a165629c7'),
#  'cuisine': 'Vegetarian',
#  'name': 'Salty Pvt Ltd',
#  'rating': 1}

# %% [markdown]
# 3.Count the Number of Businesses in Each Cuisine Category

# %%
query = [
    {"$group":{"_id":"$cuisine","cnt":{"$sum":1}}},
    {"$sort":{"cnt":-1}}
]
res = business.aggregate(query)
for i in res:
    pprint(i)
# Out:
# {'_id': 'Vegetarian', 'cnt': 8}
# {'_id': 'Fast Food', 'cnt': 7}
# {'_id': 'Mexican', 'cnt': 6}
# {'_id': 'Chinese', 'cnt': 6}
# {'_id': 'American', 'cnt': 6}
# {'_id': 'Indian', 'cnt': 6}
# {'_id': 'Italian', 'cnt': 6}
# {'_id': 'Pizza', 'cnt': 5}

# %% [markdown]
# 4.Find Businesses Offering "Pizza" Cuisine with a Rating of 4 or 5

# %%
query = {"cuisine":"Pizza", "rating":{"$in":[4,5]}}
projection = {"_id":0,"cuisine":1,"rating":1,"name":1}
res = business.find(query,projection)
for i in res:
    pprint(i)
# Out:
# {'cuisine': 'Pizza', 'name': 'Big Pvt Ltd', 'rating': 5}
# {'cuisine': 'Pizza', 'name': 'Kitchen Pvt Ltd', 'rating': 5}
# {'cuisine': 'Pizza', 'name': 'Pizza Pvt Ltd', 'rating': 4}
# {'cuisine': 'Pizza', 'name': 'Sandwich Pvt Ltd', 'rating': 5}

# %%
=[
     # Step 1: Filter documents with a rating of 5
    {"$match":{"rating":5}},  #Filter documents with a rating of 5
    
    # Step 2: Group by brand and count the number of 5/5 ratings
    {"$group":{
        "_id":"$brand",    # Group by brand
        "count":{"$sum":1} # count the number of 5 ratings for each brand
    }}, 
     # Step 3: Sort by count in descending order to get the brand with the most 5/5 ratings
    {"$sort": {"count": -1}}, 
    # {"$sort": {"count": -1,"brand": 1}}, For multiple column
     # Step 4: Limit to the top 1 result (most 5/5 ratings)
    {"$limit": 1}
]
