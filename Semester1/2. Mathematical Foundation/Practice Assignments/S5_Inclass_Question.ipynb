# %% [markdown]
# ## Question 1 : Function

# %% [markdown]
# A person drives everday.The amount of distance he drives through is the 10 times of the index number of  day and an addition of 7 miles.The index start from considering sunday as 0 and goes serialwise.
#
# 1. Construct the funtion for miles travelled by the person.
# 2. Draw the function of the daily amount of miles,the person drives for a month.

# %% [markdown]
# ### 1.1 : Construct the funtion for miles travelled by the person.

# %% [markdown]
# ### 1.2 : Draw the function of the daily amount of miles,the person drives for a month.

# %% [markdown]
# ## Question 2 : Limit

# %% [markdown]
# According to a research  the amount of energy sun is loosing everyday can be put in an equation.
# The function to express the change in the energy of sun could be written as 1 - x sin(1/x).
#
# 1. What would happen to sun in very distant future.

# %% [markdown]
# ### 2.1 : What would happen to sun in very distant future.

# %% [markdown]
# ## Question 3 : Derivative

# %% [markdown]
# A particle travels along the function sin(x) - cos(x).Where x represents seconds.
#
# 1. Draw the function of the moving particle
# 2. Find the rate of change of movement of the particle
#     1. Use the limit concept.
#     2. use the differential fuction
# 3. Draw the rate of change of movement of the particle
# 4. Find the rate of change of movement of the particle at 90 seconds
#     1. Use the limit concept.
#     2. use the differential fuction
# 5. Draw the rate of change of movement of the particle  at 90 seconds

# %% [markdown]
# ### 3.1 : Draw the function of the moving particle

# %% [markdown]
# ### 3.2 : Find the rate of change of movement of the particle

# %% [markdown]
# ### 3.2.1 : Use the limit concept.

# %% [markdown]
# ### 3.2.1 : Use the differential fuction

# %% [markdown]
# ### 3.3 : Draw the rate of change of movement of the particle

# %% [markdown]
# ### 3.4 : Find the rate of change of movement of the particle at 90 seconds

# %% [markdown]
# ### 3.4.1 : Use the limit concept.

# %% [markdown]
# ### 3.2.1 : Use the differential fuction

# %% [markdown]
# ### 3.5 :  Draw the rate of change of movement of the particle  at 90 seconds

# %% [markdown]
# ## Question 4 : Chain Rule

# %% [markdown]
# ### Find the derivative of f(x) with the help of chain rule.

# %%
Image(S4_IN.png)

# %% [markdown]
# ### 4.1 : Calculate f1

# %% [markdown]
# ### 4.2 : Calculate f2

# %% [markdown]
# ### 4.3 : Calculate f3

# %% [markdown]
# ### 4.4 : Calculate f4

# %% [markdown]
# ### 4.5 : Multiply f1 ,f2 ,f3 ,f4

# %% [markdown]
# ### 4.6 : Calculate differentiation of f(x) with respect to x

# %% [markdown]
# ## Question 5 : Application

# %% [markdown]
# Company A produces 100 chocolates per day.
# Each chocolate costs Rs. 2 and sold at a price of Rs 5.
#
# Company A starts buying the raw material from company B after 2 months.It incurrs an additional cost Rs 1 per chocolate to Company A.
#
# 1. Calculate the profit of Company A for first 3 years of it's business.
# 2. Draw the graph of Profit, Cost and Sales amount day wise of Company A for first 3 years of it's business.

# %% [markdown]
# ### 5.1 : Calculate the profit of Company A for first 3 years of it's business.

# %% [markdown]
# ### 5.2 : Draw the graph of Profit, Cost and Sales amount day wise of Company A for first 3 years of it's business.
