# %% [markdown]
# # Question 1 : Optimizing function with one variable

# %% [markdown]
# A particle travels in a particular path.The function of the path could be written as sin(1/t) + (1/t ** 3) + 2 (t ** 5) where t refers the time in second.
#
# 1. Draw the path of the partical
# 2. Find out the velocity of the partical
# 3. Draw the velocity of the partical
# 4. Find out the time(in sec) where the partical moves the fastest
# 5.  Find out the time(in sec) where the partical moves the slowest
# 6. Find out if there is any time point where the partical does not move

# %% [markdown]
# ### 1.1. Draw the path of the particle

# %% [markdown]
# ### 1.2. Find out the velocity of the particle

# %% [markdown]
# ### 1.3. Draw the velocity of the particle

# %% [markdown]
# ### 1.4. Find out the time(in sec) where the particle moves the fastest

# %% [markdown]
# ### 1.5.  Find out the time(in sec) where the partical moves the slowest

# %% [markdown]
# ### 1.6. Find out if there is any time point where the particle does not move

# %% [markdown]
# # Question 2 : Minimizing function with multiple variables

# %% [markdown]
# A person has a savings of  total of Rs 50000
# The person wants to invest in two shares , Share-1 & Share-2
#
# The Price of Share-1 is 50
# The return of Share-1 follows a function 48 - (1/ (t ** 2) + 10 sin(pi * t / 180)
# The Price of Share-2 is 50
# The return of Share-2 follows a function 52 - (1/ t) + 10 tan (pi * t / 180)
# where t represents the time in day.
#
# He is going to invest his moey for a maximum of 1000 days.
#
# 1. Draw a graph of the return if the person invests all his money on Share-1
# 2. Draw a graph of the return if the person invests all his money on Share-2
# 3. Constract a return function  with parameters as number of share the person brought of each Share-1 and Share-2 and time
# 4. Constact a profit function with the previous function
# 5. Find out the optimum split of number of shares in Share-1 & Share-2 and the time point

# %% [markdown]
# ### 2.1. Draw a graph of the return if the person invests all his money on Share-1

# %% [markdown]
# ### 2.2. Draw a graph of the return if the person invests all his money on Share-2

# %% [markdown]
# ### 2.3. Constract a return function  with parameters as number of share the person brought of each Share-1 and Share-2 and time

# %% [markdown]
# ### 2.4. Constact a profit function with the previous function

# %% [markdown]
# ### 2.5. Find out the optimum split of number of shares in Share-1 & Share-2 and the time point

# %% [markdown]
# # Question 3 : Find root

# %% [markdown]
# ### 3.1 Find the root of the funtion f.
#
# f = 19 * sin((1-x)*0.0174533)/3 + (.03 * x)

# %% [markdown]
# # Question 4 : Gradient Descent Step by step

# %% [markdown]
# We have recorded the conversion rate of Dolar and pound over 200 days.Y shows the conversion rate and x shows the number of the day.
# Try to fit the best possible function 'f' to stablish the relationship between the number of the day and conversion rate.(Applying Gradient descent)
#   where f(x) = y = a + b * x
#
# 4.1 Fix the initial values of the parameters, learninng rate and error rate
#
# 4.2 Initiate two list with intial values of the parameters
#
# 4.3 Find the length of x
#
# 4.4 Prepare the cost function
#
# 4.5 Find the derivative of cost with respect to 'a'.
#
# 4.6 Find the value of the derivative in 4.5 with the initial values of 'a' & 'b' and store it in a variable A
#
# 4.7 Find the derivative of cost with respect to 'b'.
#
#
# 4.8 Find the value of the derivative in 4.7 with the initial values of 'a' & 'b' and store it in a variable B
#
# 4.9 Update the values of 'a' & 'b'
#
# 4.10 Store the new values of the parametters in the listcreated in step 4.2
#
# 4.11 Find the diference in the value of parameter from the initial values.
#
# 4.12 if the difference in smaller than error rate stop otherwise recalculate the value of 4.6 & 4.8 with the new pair of parameter values
#
# 4.13 Run a loop to repeat 4.9,4.10,4.11,4.12 until we reach to the stopping condition.
#
# 4.14 Combine all the steps and prepare the final version

# %%
Y = np.array([3.17, 1.96, 1.87, 3.25, 2.17, 3.83, 3.09, 3.67, 4.04, 4.57, 
              4.29, 4.34, 5.12, 4.0, 1.56, 5.56, 5.31, 5.86, 4.84, 5.15, 
              6.67, 5.84, 7.46, 9.06, 5.08, 6.84, 6.53, 6.11, 6.85, 7.22,
              8.18, 8.44, 8.99, 8.26, 7.83, 9.7, 9.49, 10.04, 9.02, 11.74, 
              10.77, 9.82, 10.41, 11.36, 11.22, 11.35, 10.6, 10.41, 12.31, 
              11.99, 12.78, 13.32, 12.84, 13.11, 15.61, 14.33, 13.75, 12.67, 
              13.11, 13.12, 16.44, 14.57, 13.4, 16.21, 16.01, 15.6, 14.95, 
              16.91, 15.89, 16.14, 16.51, 17.52, 15.37, 15.5, 17.77, 16.1, 
              18.22, 17.52, 19.08, 17.8, 17.09, 18.97, 16.37, 20.04, 19.01, 
              17.53, 20.07, 19.89, 18.18, 18.39, 19.67, 20.73, 19.87, 19.41, 
              21.68, 21.8, 20.62, 19.65, 20.67, 22.55, 22.03, 22.31, 23.05, 
              23.25, 22.94, 22.05, 22.88, 24.43, 22.95, 21.39, 24.17, 22.85, 
              24.8, 26.05, 26.1, 25.36, 25.19, 26.09, 25.12, 25.4, 24.65, 
              27.69, 23.93, 28.23, 27.13, 26.29, 28.29, 28.05, 26.45, 27.09, 
              28.57, 29.74, 28.09, 28.81, 30.58, 28.96, 27.61, 29.05, 28.93, 
              28.48, 29.29, 29.48, 30.26, 30.5, 29.35, 30.72, 31.58, 31.28, 
              33.63, 33.27, 32.9, 32.14, 32.02, 32.64, 34.61, 33.22, 32.78, 
              33.28, 32.26, 35.82, 35.09, 35.35, 33.58, 34.29, 34.77, 34.65, 
              36.72, 34.78, 36.68, 35.82, 35.99, 38.86, 36.74, 35.7, 36.5, 39.02, 
              35.93, 36.8, 35.8, 35.78, 40.93, 38.78, 38.5, 37.28, 38.51, 38.56, 
              38.32, 39.26, 40.75, 39.02, 41.05, 40.2, 39.24, 
              41.22, 41.07, 42.48, 41.86, 40.6, 40.66, 42.54])


x = np.array([  1,   6,  11,  16,  21,  26,  31,  36,  41,  46,  51,  56,  61,
         66,  71,  76,  81,  86,  91,  96, 101, 106, 111, 116, 121, 126,
        131, 136, 141, 146, 151, 156, 161, 166, 171, 176, 181, 186, 191,
        196, 201, 206, 211, 216, 221, 226, 231, 236, 241, 246, 251, 256,
        261, 266, 271, 276, 281, 286, 291, 296, 301, 306, 311, 316, 321,
        326, 331, 336, 341, 346, 351, 356, 361, 366, 371, 376, 381, 386,
        391, 396, 401, 406, 411, 416, 421, 426, 431, 436, 441, 446, 451,
        456, 461, 466, 471, 476, 481, 486, 491, 496, 501, 506, 511, 516,
        521, 526, 531, 536, 541, 546, 551, 556, 561, 566, 571, 576, 581,
        586, 591, 596, 601, 606, 611, 616, 621, 626, 631, 636, 641, 646,
        651, 656, 661, 666, 671, 676, 681, 686, 691, 696, 701, 706, 711,
        716, 721, 726, 731, 736, 741, 746, 751, 756, 761, 766, 771, 776,
        781, 786, 791, 796, 801, 806, 811, 816, 821, 826, 831, 836, 841,
        846, 851, 856, 861, 866, 871, 876, 881, 886, 891, 896, 901, 906,
        911, 916, 921, 926, 931, 936, 941, 946, 951, 956, 961, 966, 971,
        976, 981, 986, 991, 996])

# %% [markdown]
# ### 4.1 Fix the initial values of the parameters, learninng rate and error rate

# %% [markdown]
# ### 4.2 Initiate two list with intial values of the parameters

# %% [markdown]
# ### 4.3 Find the length of X

# %% [markdown]
# ### 4.4 Prepare the cost function

# %% [markdown]
# ### 4.5 Find the derivative of cost with respect to 'a'.

# %% [markdown]
# ### 4.6 Find the value of the derivative in 4.5 with the initial values of 'a' & 'b' and store it in a variable A

# %% [markdown]
# ### 4.7 Find the derivative of cost with respect to 'b'.

# %% [markdown]
# ### 4.8 Find the value of the derivative in 4.7 with the initial values of 'a' & 'b' and store it in a variable B

# %% [markdown]
# ### 4.9 Update the values of 'a' & 'b'

# %% [markdown]
# ### 4.10 Store the new values of the parametters in the listcreated in step 4.2

# %% [markdown]
# ### 4.11 Find the diference in the value of parameter from the initial values.

# %% [markdown]
# ### 4.12 if the difference in smaller than error rate stop otherwise recalculate the value of 4.6 & 4.8 with the new pair of parameter values

# %% [markdown]
# ### 4.13 Run a loop to repeat 4.9, 4.10, 4.11, 4.12 until we reach to the stopping condition.

# %% [markdown]
# ### 4.14 Combine all the steps and prepare the final version

# %% [markdown]
# ### --------------------------------------------------------------HAPPY LEARNING ! !-----------------------------------------------------------------
